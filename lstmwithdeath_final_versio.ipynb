# %% [markdown]
# <a href="https://colab.research.google.com/github/javmencia/COBWEBfiles/blob/main/lstmwithdeath_final_versio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## WITH DEATH

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (classification_report, balanced_accuracy_score,
                            accuracy_score, precision_recall_fscore_support,
                            confusion_matrix, roc_auc_score, cohen_kappa_score,
                            matthews_corrcoef)
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Masking, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
import os
import seaborn as sns
from sklearn.utils.class_weight import compute_class_weight
from collections import Counter
from keras import backend as K

# --- Set Random Seeds for Reproducibility ---
random.seed(1927)
np.random.seed(1927)
tf.random.set_seed(1927)

# --- Data Loading and Preparation ---
data = pd.read_csv('sledatacutsdi.csv', parse_dates=['ASSDT'])
data = data[data['end_state'].isin(['Disability Benefit', 'Employed', "Employed (Died)"])]  # Three classes

# Feature Engineering
data['sdi_flare_interaction'] = data['score_n'] * data['total_flares']
data['flares_per_month'] = data['total_flares'] / (data['time_since_first']/30 + 1e-6)
data['delta_SLEDAI_Renal'] = data.groupby('PTNO')['SLEDAI_Renal'].diff().fillna(0)
data['time_between_visits'] = data.groupby('PTNO')['ASSDT'].diff().dt.days
data['visits_last_year'] = data.groupby('PTNO')['ASSDT'].transform(
    lambda x: x.apply(lambda d: ((x >= (d - pd.Timedelta(days=365))) & (x <= d)).sum())
)

# Select features
numeric_cols = [col for col in data.select_dtypes(include=['int64', 'float64']).columns
               if col not in ['PTNO', 'total_visits96', 'time_first_last96', 'total_visits',
                             'time_first_last','AMS_alt', 'first_change_index', 'time_since_first',
                             'time_since_last', 'ID', 'MAXSTEROIDDOSE', 'time_between96',
                             'early_retirement', 'DEATH', 'age_at_death', 'age_at_retirement',
                             'EMP_numeric', 'lupus_primary_death', 'visit_num96',
                             'lupus_secondary_death', 'time_to_first_change', 'cum_time']]

# --- Data Cleaning and Scaling ---
for col in numeric_cols:
    # Handle infinite values
    data[col] = data[col].replace([np.inf, -np.inf], np.nan)

    # Log-transform large values
    if data[col].max() > 1e6:
        data[col] = np.log1p(data[col])

    # Fill NaNs
    data[col] = data[col].fillna(0)

# Apply scaling
scaler = MinMaxScaler(feature_range=(0, 1))
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])

# --- Feature Selection with Random Forest ---
print("=== Feature Selection with Random Forest ===")

# Get MAXIMUM value for each patient
max_obs = data.groupby('PTNO')[numeric_cols].max()
y_labels = data.groupby('PTNO')['end_state_encoded'].last()  # Last outcome

# Train RF to get feature importances
rf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf.fit(max_obs, y_labels)

# Get top 20 features
importances = rf.feature_importances_
top_25_idx = np.argsort(importances)[-25:]
selected_features = [numeric_cols[i] for i in top_25_idx]

print("\nSelected Top 20 Features:")
for i, feat in enumerate(selected_features):
    print(f"{i+1}. {feat} (importance: {importances[top_25_idx][i]:.4f})")

# --- Prepare Sequences with Selected Features ---
def create_sequences(data, features, max_seq_length=None):
    patients = data['PTNO'].unique()
    if not max_seq_length:
        max_seq_length = data.groupby('PTNO').size().max()

    X_seq = np.zeros((len(patients), max_seq_length, len(features)))
    y = np.zeros(len(patients))

    for i, patient in enumerate(patients):
        patient_data = data[data['PTNO'] == patient].sort_values('ASSDT')
        seq_len = len(patient_data)
        X_seq[i, :seq_len, :] = patient_data[features].values
        y[i] = patient_data['end_state_encoded'].iloc[-1]

    return X_seq, to_categorical(y)

# Create sequences with only selected features
X_seq, y = create_sequences(data, selected_features)
y_labels = np.argmax(y, axis=1)

# --- Class Balance Analysis ---
print("\n=== Class Distribution ===")
class_counts = Counter(y_labels)
for class_label, count in class_counts.items():
    class_name = ['Disability Benefit', 'Employed', "Employed (Died)"][class_label]
    print(f"Class {class_label} ({class_name}): {count} samples ({count/len(y_labels):.2%})")

# --- Data Augmentation for Minority Class ---
def augment_minority_class(X, y, minority_class=2, augmentation_factor=5):
    """Augment minority class samples by adding small noise to existing samples"""
    minority_indices = np.where(np.argmax(y, axis=1) == minority_class)[0]
    X_minority = X[minority_indices]
    y_minority = y[minority_indices]

    if len(X_minority) == 0:
        return X, y

    augmented_X = [X]
    augmented_y = [y]

    for _ in range(augmentation_factor):
        noise = np.random.normal(0, 0.01, size=X_minority.shape)
        augmented_X.append(X_minority + noise)
        augmented_y.append(y_minority)

    augmented_X = np.concatenate(augmented_X)
    augmented_y = np.concatenate(augmented_y)

    return augmented_X, augmented_y

# Augment only if minority class exists
if 2 in y_labels:
    X_seq_aug, y_aug = augment_minority_class(X_seq, y)
    y_labels_aug = np.argmax(y_aug, axis=1)
    print("\nAfter augmentation:")
    for class_label, count in Counter(y_labels_aug).items():
        class_name = ['Disability Benefit', 'Employed', "Employed (Died)"][class_label]
        print(f"Class {class_label} ({class_name}): {count} samples ({count/len(y_labels_aug):.2%})")
else:
    X_seq_aug, y_aug = X_seq, y
    y_labels_aug = y_labels

# Verify shapes before training
print("\n=== Data Shapes ===")
print(f"X_seq_aug shape: {X_seq_aug.shape}")  # Should be (n_samples, seq_length, n_features)
print(f"y_aug shape: {y_aug.shape}")  # Should be (n_samples, n_classes)

import tensorflow as tf
def balanced_accuracy_metric(y_true, y_pred):
    y_pred_classes = tf.argmax(y_pred, axis=-1)
    y_true_classes = tf.argmax(y_true, axis=-1)

    num_classes = y_pred.shape[1]  # Requires static shape

    class_accs = []
    for class_id in range(num_classes):
        mask = tf.equal(y_true_classes, class_id)
        class_correct = tf.reduce_sum(
            tf.cast(tf.equal(y_pred_classes[mask], y_true_classes[mask]), tf.float32)
        )
        class_total = tf.reduce_sum(tf.cast(mask, tf.float32))
        class_acc = class_correct / (class_total + tf.keras.backend.epsilon())
        class_accs.append(class_acc)

    return tf.reduce_mean(class_accs)

# --- LSTM Model with Improved Architecture ---
def build_lstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Masking(mask_value=0)(inputs)

    # First LSTM layer with more units
    x = LSTM(128, return_sequences=True, kernel_regularizer=tf.keras.regularizers.l2(0.01))(x)
    x = BatchNormalization()(x)
    x = Dropout(0.5)(x)

    # Second LSTM layer
    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.4)(x)

    # Third LSTM layer
    x = LSTM(32)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)

    # Additional dense layer
    x = Dense(32, activation='relu')(x)
    x = BatchNormalization()(x)

    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)

    # Custom metrics for imbalanced data
    metrics = [
        'accuracy',
        balanced_accuracy_metric,
        tf.keras.metrics.AUC(name='auc', multi_label=True),
        tf.keras.metrics.Precision(name='precision'),
        tf.keras.metrics.Recall(name='recall'),
        tf.keras.metrics.F1Score(name='f1_score', average='weighted')
    ]

    model.compile(optimizer=Adam(0.001),
                loss='categorical_crossentropy',
                metrics=metrics)

    return model

# --- LSTM Training with Selected Features ---
print("\n=== Training LSTM with Selected Features ===")
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=1927)

# Initialize metric storage
fold_metrics = {
    'precision_0': [], 'recall_0': [], 'f1_0': [],
    'precision_1': [], 'recall_1': [], 'f1_1': [],
    'precision_2': [], 'recall_2': [], 'f1_2': [],
    'bal_acc': [], 'acc': [], 'roc_auc_ovr': [], 'roc_auc_ovo': [],
    'kappa': [], 'mcc': []
}

class_accuracies = {0: [], 1: [], 2: []}  # To store accuracies for each class
all_y_true = []
all_y_pred = []
all_y_probs = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X_seq_aug, y_labels_aug)):
    print(f"\nFold {fold + 1}/{n_splits}")

    X_train, X_val = X_seq_aug[train_idx], X_seq_aug[val_idx]
    y_train, y_val = y_aug[train_idx], y_aug[val_idx]
    y_train_labels = np.argmax(y_train, axis=1)

    # Compute class weights
    class_weights = compute_class_weight('balanced', classes=np.unique(y_train_labels), y=y_train_labels)
    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

    # Build and train model
    model = build_lstm_model((X_seq_aug.shape[1], X_seq_aug.shape[2]), y_aug.shape[1])

    callbacks = [
        EarlyStopping(
            monitor='val_balanced_accuracy_metric',
            patience=20,
            restore_best_weights=True,
            min_delta=0.001,
            mode='max'
        ),
        ReduceLROnPlateau(
            monitor='val_balanced_accuracy_metric',
            factor=0.5,
            patience=10,
            min_lr=1e-6,
            verbose=1,
            mode='max'
        ),
        ModelCheckpoint(
            filepath=f'best_model_fold{fold}.h5',
            monitor='val_balanced_accuracy_metric',
            save_best_only=True,
            mode='max'
        )
    ]

    # Apply class weights through sample weights
    sample_weights = np.array([class_weight_dict[label] for label in y_train_labels])

    history = model.fit(
        X_train, y_train,
        epochs=300,
        batch_size=32,
        validation_data=(X_val, y_val),
        callbacks=callbacks,
        verbose=1,
        shuffle=True,
        sample_weight=sample_weights  # Using sample_weight instead of class_weight
    )

    # Load the best model
    try:
        model = load_model(f'best_model_fold{fold}.h5',
                          custom_objects={'balanced_accuracy_metric': balanced_accuracy_metric})
    except:
        print(f"Could not load best model for fold {fold+1}, using last epoch's model")

    # Evaluate
    y_pred = model.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_val, axis=1)

    # Store predictions for overall evaluation
    all_y_true.extend(y_true_classes)
    all_y_pred.extend(y_pred_classes)
    all_y_probs.extend(y_pred)

    # Calculate metrics
    bal_acc = balanced_accuracy_score(y_true_classes, y_pred_classes)
    acc = accuracy_score(y_true_classes, y_pred_classes)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true_classes, y_pred_classes, zero_division=0)
    kappa = cohen_kappa_score(y_true_classes, y_pred_classes)
    mcc = matthews_corrcoef(y_true_classes, y_pred_classes)

    # For multi-class ROC AUC
    if len(np.unique(y_true_classes)) > 2:
        try:
            roc_auc_ovr = roc_auc_score(y_true_classes, y_pred, multi_class='ovr')
            roc_auc_ovo = roc_auc_score(y_true_classes, y_pred, multi_class='ovo')
        except:
            roc_auc_ovr = np.nan
            roc_auc_ovo = np.nan

    # Store fold metrics
    for class_label in [0, 1, 2]:
        fold_metrics[f'precision_{class_label}'].append(precision[class_label] if class_label < len(precision) else np.nan)
        fold_metrics[f'recall_{class_label}'].append(recall[class_label] if class_label < len(recall) else np.nan)
        fold_metrics[f'f1_{class_label}'].append(f1[class_label] if class_label < len(f1) else np.nan)

    fold_metrics['bal_acc'].append(bal_acc)
    fold_metrics['acc'].append(acc)
    fold_metrics['kappa'].append(kappa)
    fold_metrics['mcc'].append(mcc)

    if len(np.unique(y_true_classes)) > 2:
        fold_metrics['roc_auc_ovr'].append(roc_auc_ovr)
        fold_metrics['roc_auc_ovo'].append(roc_auc_ovo)

    # Calculate and store accuracy for each class
    for class_label in [0, 1, 2]:
        class_mask = y_true_classes == class_label
        if sum(class_mask) > 0:
            class_acc = accuracy_score(y_true_classes[class_mask], y_pred_classes[class_mask])
            class_accuracies[class_label].append(class_acc)

    # Print fold results
    print(f"\nFold {fold + 1} Results:")
    print(f"Balanced Accuracy: {bal_acc:.4f}")
    print(f"Accuracy: {acc:.4f}")
    print(f"Cohen's Kappa: {kappa:.4f}")
    print(f"Matthews Correlation: {mcc:.4f}")
    if len(np.unique(y_true_classes)) > 2:
        print(f"ROC AUC (OvR): {roc_auc_ovr:.4f}")
        print(f"ROC AUC (OvO): {roc_auc_ovo:.4f}")

    print("\nClassification Report:")
    print(classification_report(y_true_classes, y_pred_classes,
                              target_names=['Disability Benefit', 'Employed', "Employed (Died)"],
                              zero_division=0))

    # Clean up model file
    try:
        os.remove(f'best_model_fold{fold}.h5')
    except:
        pass

# --- Final Evaluation ---
print("\n=== Final LSTM Evaluation ===")

# Calculate mean and std of all metrics
final_metrics = {k: (np.mean(v), np.std(v)) for k, v in fold_metrics.items() if len(v) > 0}

# Print averaged metrics
print("\n=== Average Performance Across All Folds ===")
print(f"Balanced Accuracy: {final_metrics['bal_acc'][0]:.4f} ± {final_metrics['bal_acc'][1]:.4f}")
print(f"Accuracy: {final_metrics['acc'][0]:.4f} ± {final_metrics['acc'][1]:.4f}")
print(f"Cohen's Kappa: {final_metrics['kappa'][0]:.4f} ± {final_metrics['kappa'][1]:.4f}")
print(f"Matthews Correlation: {final_metrics['mcc'][0]:.4f} ± {final_metrics['mcc'][1]:.4f}")
if 'roc_auc_ovr' in final_metrics:
    print(f"ROC AUC (OvR): {final_metrics['roc_auc_ovr'][0]:.4f} ± {final_metrics['roc_auc_ovr'][1]:.4f}")
    print(f"ROC AUC (OvO): {final_metrics['roc_auc_ovo'][0]:.4f} ± {final_metrics['roc_auc_ovo'][1]:.4f}")

print("\n=== Class-wise Average Performance ===")
for class_label in [0, 1, 2]:
    if len(class_accuracies.get(class_label, [])) > 0:
        print(f"\nClass {class_label}:")
        print(f"  Precision: {final_metrics[f'precision_{class_label}'][0]:.4f} ± {final_metrics[f'precision_{class_label}'][1]:.4f}")
        print(f"  Recall: {final_metrics[f'recall_{class_label}'][0]:.4f} ± {final_metrics[f'recall_{class_label}'][1]:.4f}")
        print(f"  F1-score: {final_metrics[f'f1_{class_label}'][0]:.4f} ± {final_metrics[f'f1_{class_label}'][1]:.4f}")
        print(f"  Accuracy: {np.mean(class_accuracies[class_label]):.4f} ± {np.std(class_accuracies[class_label]):.4f}")

# --- Comprehensive Evaluation on All Predictions ---
print("\n=== Comprehensive Evaluation on All Predictions ===")
all_y_true = np.array(all_y_true)
all_y_pred = np.array(all_y_pred)
all_y_probs = np.array(all_y_probs)

print("\nClassification Report:")
print(classification_report(all_y_true, all_y_pred,
                          target_names=['Disability Benefit', 'Employed', "Employed (Died)"],
                          zero_division=0))

print("\nConfusion Matrix:")
cm = confusion_matrix(all_y_true, all_y_pred)
print(cm)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=['Disability Benefit', 'Employed', "Employed (Died)"],
            yticklabels=['Disability Benefit', 'Employed', "Employed (Died)"])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

if len(np.unique(all_y_true)) > 2:
    try:
        print(f"\nROC AUC Score (OvR): {roc_auc_score(all_y_true, all_y_probs, multi_class='ovr'):.4f}")
        print(f"ROC AUC Score (OvO): {roc_auc_score(all_y_true, all_y_probs, multi_class='ovo'):.4f}")
    except:
        print("\nCould not calculate multi-class ROC AUC scores")

# --- Generate Final Report ---
print("\n=== FINAL REPORT ===")
print("Model: LSTM with 3 layers (128, 64 and 32 units)")
print(f"Cross-validation: {n_splits}-fold stratified")
print("\nAverage Performance Across Folds:")
print(f"- Balanced Accuracy: {final_metrics['bal_acc'][0]:.4f} ± {final_metrics['bal_acc'][1]:.4f}")
print(f"- Accuracy: {final_metrics['acc'][0]:.4f} ± {final_metrics['acc'][1]:.4f}")
print(f"- Cohen's Kappa: {final_metrics['kappa'][0]:.4f} ± {final_metrics['kappa'][1]:.4f}")
print(f"- Matthews Correlation: {final_metrics['mcc'][0]:.4f} ± {final_metrics['mcc'][1]:.4f}")
if 'roc_auc_ovr' in final_metrics:
    print(f"- ROC AUC (OvR): {final_metrics['roc_auc_ovr'][0]:.4f} ± {final_metrics['roc_auc_ovr'][1]:.4f}")
    print(f"- ROC AUC (OvO): {final_metrics['roc_auc_ovo'][0]:.4f} ± {final_metrics['roc_auc_ovo'][1]:.4f}")

for class_label in [0, 1, 2]:
    if len(class_accuracies.get(class_label, [])) > 0:
        class_name = ['Disability Benefit', 'Employed', "Employed (Died)"][class_label]
        print(f"\nClass {class_label} ({class_name}):")
        print(f"- Precision: {final_metrics[f'precision_{class_label}'][0]:.4f} ± {final_metrics[f'precision_{class_label}'][1]:.4f}")
        print(f"- Recall: {final_metrics[f'recall_{class_label}'][0]:.4f} ± {final_metrics[f'recall_{class_label}'][1]:.4f}")
        print(f"- F1-score: {final_metrics[f'f1_{class_label}'][0]:.4f} ± {final_metrics[f'f1_{class_label}'][1]:.4f}")
        print(f"- Accuracy: {np.mean(class_accuracies[class_label]):.4f} ± {np.std(class_accuracies[class_label]):.4f}")

print("\nConfusion Matrix (All Predictions):")
print(cm)
# Out:
# /tmp/ipython-input-3811813592.py:31: DtypeWarning: Columns (136,138,145,147,154,156,161) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sledatacutsdi.csv', parse_dates=['ASSDT'])
# /tmp/ipython-input-3811813592.py:67: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])
# === Feature Selection with Random Forest ===
#
# Selected Top 20 Features:
# 1. SLEDAI2_I (importance: 0.0139)
# 2. STERDOSE (importance: 0.0151)
# 3. cumulative_AMS_5yrs (importance: 0.0152)
# 4. visits_last_year (importance: 0.0158)
# 5. previous_sledai (importance: 0.0161)
# 6. time_since_dx (importance: 0.0170)
# 7. area (importance: 0.0182)
# 8. AMS (importance: 0.0184)
# 9. cum_steroid_average (importance: 0.0186)
# 10. sledai_change (importance: 0.0192)
# 11. time_interval (importance: 0.0205)
# 12. time_between (importance: 0.0208)
# 13. STERAVER (importance: 0.0217)
# 14. days_since_last_visit (importance: 0.0224)
# 15. sick_leave_spell (importance: 0.0234)
# 16. sdi_flare_interaction (importance: 0.0236)
# 17. time_between_visits (importance: 0.0236)
# 18. age_at_record (importance: 0.0258)
# 19. score_n (importance: 0.0260)
# 20. sick_leave_duration (importance: 0.0287)
# 21. cum_area (importance: 0.0312)
# 22. cum_steroid_dose (importance: 0.0355)
# 23. visit_num (importance: 0.0405)
# 24. cum_am_hydroxychloroquine (importance: 0.0524)
# 25. years_since_first_visit (importance: 0.0571)
#
# === Class Distribution ===
# Class 0 (Disability Benefit): 129 samples (14.19%)
# Class 1 (Employed): 753 samples (82.84%)
# Class 2 (Employed (Died)): 27 samples (2.97%)
#
# After augmentation:
# Class 0 (Disability Benefit): 129 samples (12.36%)
# Class 1 (Employed): 753 samples (72.13%)
# Class 2 (Employed (Died)): 162 samples (15.52%)
#
# === Data Shapes ===
# X_seq_aug shape: (1044, 87, 25)
# y_aug shape: (1044, 3)
#
# === Training LSTM with Selected Features ===
#
# Fold 1/5
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step - accuracy: 0.5034 - auc: 0.7972 - balanced_accuracy_metric: 0.6375 - f1_score: 0.5278 - loss: 1.3003 - precision: 0.5259 - recall: 0.4224
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 20s 343ms/step - accuracy: 0.5056 - auc: 0.7992 - balanced_accuracy_metric: 0.6391 - f1_score: 0.5303 - loss: 1.2940 - precision: 0.5284 - recall: 0.4245 - val_accuracy: 0.1244 - val_auc: 0.8421 - val_balanced_accuracy_metric: 0.2857 - val_f1_score: 0.0275 - val_loss: 1.4063 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.7367 - auc: 0.9145 - balanced_accuracy_metric: 0.8034 - f1_score: 0.7644 - loss: 0.8910 - precision: 0.7767 - recall: 0.6747
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.7366 - auc: 0.9145 - balanced_accuracy_metric: 0.8028 - f1_score: 0.7642 - loss: 0.8891 - precision: 0.7764 - recall: 0.6745 - val_accuracy: 0.6842 - val_auc: 0.8924 - val_balanced_accuracy_metric: 0.4200 - val_f1_score: 0.6738 - val_loss: 1.2815 - val_precision: 0.5000 - val_recall: 0.0144 - learning_rate: 0.0010
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 351ms/step - accuracy: 0.8285 - auc: 0.9376 - balanced_accuracy_metric: 0.8708 - f1_score: 0.8409 - loss: 0.7286 - precision: 0.8635 - recall: 0.7837 - val_accuracy: 0.7033 - val_auc: 0.8421 - val_balanced_accuracy_metric: 0.3353 - val_f1_score: 0.6374 - val_loss: 1.1743 - val_precision: 0.5000 - val_recall: 0.0239 - learning_rate: 0.0010
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8405 - auc: 0.9358 - balanced_accuracy_metric: 0.8648 - f1_score: 0.8532 - loss: 0.6749 - precision: 0.8579 - recall: 0.7924
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.8399 - auc: 0.9357 - balanced_accuracy_metric: 0.8639 - f1_score: 0.8527 - loss: 0.6738 - precision: 0.8576 - recall: 0.7919 - val_accuracy: 0.7512 - val_auc: 0.9069 - val_balanced_accuracy_metric: 0.4627 - val_f1_score: 0.7193 - val_loss: 1.1427 - val_precision: 0.7222 - val_recall: 0.0622 - learning_rate: 0.0010
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.8800 - auc: 0.9420 - balanced_accuracy_metric: 0.8913 - f1_score: 0.8861 - loss: 0.5931 - precision: 0.8966 - recall: 0.8537
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.8792 - auc: 0.9419 - balanced_accuracy_metric: 0.8900 - f1_score: 0.8855 - loss: 0.5925 - precision: 0.8961 - recall: 0.8526 - val_accuracy: 0.7895 - val_auc: 0.9346 - val_balanced_accuracy_metric: 0.4773 - val_f1_score: 0.7427 - val_loss: 1.0643 - val_precision: 0.9016 - val_recall: 0.2632 - learning_rate: 0.0010
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9024 - auc: 0.9516 - balanced_accuracy_metric: 0.9082 - f1_score: 0.9063 - loss: 0.5465 - precision: 0.9110 - recall: 0.8831 - val_accuracy: 0.7895 - val_auc: 0.9439 - val_balanced_accuracy_metric: 0.4773 - val_f1_score: 0.7230 - val_loss: 0.9561 - val_precision: 0.9273 - val_recall: 0.7321 - learning_rate: 0.0010
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 290ms/step - accuracy: 0.8980 - auc: 0.9494 - balanced_accuracy_metric: 0.8955 - f1_score: 0.9020 - loss: 0.5393 - precision: 0.9161 - recall: 0.8836 - val_accuracy: 0.7799 - val_auc: 0.9172 - val_balanced_accuracy_metric: 0.4377 - val_f1_score: 0.7348 - val_loss: 0.9047 - val_precision: 0.8901 - val_recall: 0.7751 - learning_rate: 0.0010
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step - accuracy: 0.9096 - auc: 0.9425 - balanced_accuracy_metric: 0.8862 - f1_score: 0.9106 - loss: 0.5455 - precision: 0.9126 - recall: 0.8950
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 310ms/step - accuracy: 0.9088 - auc: 0.9424 - balanced_accuracy_metric: 0.8854 - f1_score: 0.9099 - loss: 0.5443 - precision: 0.9121 - recall: 0.8940 - val_accuracy: 0.9139 - val_auc: 0.9553 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.7012 - val_precision: 0.9011 - val_recall: 0.7847 - learning_rate: 0.0010
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.8977 - auc: 0.9505 - balanced_accuracy_metric: 0.9029 - f1_score: 0.9022 - loss: 0.4985 - precision: 0.9191 - recall: 0.8751 - val_accuracy: 0.7895 - val_auc: 0.9491 - val_balanced_accuracy_metric: 0.4773 - val_f1_score: 0.7230 - val_loss: 0.6742 - val_precision: 0.9011 - val_recall: 0.7847 - learning_rate: 0.0010
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9036 - auc: 0.9529 - balanced_accuracy_metric: 0.9008 - f1_score: 0.9054 - loss: 0.4755 - precision: 0.9183 - recall: 0.8827 - val_accuracy: 0.9091 - val_auc: 0.9557 - val_balanced_accuracy_metric: 0.5673 - val_f1_score: 0.9081 - val_loss: 0.6014 - val_precision: 0.9066 - val_recall: 0.7895 - learning_rate: 0.0010
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9204 - auc: 0.9530 - balanced_accuracy_metric: 0.9154 - f1_score: 0.9214 - loss: 0.4646 - precision: 0.9262 - recall: 0.9101 - val_accuracy: 0.9139 - val_auc: 0.9599 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.4898 - val_precision: 0.9139 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.9126 - auc: 0.9477 - balanced_accuracy_metric: 0.9018 - f1_score: 0.9135 - loss: 0.4755 - precision: 0.9253 - recall: 0.8968
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9124 - auc: 0.9477 - balanced_accuracy_metric: 0.9008 - f1_score: 0.9132 - loss: 0.4746 - precision: 0.9251 - recall: 0.8965 - val_accuracy: 0.9187 - val_auc: 0.9635 - val_balanced_accuracy_metric: 0.5821 - val_f1_score: 0.9183 - val_loss: 0.4699 - val_precision: 0.9231 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step - accuracy: 0.9236 - auc: 0.9386 - balanced_accuracy_metric: 0.9149 - f1_score: 0.9237 - loss: 0.4823 - precision: 0.9303 - recall: 0.9081
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9230 - auc: 0.9386 - balanced_accuracy_metric: 0.9137 - f1_score: 0.9232 - loss: 0.4814 - precision: 0.9299 - recall: 0.9075 - val_accuracy: 0.9282 - val_auc: 0.9617 - val_balanced_accuracy_metric: 0.6154 - val_f1_score: 0.9283 - val_loss: 0.4456 - val_precision: 0.9366 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 376ms/step - accuracy: 0.9132 - auc: 0.9613 - balanced_accuracy_metric: 0.9108 - f1_score: 0.9143 - loss: 0.4265 - precision: 0.9286 - recall: 0.8887 - val_accuracy: 0.9139 - val_auc: 0.9574 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.4283 - val_precision: 0.9317 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9114 - auc: 0.9550 - balanced_accuracy_metric: 0.9049 - f1_score: 0.9122 - loss: 0.4388 - precision: 0.9228 - recall: 0.8934 - val_accuracy: 0.9139 - val_auc: 0.9602 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9131 - val_loss: 0.4120 - val_precision: 0.9317 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9212 - auc: 0.9610 - balanced_accuracy_metric: 0.9076 - f1_score: 0.9222 - loss: 0.4314 - precision: 0.9303 - recall: 0.9043 - val_accuracy: 0.9187 - val_auc: 0.9620 - val_balanced_accuracy_metric: 0.5821 - val_f1_score: 0.9182 - val_loss: 0.3967 - val_precision: 0.9317 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.9175 - auc: 0.9576 - balanced_accuracy_metric: 0.9178 - f1_score: 0.9182 - loss: 0.4030 - precision: 0.9352 - recall: 0.9010 - val_accuracy: 0.9139 - val_auc: 0.9615 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.3994 - val_precision: 0.9139 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 296ms/step - accuracy: 0.9161 - auc: 0.9564 - balanced_accuracy_metric: 0.9129 - f1_score: 0.9170 - loss: 0.4225 - precision: 0.9248 - recall: 0.9018 - val_accuracy: 0.9187 - val_auc: 0.9632 - val_balanced_accuracy_metric: 0.5821 - val_f1_score: 0.9183 - val_loss: 0.3988 - val_precision: 0.9227 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 294ms/step - accuracy: 0.9164 - auc: 0.9649 - balanced_accuracy_metric: 0.9050 - f1_score: 0.9172 - loss: 0.3978 - precision: 0.9263 - recall: 0.9071 - val_accuracy: 0.9187 - val_auc: 0.9578 - val_balanced_accuracy_metric: 0.5821 - val_f1_score: 0.9183 - val_loss: 0.4060 - val_precision: 0.9272 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.9153 - auc: 0.9568 - balanced_accuracy_metric: 0.9066 - f1_score: 0.9166 - loss: 0.4238 - precision: 0.9228 - recall: 0.9046 - val_accuracy: 0.9139 - val_auc: 0.9598 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.3939 - val_precision: 0.9227 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 298ms/step - accuracy: 0.9285 - auc: 0.9531 - balanced_accuracy_metric: 0.9266 - f1_score: 0.9298 - loss: 0.4209 - precision: 0.9295 - recall: 0.9140 - val_accuracy: 0.9139 - val_auc: 0.9562 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.3865 - val_precision: 0.9139 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 304ms/step - accuracy: 0.9109 - auc: 0.9509 - balanced_accuracy_metric: 0.8981 - f1_score: 0.9121 - loss: 0.4393 - precision: 0.9159 - recall: 0.9001 - val_accuracy: 0.9139 - val_auc: 0.9525 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.4146 - val_precision: 0.9139 - val_recall: 0.9139 - learning_rate: 0.0010
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9168 - auc: 0.9585 - balanced_accuracy_metric: 0.8967 - f1_score: 0.9178 - loss: 0.4147 - precision: 0.9235 - recall: 0.9129
# Epoch 23: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9166 - auc: 0.9583 - balanced_accuracy_metric: 0.8961 - f1_score: 0.9176 - loss: 0.4140 - precision: 0.9233 - recall: 0.9125 - val_accuracy: 0.9187 - val_auc: 0.9586 - val_balanced_accuracy_metric: 0.5749 - val_f1_score: 0.9176 - val_loss: 0.3725 - val_precision: 0.9187 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 259ms/step - accuracy: 0.9256 - auc: 0.9621 - balanced_accuracy_metric: 0.9150 - f1_score: 0.9262 - loss: 0.3866 - precision: 0.9291 - recall: 0.9133 - val_accuracy: 0.9282 - val_auc: 0.9608 - val_balanced_accuracy_metric: 0.5969 - val_f1_score: 0.9283 - val_loss: 0.3540 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 5.0000e-04
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9306 - auc: 0.9679 - balanced_accuracy_metric: 0.9186 - f1_score: 0.9306 - loss: 0.3638 - precision: 0.9409 - recall: 0.9261 - val_accuracy: 0.9139 - val_auc: 0.9601 - val_balanced_accuracy_metric: 0.5726 - val_f1_score: 0.9132 - val_loss: 0.3768 - val_precision: 0.9183 - val_recall: 0.9139 - learning_rate: 5.0000e-04
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9256 - auc: 0.9675 - balanced_accuracy_metric: 0.9103 - f1_score: 0.9255 - loss: 0.3748 - precision: 0.9341 - recall: 0.9127 - val_accuracy: 0.9187 - val_auc: 0.9624 - val_balanced_accuracy_metric: 0.5821 - val_f1_score: 0.9183 - val_loss: 0.3459 - val_precision: 0.9187 - val_recall: 0.9187 - learning_rate: 5.0000e-04
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step - accuracy: 0.9309 - auc: 0.9638 - balanced_accuracy_metric: 0.9230 - f1_score: 0.9313 - loss: 0.3735 - precision: 0.9413 - recall: 0.9234 - val_accuracy: 0.9282 - val_auc: 0.9634 - val_balanced_accuracy_metric: 0.5969 - val_f1_score: 0.9283 - val_loss: 0.3478 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - accuracy: 0.9274 - auc: 0.9663 - balanced_accuracy_metric: 0.9184 - f1_score: 0.9278 - loss: 0.3829 - precision: 0.9312 - recall: 0.9201 - val_accuracy: 0.9282 - val_auc: 0.9636 - val_balanced_accuracy_metric: 0.6154 - val_f1_score: 0.9282 - val_loss: 0.3640 - val_precision: 0.9372 - val_recall: 0.9282 - learning_rate: 5.0000e-04
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 261ms/step - accuracy: 0.9229 - auc: 0.9593 - balanced_accuracy_metric: 0.9167 - f1_score: 0.9237 - loss: 0.3894 - precision: 0.9282 - recall: 0.9140 - val_accuracy: 0.9282 - val_auc: 0.9648 - val_balanced_accuracy_metric: 0.5969 - val_f1_score: 0.9282 - val_loss: 0.3402 - val_precision: 0.9369 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.9342 - auc: 0.9761 - balanced_accuracy_metric: 0.9291 - f1_score: 0.9341 - loss: 0.3352 - precision: 0.9399 - recall: 0.9149 - val_accuracy: 0.9282 - val_auc: 0.9648 - val_balanced_accuracy_metric: 0.6154 - val_f1_score: 0.9282 - val_loss: 0.3422 - val_precision: 0.9372 - val_recall: 0.9282 - learning_rate: 5.0000e-04
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9228 - auc: 0.9650 - balanced_accuracy_metric: 0.9144 - f1_score: 0.9234 - loss: 0.3681 - precision: 0.9313 - recall: 0.9131
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - accuracy: 0.9223 - auc: 0.9648 - balanced_accuracy_metric: 0.9135 - f1_score: 0.9230 - loss: 0.3675 - precision: 0.9310 - recall: 0.9126 - val_accuracy: 0.9378 - val_auc: 0.9636 - val_balanced_accuracy_metric: 0.6303 - val_f1_score: 0.9379 - val_loss: 0.3442 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 5.0000e-04
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 250ms/step - accuracy: 0.9239 - auc: 0.9630 - balanced_accuracy_metric: 0.9174 - f1_score: 0.9245 - loss: 0.3746 - precision: 0.9298 - recall: 0.9105 - val_accuracy: 0.9234 - val_auc: 0.9629 - val_balanced_accuracy_metric: 0.5916 - val_f1_score: 0.9233 - val_loss: 0.3549 - val_precision: 0.9279 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9244 - auc: 0.9712 - balanced_accuracy_metric: 0.9177 - f1_score: 0.9249 - loss: 0.3473 - precision: 0.9381 - recall: 0.9111 - val_accuracy: 0.9282 - val_auc: 0.9627 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3557 - val_precision: 0.9279 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 284ms/step - accuracy: 0.9264 - auc: 0.9600 - balanced_accuracy_metric: 0.9217 - f1_score: 0.9267 - loss: 0.3686 - precision: 0.9368 - recall: 0.9166 - val_accuracy: 0.9187 - val_auc: 0.9603 - val_balanced_accuracy_metric: 0.5744 - val_f1_score: 0.9176 - val_loss: 0.3737 - val_precision: 0.9231 - val_recall: 0.9187 - learning_rate: 5.0000e-04
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - accuracy: 0.9298 - auc: 0.9694 - balanced_accuracy_metric: 0.9266 - f1_score: 0.9297 - loss: 0.3419 - precision: 0.9335 - recall: 0.9222 - val_accuracy: 0.9282 - val_auc: 0.9583 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3493 - val_precision: 0.9369 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 252ms/step - accuracy: 0.9269 - auc: 0.9689 - balanced_accuracy_metric: 0.9172 - f1_score: 0.9274 - loss: 0.3537 - precision: 0.9341 - recall: 0.9131 - val_accuracy: 0.9282 - val_auc: 0.9606 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3369 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 5.0000e-04
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 272ms/step - accuracy: 0.9319 - auc: 0.9709 - balanced_accuracy_metric: 0.9212 - f1_score: 0.9316 - loss: 0.3420 - precision: 0.9435 - recall: 0.9252 - val_accuracy: 0.9378 - val_auc: 0.9616 - val_balanced_accuracy_metric: 0.6226 - val_f1_score: 0.9375 - val_loss: 0.3405 - val_precision: 0.9420 - val_recall: 0.9330 - learning_rate: 5.0000e-04
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 303ms/step - accuracy: 0.9275 - auc: 0.9739 - balanced_accuracy_metric: 0.9265 - f1_score: 0.9283 - loss: 0.3216 - precision: 0.9375 - recall: 0.9179 - val_accuracy: 0.9282 - val_auc: 0.9648 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3313 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 5.0000e-04
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.9270 - auc: 0.9747 - balanced_accuracy_metric: 0.9200 - f1_score: 0.9271 - loss: 0.3329 - precision: 0.9325 - recall: 0.9203 - val_accuracy: 0.9378 - val_auc: 0.9624 - val_balanced_accuracy_metric: 0.6226 - val_f1_score: 0.9375 - val_loss: 0.3316 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 5.0000e-04
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 259ms/step - accuracy: 0.9273 - auc: 0.9705 - balanced_accuracy_metric: 0.9303 - f1_score: 0.9285 - loss: 0.3303 - precision: 0.9377 - recall: 0.9124 - val_accuracy: 0.9282 - val_auc: 0.9602 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3427 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 5.0000e-04
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.9184 - auc: 0.9703 - balanced_accuracy_metric: 0.8974 - f1_score: 0.9190 - loss: 0.3555 - precision: 0.9318 - recall: 0.9125
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9180 - auc: 0.9701 - balanced_accuracy_metric: 0.8968 - f1_score: 0.9187 - loss: 0.3550 - precision: 0.9315 - recall: 0.9120 - val_accuracy: 0.9187 - val_auc: 0.9604 - val_balanced_accuracy_metric: 0.5714 - val_f1_score: 0.9167 - val_loss: 0.3436 - val_precision: 0.9231 - val_recall: 0.9187 - learning_rate: 5.0000e-04
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 0.9342 - auc: 0.9793 - balanced_accuracy_metric: 0.9265 - f1_score: 0.9337 - loss: 0.3086 - precision: 0.9468 - recall: 0.9221 - val_accuracy: 0.9282 - val_auc: 0.9606 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3444 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 255ms/step - accuracy: 0.9343 - auc: 0.9748 - balanced_accuracy_metric: 0.9291 - f1_score: 0.9344 - loss: 0.3208 - precision: 0.9430 - recall: 0.9186 - val_accuracy: 0.9282 - val_auc: 0.9606 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3339 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 2.5000e-04
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9287 - auc: 0.9725 - balanced_accuracy_metric: 0.9265 - f1_score: 0.9291 - loss: 0.3241 - precision: 0.9350 - recall: 0.9184 - val_accuracy: 0.9187 - val_auc: 0.9577 - val_balanced_accuracy_metric: 0.5744 - val_f1_score: 0.9176 - val_loss: 0.3545 - val_precision: 0.9231 - val_recall: 0.9187 - learning_rate: 2.5000e-04
# Epoch 45/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 13s 499ms/step - accuracy: 0.9307 - auc: 0.9781 - balanced_accuracy_metric: 0.9177 - f1_score: 0.9311 - loss: 0.2994 - precision: 0.9409 - recall: 0.9213 - val_accuracy: 0.9234 - val_auc: 0.9586 - val_balanced_accuracy_metric: 0.5839 - val_f1_score: 0.9227 - val_loss: 0.3501 - val_precision: 0.9369 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 46/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 15s 275ms/step - accuracy: 0.9295 - auc: 0.9746 - balanced_accuracy_metric: 0.9256 - f1_score: 0.9297 - loss: 0.3186 - precision: 0.9410 - recall: 0.9277 - val_accuracy: 0.9330 - val_auc: 0.9597 - val_balanced_accuracy_metric: 0.5988 - val_f1_score: 0.9326 - val_loss: 0.3323 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 2.5000e-04
# Epoch 47/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9262 - auc: 0.9762 - balanced_accuracy_metric: 0.9209 - f1_score: 0.9265 - loss: 0.3178 - precision: 0.9374 - recall: 0.9161 - val_accuracy: 0.9282 - val_auc: 0.9576 - val_balanced_accuracy_metric: 0.5892 - val_f1_score: 0.9277 - val_loss: 0.3437 - val_precision: 0.9275 - val_recall: 0.9187 - learning_rate: 2.5000e-04
# Epoch 48/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - accuracy: 0.9415 - auc: 0.9788 - balanced_accuracy_metric: 0.9379 - f1_score: 0.9420 - loss: 0.2987 - precision: 0.9522 - recall: 0.9329 - val_accuracy: 0.9187 - val_auc: 0.9573 - val_balanced_accuracy_metric: 0.5744 - val_f1_score: 0.9175 - val_loss: 0.3595 - val_precision: 0.9231 - val_recall: 0.9187 - learning_rate: 2.5000e-04
# Epoch 49/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.9306 - auc: 0.9767 - balanced_accuracy_metric: 0.9204 - f1_score: 0.9312 - loss: 0.3165 - precision: 0.9456 - recall: 0.9252
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 255ms/step - accuracy: 0.9302 - auc: 0.9765 - balanced_accuracy_metric: 0.9194 - f1_score: 0.9309 - loss: 0.3164 - precision: 0.9452 - recall: 0.9248 - val_accuracy: 0.9378 - val_auc: 0.9597 - val_balanced_accuracy_metric: 0.6683 - val_f1_score: 0.9379 - val_loss: 0.3358 - val_precision: 0.9420 - val_recall: 0.9330 - learning_rate: 2.5000e-04
# Epoch 50/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9201 - auc: 0.9755 - balanced_accuracy_metric: 0.9256 - f1_score: 0.9211 - loss: 0.3188 - precision: 0.9308 - recall: 0.9131 - val_accuracy: 0.9282 - val_auc: 0.9592 - val_balanced_accuracy_metric: 0.5935 - val_f1_score: 0.9277 - val_loss: 0.3408 - val_precision: 0.9327 - val_recall: 0.9282 - learning_rate: 2.5000e-04
# Epoch 51/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9354 - auc: 0.9746 - balanced_accuracy_metric: 0.9312 - f1_score: 0.9351 - loss: 0.3114 - precision: 0.9430 - recall: 0.9239 - val_accuracy: 0.9330 - val_auc: 0.9610 - val_balanced_accuracy_metric: 0.5988 - val_f1_score: 0.9326 - val_loss: 0.3257 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 2.5000e-04
# Epoch 52/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 286ms/step - accuracy: 0.9365 - auc: 0.9773 - balanced_accuracy_metric: 0.9330 - f1_score: 0.9363 - loss: 0.2982 - precision: 0.9488 - recall: 0.9223 - val_accuracy: 0.9234 - val_auc: 0.9579 - val_balanced_accuracy_metric: 0.5916 - val_f1_score: 0.9233 - val_loss: 0.3479 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 53/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - accuracy: 0.9356 - auc: 0.9762 - balanced_accuracy_metric: 0.9319 - f1_score: 0.9364 - loss: 0.3051 - precision: 0.9392 - recall: 0.9233 - val_accuracy: 0.9330 - val_auc: 0.9579 - val_balanced_accuracy_metric: 0.5988 - val_f1_score: 0.9326 - val_loss: 0.3258 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 2.5000e-04
# Epoch 54/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 250ms/step - accuracy: 0.9351 - auc: 0.9756 - balanced_accuracy_metric: 0.9331 - f1_score: 0.9349 - loss: 0.2981 - precision: 0.9507 - recall: 0.9282 - val_accuracy: 0.9234 - val_auc: 0.9599 - val_balanced_accuracy_metric: 0.5839 - val_f1_score: 0.9227 - val_loss: 0.3418 - val_precision: 0.9234 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 55/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9349 - auc: 0.9807 - balanced_accuracy_metric: 0.9242 - f1_score: 0.9348 - loss: 0.3033 - precision: 0.9486 - recall: 0.9305 - val_accuracy: 0.9234 - val_auc: 0.9587 - val_balanced_accuracy_metric: 0.5839 - val_f1_score: 0.9227 - val_loss: 0.3324 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 56/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 329ms/step - accuracy: 0.9337 - auc: 0.9797 - balanced_accuracy_metric: 0.9295 - f1_score: 0.9337 - loss: 0.2912 - precision: 0.9425 - recall: 0.9280 - val_accuracy: 0.9234 - val_auc: 0.9607 - val_balanced_accuracy_metric: 0.5839 - val_f1_score: 0.9227 - val_loss: 0.3404 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 2.5000e-04
# Epoch 57/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9407 - auc: 0.9749 - balanced_accuracy_metric: 0.9295 - f1_score: 0.9404 - loss: 0.3162 - precision: 0.9429 - recall: 0.9377 - val_accuracy: 0.9330 - val_auc: 0.9595 - val_balanced_accuracy_metric: 0.5988 - val_f1_score: 0.9326 - val_loss: 0.3395 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 2.5000e-04
# Epoch 58/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 302ms/step - accuracy: 0.9361 - auc: 0.9831 - balanced_accuracy_metric: 0.9262 - f1_score: 0.9360 - loss: 0.2832 - precision: 0.9506 - recall: 0.9291 - val_accuracy: 0.9330 - val_auc: 0.9587 - val_balanced_accuracy_metric: 0.5988 - val_f1_score: 0.9326 - val_loss: 0.3365 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 2.5000e-04
# Epoch 59/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step - accuracy: 0.9338 - auc: 0.9746 - balanced_accuracy_metric: 0.9297 - f1_score: 0.9340 - loss: 0.3103 - precision: 0.9421 - recall: 0.9318
# Epoch 59: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 273ms/step - accuracy: 0.9338 - auc: 0.9745 - balanced_accuracy_metric: 0.9288 - f1_score: 0.9340 - loss: 0.3097 - precision: 0.9420 - recall: 0.9316 - val_accuracy: 0.9187 - val_auc: 0.9593 - val_balanced_accuracy_metric: 0.5744 - val_f1_score: 0.9175 - val_loss: 0.3502 - val_precision: 0.9320 - val_recall: 0.9187 - learning_rate: 2.5000e-04
# Epoch 60/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 275ms/step - accuracy: 0.9406 - auc: 0.9792 - balanced_accuracy_metric: 0.9314 - f1_score: 0.9404 - loss: 0.2953 - precision: 0.9427 - recall: 0.9276 - val_accuracy: 0.9139 - val_auc: 0.9565 - val_balanced_accuracy_metric: 0.5691 - val_f1_score: 0.9122 - val_loss: 0.3677 - val_precision: 0.9227 - val_recall: 0.9139 - learning_rate: 1.2500e-04
# Epoch 61/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 12s 347ms/step - accuracy: 0.9393 - auc: 0.9833 - balanced_accuracy_metric: 0.9385 - f1_score: 0.9397 - loss: 0.2688 - precision: 0.9412 - recall: 0.9343 - val_accuracy: 0.9187 - val_auc: 0.9575 - val_balanced_accuracy_metric: 0.5744 - val_f1_score: 0.9175 - val_loss: 0.3638 - val_precision: 0.9227 - val_recall: 0.9139 - learning_rate: 1.2500e-04
# Epoch 62/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 304ms/step - accuracy: 0.9409 - auc: 0.9823 - balanced_accuracy_metric: 0.9306 - f1_score: 0.9405 - loss: 0.2806 - precision: 0.9423 - recall: 0.9339 - val_accuracy: 0.9282 - val_auc: 0.9597 - val_balanced_accuracy_metric: 0.5892 - val_f1_score: 0.9277 - val_loss: 0.3435 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 1.2500e-04
# Epoch 63/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 254ms/step - accuracy: 0.9388 - auc: 0.9780 - balanced_accuracy_metric: 0.9324 - f1_score: 0.9385 - loss: 0.2886 - precision: 0.9403 - recall: 0.9357 - val_accuracy: 0.9378 - val_auc: 0.9606 - val_balanced_accuracy_metric: 0.6226 - val_f1_score: 0.9375 - val_loss: 0.3360 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 1.2500e-04
# Epoch 64/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9452 - auc: 0.9773 - balanced_accuracy_metric: 0.9425 - f1_score: 0.9454 - loss: 0.2863 - precision: 0.9516 - recall: 0.9310 - val_accuracy: 0.9282 - val_auc: 0.9610 - val_balanced_accuracy_metric: 0.5892 - val_f1_score: 0.9277 - val_loss: 0.3373 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 1.2500e-04
# Epoch 65/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 281ms/step - accuracy: 0.9295 - auc: 0.9799 - balanced_accuracy_metric: 0.9221 - f1_score: 0.9295 - loss: 0.3003 - precision: 0.9309 - recall: 0.9198 - val_accuracy: 0.9378 - val_auc: 0.9617 - val_balanced_accuracy_metric: 0.6464 - val_f1_score: 0.9377 - val_loss: 0.3317 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 1.2500e-04
# Epoch 66/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 253ms/step - accuracy: 0.9338 - auc: 0.9774 - balanced_accuracy_metric: 0.9222 - f1_score: 0.9337 - loss: 0.3034 - precision: 0.9428 - recall: 0.9256 - val_accuracy: 0.9378 - val_auc: 0.9613 - val_balanced_accuracy_metric: 0.6464 - val_f1_score: 0.9377 - val_loss: 0.3292 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 1.2500e-04
# Epoch 67/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9474 - auc: 0.9768 - balanced_accuracy_metric: 0.9467 - f1_score: 0.9475 - loss: 0.2819 - precision: 0.9527 - recall: 0.9430 - val_accuracy: 0.9330 - val_auc: 0.9606 - val_balanced_accuracy_metric: 0.6368 - val_f1_score: 0.9328 - val_loss: 0.3393 - val_precision: 0.9324 - val_recall: 0.9234 - learning_rate: 1.2500e-04
# Epoch 68/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 269ms/step - accuracy: 0.9230 - auc: 0.9792 - balanced_accuracy_metric: 0.9186 - f1_score: 0.9236 - loss: 0.2956 - precision: 0.9369 - recall: 0.9172 - val_accuracy: 0.9378 - val_auc: 0.9612 - val_balanced_accuracy_metric: 0.6464 - val_f1_score: 0.9377 - val_loss: 0.3292 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 1.2500e-04
# Epoch 69/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.9420 - auc: 0.9806 - balanced_accuracy_metric: 0.9362 - f1_score: 0.9424 - loss: 0.2741 - precision: 0.9501 - recall: 0.9358
# Epoch 69: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.9416 - auc: 0.9805 - balanced_accuracy_metric: 0.9350 - f1_score: 0.9420 - loss: 0.2741 - precision: 0.9495 - recall: 0.9353 - val_accuracy: 0.9330 - val_auc: 0.9591 - val_balanced_accuracy_metric: 0.6368 - val_f1_score: 0.9328 - val_loss: 0.3468 - val_precision: 0.9372 - val_recall: 0.9282 - learning_rate: 1.2500e-04
# Could not load best model for fold 1, using last epoch's model
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 156ms/step
#
# Fold 1 Results:
# Balanced Accuracy: 0.9090
# Accuracy: 0.9378
# Cohen's Kappa: 0.8585
# Matthews Correlation: 0.8589
# ROC AUC (OvR): 0.9605
# ROC AUC (OvO): 0.9674
#
# Classification Report:
#                     precision    recall  f1-score   support
#
# Disability Benefit       0.83      0.92      0.87        26
#           Employed       0.96      0.96      0.96       151
#    Employed (Died)       0.93      0.84      0.89        32
#
#           accuracy                           0.94       209
#          macro avg       0.91      0.91      0.91       209
#       weighted avg       0.94      0.94      0.94       209
#
#
# Fold 2/5
# Epoch 1/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.4892 - auc: 0.7354 - balanced_accuracy_metric: 0.5417 - f1_score: 0.5182 - loss: 1.4464 - precision: 0.4972 - recall: 0.3796
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 19s 318ms/step - accuracy: 0.4922 - auc: 0.7385 - balanced_accuracy_metric: 0.5451 - f1_score: 0.5212 - loss: 1.4377 - precision: 0.5007 - recall: 0.3825 - val_accuracy: 0.7656 - val_auc: 0.9191 - val_balanced_accuracy_metric: 0.3688 - val_f1_score: 0.6961 - val_loss: 1.3319 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 0.0010
# Epoch 2/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step - accuracy: 0.7315 - auc: 0.9004 - balanced_accuracy_metric: 0.7901 - f1_score: 0.7483 - loss: 0.9288 - precision: 0.7886 - recall: 0.6260
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.7313 - auc: 0.9006 - balanced_accuracy_metric: 0.7892 - f1_score: 0.7482 - loss: 0.9264 - precision: 0.7881 - recall: 0.6260 - val_accuracy: 0.7751 - val_auc: 0.9449 - val_balanced_accuracy_metric: 0.4244 - val_f1_score: 0.7070 - val_loss: 1.1523 - val_precision: 0.6429 - val_recall: 0.0431 - learning_rate: 0.0010
# Epoch 3/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 308ms/step - accuracy: 0.8126 - auc: 0.9204 - balanced_accuracy_metric: 0.8415 - f1_score: 0.8208 - loss: 0.7616 - precision: 0.8511 - recall: 0.7484 - val_accuracy: 0.7751 - val_auc: 0.9419 - val_balanced_accuracy_metric: 0.3887 - val_f1_score: 0.7070 - val_loss: 1.0162 - val_precision: 0.9291 - val_recall: 0.6268 - learning_rate: 0.0010
# Epoch 4/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step - accuracy: 0.8458 - auc: 0.9182 - balanced_accuracy_metric: 0.8502 - f1_score: 0.8515 - loss: 0.6943 - precision: 0.8833 - recall: 0.7814
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - accuracy: 0.8455 - auc: 0.9182 - balanced_accuracy_metric: 0.8498 - f1_score: 0.8512 - loss: 0.6930 - precision: 0.8830 - recall: 0.7805 - val_accuracy: 0.7847 - val_auc: 0.9550 - val_balanced_accuracy_metric: 0.4537 - val_f1_score: 0.7181 - val_loss: 0.9248 - val_precision: 0.9329 - val_recall: 0.7321 - learning_rate: 0.0010
# Epoch 5/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step - accuracy: 0.8749 - auc: 0.9262 - balanced_accuracy_metric: 0.8707 - f1_score: 0.8792 - loss: 0.6345 - precision: 0.8953 - recall: 0.8252
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.8742 - auc: 0.9262 - balanced_accuracy_metric: 0.8698 - f1_score: 0.8787 - loss: 0.6338 - precision: 0.8948 - recall: 0.8243 - val_accuracy: 0.7943 - val_auc: 0.9497 - val_balanced_accuracy_metric: 0.4670 - val_f1_score: 0.7278 - val_loss: 0.8528 - val_precision: 0.8069 - val_recall: 0.7799 - learning_rate: 0.0010
# Epoch 6/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step - accuracy: 0.8769 - auc: 0.9263 - balanced_accuracy_metric: 0.8869 - f1_score: 0.8818 - loss: 0.6077 - precision: 0.8865 - recall: 0.8262
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.8769 - auc: 0.9264 - balanced_accuracy_metric: 0.8862 - f1_score: 0.8818 - loss: 0.6059 - precision: 0.8867 - recall: 0.8262 - val_accuracy: 0.7990 - val_auc: 0.7429 - val_balanced_accuracy_metric: 0.4749 - val_f1_score: 0.7574 - val_loss: 0.8789 - val_precision: 0.9375 - val_recall: 0.7895 - learning_rate: 0.0010
# Epoch 7/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step - accuracy: 0.8997 - auc: 0.9268 - balanced_accuracy_metric: 0.8956 - f1_score: 0.9013 - loss: 0.5583 - precision: 0.9152 - recall: 0.8636
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 305ms/step - accuracy: 0.8994 - auc: 0.9270 - balanced_accuracy_metric: 0.8946 - f1_score: 0.9010 - loss: 0.5572 - precision: 0.9150 - recall: 0.8633 - val_accuracy: 0.7990 - val_auc: 0.9577 - val_balanced_accuracy_metric: 0.4914 - val_f1_score: 0.7331 - val_loss: 0.7330 - val_precision: 0.9326 - val_recall: 0.7943 - learning_rate: 0.0010
# Epoch 8/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step - accuracy: 0.8759 - auc: 0.9294 - balanced_accuracy_metric: 0.8728 - f1_score: 0.8804 - loss: 0.5793 - precision: 0.8978 - recall: 0.8405
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 253ms/step - accuracy: 0.8758 - auc: 0.9299 - balanced_accuracy_metric: 0.8722 - f1_score: 0.8804 - loss: 0.5770 - precision: 0.8978 - recall: 0.8403 - val_accuracy: 0.9330 - val_auc: 0.9620 - val_balanced_accuracy_metric: 0.5888 - val_f1_score: 0.9357 - val_loss: 0.5844 - val_precision: 0.9369 - val_recall: 0.9234 - learning_rate: 0.0010
# Epoch 9/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 285ms/step - accuracy: 0.8907 - auc: 0.9256 - balanced_accuracy_metric: 0.8648 - f1_score: 0.8931 - loss: 0.5735 - precision: 0.8993 - recall: 0.8682 - val_accuracy: 0.9330 - val_auc: 0.9653 - val_balanced_accuracy_metric: 0.5827 - val_f1_score: 0.9352 - val_loss: 0.4795 - val_precision: 0.9369 - val_recall: 0.9234 - learning_rate: 0.0010
# Epoch 10/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.8820 - auc: 0.9358 - balanced_accuracy_metric: 0.8762 - f1_score: 0.8857 - loss: 0.5222 - precision: 0.8974 - recall: 0.8665 - val_accuracy: 0.9234 - val_auc: 0.9631 - val_balanced_accuracy_metric: 0.5855 - val_f1_score: 0.9274 - val_loss: 0.5091 - val_precision: 0.9320 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 11/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 257ms/step - accuracy: 0.9037 - auc: 0.9366 - balanced_accuracy_metric: 0.8983 - f1_score: 0.9068 - loss: 0.5098 - precision: 0.9074 - recall: 0.8803 - val_accuracy: 0.9234 - val_auc: 0.9675 - val_balanced_accuracy_metric: 0.5855 - val_f1_score: 0.9274 - val_loss: 0.4952 - val_precision: 0.9320 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 12/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step - accuracy: 0.9100 - auc: 0.9381 - balanced_accuracy_metric: 0.9003 - f1_score: 0.9122 - loss: 0.4933 - precision: 0.9167 - recall: 0.8874
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9098 - auc: 0.9381 - balanced_accuracy_metric: 0.8995 - f1_score: 0.9120 - loss: 0.4925 - precision: 0.9165 - recall: 0.8870 - val_accuracy: 0.9378 - val_auc: 0.9652 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.4804 - val_precision: 0.9378 - val_recall: 0.9378 - learning_rate: 0.0010
# Epoch 13/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 258ms/step - accuracy: 0.8985 - auc: 0.9340 - balanced_accuracy_metric: 0.8701 - f1_score: 0.9006 - loss: 0.5058 - precision: 0.9168 - recall: 0.8821 - val_accuracy: 0.7943 - val_auc: 0.9526 - val_balanced_accuracy_metric: 0.4958 - val_f1_score: 0.7292 - val_loss: 0.5809 - val_precision: 0.8000 - val_recall: 0.7847 - learning_rate: 0.0010
# Epoch 14/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 304ms/step - accuracy: 0.8959 - auc: 0.9524 - balanced_accuracy_metric: 0.9011 - f1_score: 0.8999 - loss: 0.4524 - precision: 0.9039 - recall: 0.8760 - val_accuracy: 0.9234 - val_auc: 0.9680 - val_balanced_accuracy_metric: 0.5855 - val_f1_score: 0.9274 - val_loss: 0.4488 - val_precision: 0.9320 - val_recall: 0.9187 - learning_rate: 0.0010
# Epoch 15/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.8999 - auc: 0.9360 - balanced_accuracy_metric: 0.8703 - f1_score: 0.9019 - loss: 0.5154 - precision: 0.9086 - recall: 0.8883 - val_accuracy: 0.9330 - val_auc: 0.9699 - val_balanced_accuracy_metric: 0.5888 - val_f1_score: 0.9357 - val_loss: 0.4081 - val_precision: 0.9330 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 255ms/step - accuracy: 0.9055 - auc: 0.9440 - balanced_accuracy_metric: 0.8978 - f1_score: 0.9078 - loss: 0.4590 - precision: 0.9136 - recall: 0.8945 - val_accuracy: 0.9378 - val_auc: 0.9658 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.3987 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.9059 - auc: 0.9434 - balanced_accuracy_metric: 0.8953 - f1_score: 0.9077 - loss: 0.4719 - precision: 0.9125 - recall: 0.8907 - val_accuracy: 0.9330 - val_auc: 0.9662 - val_balanced_accuracy_metric: 0.5888 - val_f1_score: 0.9357 - val_loss: 0.3968 - val_precision: 0.9330 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.8999 - auc: 0.9501 - balanced_accuracy_metric: 0.8892 - f1_score: 0.9026 - loss: 0.4413 - precision: 0.9148 - recall: 0.8913 - val_accuracy: 0.9378 - val_auc: 0.9610 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.4029 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9078 - auc: 0.9440 - balanced_accuracy_metric: 0.8907 - f1_score: 0.9099 - loss: 0.4611 - precision: 0.9091 - recall: 0.8913 - val_accuracy: 0.9378 - val_auc: 0.9639 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.3706 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.9068 - auc: 0.9463 - balanced_accuracy_metric: 0.8826 - f1_score: 0.9082 - loss: 0.4464 - precision: 0.9187 - recall: 0.9000 - val_accuracy: 0.9330 - val_auc: 0.9651 - val_balanced_accuracy_metric: 0.5888 - val_f1_score: 0.9357 - val_loss: 0.3426 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 304ms/step - accuracy: 0.9105 - auc: 0.9426 - balanced_accuracy_metric: 0.8896 - f1_score: 0.9113 - loss: 0.4593 - precision: 0.9168 - recall: 0.8902 - val_accuracy: 0.9330 - val_auc: 0.9650 - val_balanced_accuracy_metric: 0.5888 - val_f1_score: 0.9357 - val_loss: 0.3630 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 0.0010
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.9244 - auc: 0.9511 - balanced_accuracy_metric: 0.9121 - f1_score: 0.9252 - loss: 0.4016 - precision: 0.9267 - recall: 0.9128
# Epoch 22: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9242 - auc: 0.9511 - balanced_accuracy_metric: 0.9113 - f1_score: 0.9250 - loss: 0.4010 - precision: 0.9266 - recall: 0.9124 - val_accuracy: 0.9378 - val_auc: 0.9631 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.3367 - val_precision: 0.9423 - val_recall: 0.9378 - learning_rate: 0.0010
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 249ms/step - accuracy: 0.9101 - auc: 0.9527 - balanced_accuracy_metric: 0.8740 - f1_score: 0.9111 - loss: 0.4397 - precision: 0.9160 - recall: 0.9020 - val_accuracy: 0.9378 - val_auc: 0.9648 - val_balanced_accuracy_metric: 0.5906 - val_f1_score: 0.9400 - val_loss: 0.3359 - val_precision: 0.9375 - val_recall: 0.9330 - learning_rate: 5.0000e-04
# Epoch 24/300
# ...
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - accuracy: 0.8899 - auc: 0.9488 - balanced_accuracy_metric: 0.8930 - f1_score: 0.8941 - loss: 0.4379 - precision: 0.9012 - recall: 0.8640 - val_accuracy: 0.9183 - val_auc: 0.9501 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.5244 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 0.0010
# Epoch 16/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 252ms/step - accuracy: 0.8914 - auc: 0.9355 - balanced_accuracy_metric: 0.8862 - f1_score: 0.8955 - loss: 0.4461 - precision: 0.9000 - recall: 0.8643 - val_accuracy: 0.9183 - val_auc: 0.9479 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4948 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 0.0010
# Epoch 17/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 254ms/step - accuracy: 0.8453 - auc: 0.9314 - balanced_accuracy_metric: 0.8759 - f1_score: 0.8550 - loss: 0.4903 - precision: 0.8540 - recall: 0.8124 - val_accuracy: 0.9135 - val_auc: 0.9468 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4790 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 18/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.8497 - auc: 0.9446 - balanced_accuracy_metric: 0.8807 - f1_score: 0.8627 - loss: 0.4656 - precision: 0.8652 - recall: 0.8110 - val_accuracy: 0.9087 - val_auc: 0.9519 - val_balanced_accuracy_metric: 0.5155 - val_f1_score: 0.9094 - val_loss: 0.4335 - val_precision: 0.9130 - val_recall: 0.9087 - learning_rate: 0.0010
# Epoch 19/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 308ms/step - accuracy: 0.9133 - auc: 0.9469 - balanced_accuracy_metric: 0.9032 - f1_score: 0.9162 - loss: 0.4205 - precision: 0.9200 - recall: 0.8875 - val_accuracy: 0.9087 - val_auc: 0.9441 - val_balanced_accuracy_metric: 0.5155 - val_f1_score: 0.9094 - val_loss: 0.4194 - val_precision: 0.9130 - val_recall: 0.9087 - learning_rate: 0.0010
# Epoch 20/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - accuracy: 0.9160 - auc: 0.9460 - balanced_accuracy_metric: 0.9080 - f1_score: 0.9188 - loss: 0.3989 - precision: 0.9232 - recall: 0.9036 - val_accuracy: 0.9087 - val_auc: 0.9515 - val_balanced_accuracy_metric: 0.5155 - val_f1_score: 0.9094 - val_loss: 0.4340 - val_precision: 0.9130 - val_recall: 0.9087 - learning_rate: 0.0010
# Epoch 21/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9137 - auc: 0.9492 - balanced_accuracy_metric: 0.9035 - f1_score: 0.9156 - loss: 0.3838 - precision: 0.9190 - recall: 0.9089
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 317ms/step - accuracy: 0.9134 - auc: 0.9494 - balanced_accuracy_metric: 0.9030 - f1_score: 0.9153 - loss: 0.3837 - precision: 0.9189 - recall: 0.9085 - val_accuracy: 0.9183 - val_auc: 0.9469 - val_balanced_accuracy_metric: 0.5943 - val_f1_score: 0.9211 - val_loss: 0.4503 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 0.0010
# Epoch 22/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 282ms/step - accuracy: 0.8823 - auc: 0.9453 - balanced_accuracy_metric: 0.8911 - f1_score: 0.8891 - loss: 0.4044 - precision: 0.8847 - recall: 0.8679 - val_accuracy: 0.9135 - val_auc: 0.9596 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4851 - val_precision: 0.9179 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 23/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 267ms/step - accuracy: 0.9124 - auc: 0.9524 - balanced_accuracy_metric: 0.9115 - f1_score: 0.9145 - loss: 0.3680 - precision: 0.9241 - recall: 0.9011 - val_accuracy: 0.9183 - val_auc: 0.9568 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4563 - val_precision: 0.9223 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 24/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.9201 - auc: 0.9450 - balanced_accuracy_metric: 0.9122 - f1_score: 0.9214 - loss: 0.3819 - precision: 0.9244 - recall: 0.9105
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 312ms/step - accuracy: 0.9198 - auc: 0.9451 - balanced_accuracy_metric: 0.9118 - f1_score: 0.9211 - loss: 0.3820 - precision: 0.9242 - recall: 0.9102 - val_accuracy: 0.9231 - val_auc: 0.9459 - val_balanced_accuracy_metric: 0.5959 - val_f1_score: 0.9246 - val_loss: 0.4259 - val_precision: 0.9275 - val_recall: 0.9231 - learning_rate: 0.0010
# Epoch 25/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 291ms/step - accuracy: 0.8884 - auc: 0.9514 - balanced_accuracy_metric: 0.8931 - f1_score: 0.8950 - loss: 0.3965 - precision: 0.8903 - recall: 0.8756 - val_accuracy: 0.9135 - val_auc: 0.9554 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4017 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 26/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9179 - auc: 0.9554 - balanced_accuracy_metric: 0.9136 - f1_score: 0.9207 - loss: 0.3646 - precision: 0.9239 - recall: 0.9018 - val_accuracy: 0.9087 - val_auc: 0.9405 - val_balanced_accuracy_metric: 0.5155 - val_f1_score: 0.9094 - val_loss: 0.4022 - val_precision: 0.9130 - val_recall: 0.9087 - learning_rate: 0.0010
# Epoch 27/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 315ms/step - accuracy: 0.8951 - auc: 0.9495 - balanced_accuracy_metric: 0.9030 - f1_score: 0.9003 - loss: 0.3841 - precision: 0.9062 - recall: 0.8831 - val_accuracy: 0.9135 - val_auc: 0.9620 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4119 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 28/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 9s 256ms/step - accuracy: 0.9090 - auc: 0.9520 - balanced_accuracy_metric: 0.9045 - f1_score: 0.9129 - loss: 0.3740 - precision: 0.9165 - recall: 0.9005 - val_accuracy: 0.9135 - val_auc: 0.9593 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4344 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 29/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9193 - auc: 0.9490 - balanced_accuracy_metric: 0.9108 - f1_score: 0.9223 - loss: 0.3749 - precision: 0.9211 - recall: 0.9067 - val_accuracy: 0.9135 - val_auc: 0.9476 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4332 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 30/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 307ms/step - accuracy: 0.9089 - auc: 0.9504 - balanced_accuracy_metric: 0.9057 - f1_score: 0.9135 - loss: 0.3707 - precision: 0.9142 - recall: 0.9056 - val_accuracy: 0.9135 - val_auc: 0.9346 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.5190 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 31/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 252ms/step - accuracy: 0.9124 - auc: 0.9643 - balanced_accuracy_metric: 0.9095 - f1_score: 0.9158 - loss: 0.3387 - precision: 0.9148 - recall: 0.9038 - val_accuracy: 0.7885 - val_auc: 0.9234 - val_balanced_accuracy_metric: 0.4679 - val_f1_score: 0.7226 - val_loss: 0.6357 - val_precision: 0.7885 - val_recall: 0.7885 - learning_rate: 0.0010
# Epoch 32/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 307ms/step - accuracy: 0.9132 - auc: 0.9484 - balanced_accuracy_metric: 0.9138 - f1_score: 0.9175 - loss: 0.3765 - precision: 0.9166 - recall: 0.9018 - val_accuracy: 0.9135 - val_auc: 0.9479 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4503 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 0.0010
# Epoch 33/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.9169 - auc: 0.9615 - balanced_accuracy_metric: 0.9082 - f1_score: 0.9199 - loss: 0.3216 - precision: 0.9198 - recall: 0.9074 - val_accuracy: 0.9183 - val_auc: 0.9613 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4339 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 0.0010
# Epoch 34/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step - accuracy: 0.9193 - auc: 0.9626 - balanced_accuracy_metric: 0.9151 - f1_score: 0.9218 - loss: 0.3299 - precision: 0.9190 - recall: 0.9030
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 273ms/step - accuracy: 0.9193 - auc: 0.9627 - balanced_accuracy_metric: 0.9152 - f1_score: 0.9218 - loss: 0.3302 - precision: 0.9191 - recall: 0.9030 - val_accuracy: 0.9231 - val_auc: 0.9600 - val_balanced_accuracy_metric: 0.5869 - val_f1_score: 0.9242 - val_loss: 0.3907 - val_precision: 0.9227 - val_recall: 0.9183 - learning_rate: 0.0010
# Epoch 35/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 309ms/step - accuracy: 0.8928 - auc: 0.9556 - balanced_accuracy_metric: 0.9028 - f1_score: 0.8980 - loss: 0.3661 - precision: 0.9042 - recall: 0.8786 - val_accuracy: 0.9135 - val_auc: 0.9522 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4230 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 5.0000e-04
# Epoch 36/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 262ms/step - accuracy: 0.9274 - auc: 0.9620 - balanced_accuracy_metric: 0.9162 - f1_score: 0.9288 - loss: 0.3089 - precision: 0.9378 - recall: 0.9244 - val_accuracy: 0.9183 - val_auc: 0.9573 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4399 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Epoch 37/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 258ms/step - accuracy: 0.9243 - auc: 0.9592 - balanced_accuracy_metric: 0.9100 - f1_score: 0.9264 - loss: 0.3243 - precision: 0.9296 - recall: 0.9088 - val_accuracy: 0.9183 - val_auc: 0.9517 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4057 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Epoch 38/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 253ms/step - accuracy: 0.9155 - auc: 0.9748 - balanced_accuracy_metric: 0.9156 - f1_score: 0.9185 - loss: 0.2966 - precision: 0.9295 - recall: 0.9117 - val_accuracy: 0.9135 - val_auc: 0.9441 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4041 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 5.0000e-04
# Epoch 39/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 0.9175 - auc: 0.9660 - balanced_accuracy_metric: 0.9137 - f1_score: 0.9202 - loss: 0.3114 - precision: 0.9250 - recall: 0.9146 - val_accuracy: 0.9135 - val_auc: 0.9540 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4153 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 5.0000e-04
# Epoch 40/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 260ms/step - accuracy: 0.9253 - auc: 0.9663 - balanced_accuracy_metric: 0.9156 - f1_score: 0.9271 - loss: 0.3109 - precision: 0.9311 - recall: 0.9177 - val_accuracy: 0.9183 - val_auc: 0.9514 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4005 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Epoch 41/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 309ms/step - accuracy: 0.9159 - auc: 0.9698 - balanced_accuracy_metric: 0.9119 - f1_score: 0.9184 - loss: 0.3048 - precision: 0.9185 - recall: 0.9072 - val_accuracy: 0.9183 - val_auc: 0.9532 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.3925 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Epoch 42/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 308ms/step - accuracy: 0.9236 - auc: 0.9681 - balanced_accuracy_metric: 0.9143 - f1_score: 0.9252 - loss: 0.3031 - precision: 0.9289 - recall: 0.9161 - val_accuracy: 0.9135 - val_auc: 0.9510 - val_balanced_accuracy_metric: 0.5631 - val_f1_score: 0.9144 - val_loss: 0.4038 - val_precision: 0.9135 - val_recall: 0.9135 - learning_rate: 5.0000e-04
# Epoch 43/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 7s 255ms/step - accuracy: 0.9332 - auc: 0.9565 - balanced_accuracy_metric: 0.9175 - f1_score: 0.9339 - loss: 0.3175 - precision: 0.9360 - recall: 0.9270 - val_accuracy: 0.9183 - val_auc: 0.9536 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.4014 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Epoch 44/300
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - accuracy: 0.9262 - auc: 0.9668 - balanced_accuracy_metric: 0.9208 - f1_score: 0.9278 - loss: 0.2916 - precision: 0.9286 - recall: 0.9168
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.9260 - auc: 0.9669 - balanced_accuracy_metric: 0.9205 - f1_score: 0.9276 - loss: 0.2918 - precision: 0.9284 - recall: 0.9165 - val_accuracy: 0.9183 - val_auc: 0.9534 - val_balanced_accuracy_metric: 0.5750 - val_f1_score: 0.9193 - val_loss: 0.3955 - val_precision: 0.9183 - val_recall: 0.9183 - learning_rate: 5.0000e-04
# Could not load best model for fold 5, using last epoch's model
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step
#
# Fold 5 Results:
# Balanced Accuracy: 0.9043
# Accuracy: 0.9231
# Cohen's Kappa: 0.8258
# Matthews Correlation: 0.8282
# ROC AUC (OvR): 0.9458
# ROC AUC (OvO): 0.9585
#
# Classification Report:
#                     precision    recall  f1-score   support
#
# Disability Benefit       0.73      0.96      0.83        25
#           Employed       0.95      0.94      0.95       151
#    Employed (Died)       1.00      0.81      0.90        32
#
#           accuracy                           0.92       208
#          macro avg       0.89      0.90      0.89       208
#       weighted avg       0.93      0.92      0.92       208
#
#
# === Final LSTM Evaluation ===
#
# === Average Performance Across All Folds ===
# Balanced Accuracy: 0.9118 ± 0.0111
# Accuracy: 0.9368 ± 0.0072
# Cohen's Kappa: 0.8570 ± 0.0162
# Matthews Correlation: 0.8586 ± 0.0159
# ROC AUC (OvR): 0.9527 ± 0.0089
# ROC AUC (OvO): 0.9619 ± 0.0073
#
# === Class-wise Average Performance ===
#
# Class 0:
#   Precision: 0.7835 ± 0.0439
#   Recall: 0.9382 ± 0.0185
#   F1-score: 0.8527 ± 0.0191
#   Accuracy: 0.9382 ± 0.0185
#
# Class 1:
#   Precision: 0.9601 ± 0.0070
#   Recall: 0.9575 ± 0.0136
#   F1-score: 0.9588 ± 0.0066
#   Accuracy: 0.9575 ± 0.0136
#
# Class 2:
#   Precision: 0.9862 ± 0.0276
#   Recall: 0.8396 ± 0.0353
#   F1-score: 0.9064 ± 0.0234
#   Accuracy: 0.8396 ± 0.0353
#
# === Comprehensive Evaluation on All Predictions ===
#
# Classification Report:
#                     precision    recall  f1-score   support
#
# Disability Benefit       0.78      0.94      0.85       129
#           Employed       0.96      0.96      0.96       753
#    Employed (Died)       0.99      0.84      0.91       162
#
#           accuracy                           0.94      1044
#          macro avg       0.91      0.91      0.91      1044
#       weighted avg       0.94      0.94      0.94      1044
#
#
# Confusion Matrix:
# [[121   7   1]
#  [ 31 721   1]
#  [  3  23 136]]
# ROC AUC Score (OvR): 0.9468
# ROC AUC Score (OvO): 0.9564
#
# === FINAL REPORT ===
# Model: LSTM with 3 layers (128, 64 and 32 units)
# Cross-validation: 5-fold stratified
#
# Average Performance Across Folds:
# - Balanced Accuracy: 0.9118 ± 0.0111
# - Accuracy: 0.9368 ± 0.0072
# - Cohen's Kappa: 0.8570 ± 0.0162
# - Matthews Correlation: 0.8586 ± 0.0159
# - ROC AUC (OvR): 0.9527 ± 0.0089
# - ROC AUC (OvO): 0.9619 ± 0.0073
#
# Class 0 (Disability Benefit):
# - Precision: 0.7835 ± 0.0439
# - Recall: 0.9382 ± 0.0185
# - F1-score: 0.8527 ± 0.0191
# - Accuracy: 0.9382 ± 0.0185
#
# Class 1 (Employed):
# - Precision: 0.9601 ± 0.0070
# - Recall: 0.9575 ± 0.0136
# - F1-score: 0.9588 ± 0.0066
# - Accuracy: 0.9575 ± 0.0136
#
# Class 2 (Employed (Died)):
# - Precision: 0.9862 ± 0.0276
# - Recall: 0.8396 ± 0.0353
# - F1-score: 0.9064 ± 0.0234
# - Accuracy: 0.8396 ± 0.0353
#
# Confusion Matrix (All Predictions):
# [[121   7   1]
#  [ 31 721   1]
#  [  3  23 136]]

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (confusion_matrix, classification_report,
                             roc_auc_score, precision_recall_curve,
                             average_precision_score)
import matplotlib.pyplot as plt

import os
import pandas as pd
import numpy as np
from datetime import datetime
from sklearn.metrics import precision_recall_curve, average_precision_score, confusion_matrix, classification_report, roc_auc_score

# --- First, train and save the best model ---

# [Previous code remains the same until after model training]

# After cross-validation training, train a final model on all data
print("\n=== Training Final Model on All Data ===")
final_model = build_lstm_model((X_seq.shape[1], X_seq.shape[2]), y.shape[1])

# Callbacks for final training
final_callbacks = [
    EarlyStopping(
        monitor='loss',
        patience=15,
        restore_best_weights=True,
        min_delta=0.001
    ),
    ReduceLROnPlateau(
        monitor='loss',
        factor=0.5,
        patience=7,
        min_lr=1e-6,
        verbose=1
    ),
    ModelCheckpoint(
        filepath='best_final_model.h5',
        monitor='accuracy',
        save_best_only=True,
        mode='max'
    )
]

# Train final model
history = final_model.fit(
    X_seq, y,
    epochs=300,
    batch_size=64,
    callbacks=final_callbacks,
    verbose=1,
    shuffle=True
)

# Load the best final model
try:
    final_model = load_model('best_final_model.h5', custom_objects=custom_objects)
    print("Successfully loaded best final model")
except Exception as e:
    print(f"Error loading final model: {e}")
    print("Using last epoch's model instead")


def assess_patient_risk_lstm_only(patient_data, model, temporal_features, max_seq_length, threshold=0.7):
    """
    Risk assessment using only LSTM model predictions
    Args:
        patient_data: DataFrame for one patient's visits
        model: Trained LSTM model
        temporal_features: List of temporal pattern features
        max_seq_length: Maximum sequence length model expects
        threshold: Risk threshold for flagging
    Returns:
        DataFrame with risk assessments for each visit
    """
    risks = []
    patient_data = patient_data.sort_values('ASSDT')

    for i in range(1, len(patient_data)+1):
        current_visit = patient_data.iloc[:i]
        current_row = current_visit.iloc[-1]

        # Prepare sequence data
        seq_len = len(current_visit)
        seq_data = np.zeros((1, max_seq_length, len(temporal_features)))
        seq_data[0, :seq_len, :] = current_visit[temporal_features].values

        # Get prediction
        pred_proba = model.predict(seq_data, verbose=0)[0][0]

        risks.append({
            'visit_date': current_row['ASSDT'],
            'visit_number': i,
            'risk_score': pred_proba,
            'flagged': pred_proba >= threshold
        })

    return pd.DataFrame(risks)

def evaluate_patients(data, model, temporal_features, max_seq_length):
    """
    Evaluate all patients using LSTM-only approach
    Args:
        data: Full dataset with all patients
        model: Trained LSTM model
        temporal_features: List of temporal features
        max_seq_length: Maximum sequence length
    Returns:
        results_df: DataFrame with evaluation results
        timing_data: List of detection times
    """
    results = []
    timing_analysis = []

    for ptno, patient_data in data.groupby('PTNO'):
        patient_data = patient_data.sort_values('ASSDT')
        final_outcome = patient_data['end_state_encoded'].iloc[-1]

        # Get risk assessment
        risk_df = assess_patient_risk_lstm_only(
            patient_data,
            model,
            temporal_features,
            max_seq_length
        )

        # Record first time flagged (if any)
        first_flag = risk_df[risk_df['flagged']]['visit_date'].min()

        # For patients who became disabled
        if final_outcome == 0:  # Disability
            if pd.notna(first_flag):
                months_before = (patient_data['ASSDT'].iloc[-1] - first_flag).days / 30
                timing_analysis.append(months_before)
            else:
                disability_date = patient_data['ASSDT'].iloc[-1]
                last_visit_date = patient_data['ASSDT'].iloc[-2] if len(patient_data) > 1 else disability_date
                months_after = (first_flag - disability_date).days / 30 if pd.notna(first_flag) else (disability_date - last_visit_date).days / 30
                timing_analysis.append(-months_after)

        # Store results
        results.append({
            'PTNO': ptno,
            'final_outcome': final_outcome,
            'ever_flagged': any(risk_df['flagged']),
            'first_flag_date': first_flag,
            'max_risk_score': risk_df['risk_score'].max(),
            'final_risk_score': risk_df['risk_score'].iloc[-1],
            'num_visits': len(patient_data)
        })

    return pd.DataFrame(results)



# Example Usage
if __name__ == "__main__":
    # Assuming you have these defined:
    # data = your patient data
    # final_model = your trained LSTM model
    # selected_features = your temporal features
    # X_seq = your sequence data (for getting max_seq_length)

    max_seq_length = X_seq.shape[1]  # Get sequence length from training data

    results_df = evaluate_patients(
        data,
        final_model,
        temporal_features=selected_features,
        max_seq_length=max_seq_length
    )
# Out:
# === Training Final Model on All Data ===
# Epoch 1/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.3639 - auc: 0.5827 - balanced_accuracy_metric: 0.4182 - f1_score: 0.4496 - loss: 1.8176 - precision: 0.3479 - recall: 0.2653
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 16s 334ms/step - accuracy: 0.3675 - auc: 0.5878 - balanced_accuracy_metric: 0.4214 - f1_score: 0.4534 - loss: 1.8076 - precision: 0.3525 - recall: 0.2682 - learning_rate: 0.0010
# Epoch 2/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.5478 - auc: 0.7396 - balanced_accuracy_metric: 0.5619 - f1_score: 0.6339 - loss: 1.4066 - precision: 0.5821 - recall: 0.4042
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.5492 - auc: 0.7410 - balanced_accuracy_metric: 0.5633 - f1_score: 0.6350 - loss: 1.4016 - precision: 0.5845 - recall: 0.4052 - learning_rate: 0.0010
# Epoch 3/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.6941 - auc: 0.7958 - balanced_accuracy_metric: 0.6018 - f1_score: 0.7536 - loss: 1.1559 - precision: 0.7588 - recall: 0.5053
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.6954 - auc: 0.7952 - balanced_accuracy_metric: 0.6008 - f1_score: 0.7547 - loss: 1.1519 - precision: 0.7600 - recall: 0.5068 - learning_rate: 0.0010
# Epoch 4/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step - accuracy: 0.8000 - auc: 0.8173 - balanced_accuracy_metric: 0.6365 - f1_score: 0.8304 - loss: 1.0502 - precision: 0.8578 - recall: 0.6141
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 402ms/step - accuracy: 0.8004 - auc: 0.8163 - balanced_accuracy_metric: 0.6356 - f1_score: 0.8307 - loss: 1.0450 - precision: 0.8579 - recall: 0.6156 - learning_rate: 0.0010
# Epoch 5/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.8281 - auc: 0.7836 - balanced_accuracy_metric: 0.5591 - f1_score: 0.8480 - loss: 0.9245 - precision: 0.8638 - recall: 0.7174
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 332ms/step - accuracy: 0.8286 - auc: 0.7845 - balanced_accuracy_metric: 0.5606 - f1_score: 0.8484 - loss: 0.9200 - precision: 0.8649 - recall: 0.7188 - learning_rate: 0.0010
# Epoch 6/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.8723 - auc: 0.8392 - balanced_accuracy_metric: 0.6619 - f1_score: 0.8811 - loss: 0.8200 - precision: 0.9139 - recall: 0.8271
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 435ms/step - accuracy: 0.8728 - auc: 0.8380 - balanced_accuracy_metric: 0.6606 - f1_score: 0.8814 - loss: 0.8153 - precision: 0.9143 - recall: 0.8270 - learning_rate: 0.0010
# Epoch 7/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.8821 - auc: 0.8073 - balanced_accuracy_metric: 0.6056 - f1_score: 0.8832 - loss: 0.7603 - precision: 0.8991 - recall: 0.8413
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 333ms/step - accuracy: 0.8826 - auc: 0.8076 - balanced_accuracy_metric: 0.6058 - f1_score: 0.8836 - loss: 0.7544 - precision: 0.9000 - recall: 0.8422 - learning_rate: 0.0010
# Epoch 8/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step - accuracy: 0.8808 - auc: 0.7942 - balanced_accuracy_metric: 0.5755 - f1_score: 0.8787 - loss: 0.7364 - precision: 0.9059 - recall: 0.8431
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.8820 - auc: 0.7945 - balanced_accuracy_metric: 0.5767 - f1_score: 0.8796 - loss: 0.7294 - precision: 0.9069 - recall: 0.8446 - learning_rate: 0.0010
# Epoch 9/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.8971 - auc: 0.7928 - balanced_accuracy_metric: 0.5925 - f1_score: 0.8918 - loss: 0.6976 - precision: 0.9074 - recall: 0.8719
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.8977 - auc: 0.7929 - balanced_accuracy_metric: 0.5932 - f1_score: 0.8923 - loss: 0.6903 - precision: 0.9083 - recall: 0.8721 - learning_rate: 0.0010
# Epoch 10/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9002 - auc: 0.8647 - balanced_accuracy_metric: 0.5974 - f1_score: 0.8905 - loss: 0.6458 - precision: 0.9109 - recall: 0.8950 - learning_rate: 0.0010
# Epoch 11/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 405ms/step - accuracy: 0.9002 - auc: 0.8100 - balanced_accuracy_metric: 0.5862 - f1_score: 0.8917 - loss: 0.5852 - precision: 0.9086 - recall: 0.8926
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 412ms/step - accuracy: 0.9013 - auc: 0.8103 - balanced_accuracy_metric: 0.5882 - f1_score: 0.8928 - loss: 0.5799 - precision: 0.9098 - recall: 0.8936 - learning_rate: 0.0010
# Epoch 12/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9092 - auc: 0.7908 - balanced_accuracy_metric: 0.6066 - f1_score: 0.8989 - loss: 0.5389 - precision: 0.9116 - recall: 0.8998
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 432ms/step - accuracy: 0.9100 - auc: 0.7924 - balanced_accuracy_metric: 0.6072 - f1_score: 0.8996 - loss: 0.5343 - precision: 0.9125 - recall: 0.9005 - learning_rate: 0.0010
# Epoch 13/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.9064 - auc: 0.8530 - balanced_accuracy_metric: 0.5943 - f1_score: 0.8955 - loss: 0.5412 - precision: 0.9156 - recall: 0.8962 - learning_rate: 0.0010
# Epoch 14/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - accuracy: 0.9000 - auc: 0.8109 - balanced_accuracy_metric: 0.5776 - f1_score: 0.8878 - loss: 0.4937 - precision: 0.9023 - recall: 0.8957 - learning_rate: 0.0010
# Epoch 15/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 403ms/step - accuracy: 0.9079 - auc: 0.8301 - balanced_accuracy_metric: 0.5895 - f1_score: 0.8954 - loss: 0.4990 - precision: 0.9160 - recall: 0.8920 - learning_rate: 0.0010
# Epoch 16/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9103 - auc: 0.8393 - balanced_accuracy_metric: 0.6190 - f1_score: 0.9019 - loss: 0.4306 - precision: 0.9132 - recall: 0.8983 - learning_rate: 0.0010
# Epoch 17/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 426ms/step - accuracy: 0.9072 - auc: 0.8339 - balanced_accuracy_metric: 0.5866 - f1_score: 0.8948 - loss: 0.4160 - precision: 0.9161 - recall: 0.9023 - learning_rate: 0.0010
# Epoch 18/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - accuracy: 0.9166 - auc: 0.8578 - balanced_accuracy_metric: 0.6060 - f1_score: 0.9061 - loss: 0.3967 - precision: 0.9212 - recall: 0.9059
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 342ms/step - accuracy: 0.9174 - auc: 0.8576 - balanced_accuracy_metric: 0.6073 - f1_score: 0.9069 - loss: 0.3937 - precision: 0.9221 - recall: 0.9067 - learning_rate: 0.0010
# Epoch 19/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 395ms/step - accuracy: 0.9153 - auc: 0.8242 - balanced_accuracy_metric: 0.6004 - f1_score: 0.9023 - loss: 0.3895 - precision: 0.9191 - recall: 0.9145 - learning_rate: 0.0010
# Epoch 20/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.9150 - auc: 0.8229 - balanced_accuracy_metric: 0.5968 - f1_score: 0.9025 - loss: 0.3894 - precision: 0.9148 - recall: 0.9090
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 329ms/step - accuracy: 0.9160 - auc: 0.8242 - balanced_accuracy_metric: 0.5982 - f1_score: 0.9034 - loss: 0.3869 - precision: 0.9158 - recall: 0.9099 - learning_rate: 0.0010
# Epoch 21/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - accuracy: 0.9108 - auc: 0.8593 - balanced_accuracy_metric: 0.5930 - f1_score: 0.8976 - loss: 0.3872 - precision: 0.9106 - recall: 0.9086 - learning_rate: 0.0010
# Epoch 22/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.9089 - auc: 0.8279 - balanced_accuracy_metric: 0.5842 - f1_score: 0.8956 - loss: 0.3744 - precision: 0.9167 - recall: 0.9077 - learning_rate: 0.0010
# Epoch 23/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 382ms/step - accuracy: 0.9208 - auc: 0.8743 - balanced_accuracy_metric: 0.6081 - f1_score: 0.9076 - loss: 0.3572 - precision: 0.9232 - recall: 0.9166 - learning_rate: 0.0010
# Epoch 24/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 349ms/step - accuracy: 0.9153 - auc: 0.8777 - balanced_accuracy_metric: 0.6053 - f1_score: 0.9033 - loss: 0.3425 - precision: 0.9175 - recall: 0.9135 - learning_rate: 0.0010
# Epoch 25/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 429ms/step - accuracy: 0.9186 - auc: 0.8506 - balanced_accuracy_metric: 0.6021 - f1_score: 0.9049 - loss: 0.3562 - precision: 0.9217 - recall: 0.9176 - learning_rate: 0.0010
# Epoch 26/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.9036 - auc: 0.8636 - balanced_accuracy_metric: 0.5755 - f1_score: 0.8910 - loss: 0.3500 - precision: 0.9124 - recall: 0.9013 - learning_rate: 0.0010
# Epoch 27/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.9126 - auc: 0.8870 - balanced_accuracy_metric: 0.5840 - f1_score: 0.8989 - loss: 0.3529 - precision: 0.9184 - recall: 0.9101 - learning_rate: 0.0010
# Epoch 28/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.9265 - auc: 0.8552 - balanced_accuracy_metric: 0.6073 - f1_score: 0.9127 - loss: 0.3251 - precision: 0.9295 - recall: 0.9206
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 327ms/step - accuracy: 0.9270 - auc: 0.8557 - balanced_accuracy_metric: 0.6078 - f1_score: 0.9131 - loss: 0.3234 - precision: 0.9301 - recall: 0.9211 - learning_rate: 0.0010
# Epoch 29/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.9126 - auc: 0.8728 - balanced_accuracy_metric: 0.5991 - f1_score: 0.9012 - loss: 0.3185 - precision: 0.9193 - recall: 0.9122 - learning_rate: 0.0010
# Epoch 30/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.9211 - auc: 0.8725 - balanced_accuracy_metric: 0.6064 - f1_score: 0.9080 - loss: 0.3187 - precision: 0.9214 - recall: 0.9179
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9219 - auc: 0.8721 - balanced_accuracy_metric: 0.6074 - f1_score: 0.9088 - loss: 0.3168 - precision: 0.9223 - recall: 0.9188 - learning_rate: 0.0010
# Epoch 31/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.9028 - auc: 0.9023 - balanced_accuracy_metric: 0.5613 - f1_score: 0.8881 - loss: 0.3319 - precision: 0.9113 - recall: 0.9028 - learning_rate: 0.0010
# Epoch 32/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9178 - auc: 0.8997 - balanced_accuracy_metric: 0.5860 - f1_score: 0.9035 - loss: 0.3126 - precision: 0.9200 - recall: 0.9167 - learning_rate: 0.0010
# Epoch 33/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9299 - auc: 0.8753 - balanced_accuracy_metric: 0.6143 - f1_score: 0.9186 - loss: 0.2890 - precision: 0.9343 - recall: 0.9294 - learning_rate: 0.0010
# Epoch 34/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 414ms/step - accuracy: 0.9213 - auc: 0.8843 - balanced_accuracy_metric: 0.6085 - f1_score: 0.9095 - loss: 0.2940 - precision: 0.9231 - recall: 0.9201 - learning_rate: 0.0010
# Epoch 35/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9196 - auc: 0.9039 - balanced_accuracy_metric: 0.6073 - f1_score: 0.9073 - loss: 0.3124 - precision: 0.9215 - recall: 0.9193 - learning_rate: 0.0010
# Epoch 36/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step - accuracy: 0.9308 - auc: 0.8808 - balanced_accuracy_metric: 0.6022 - f1_score: 0.9167 - loss: 0.2890 - precision: 0.9347 - recall: 0.9239
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.9315 - auc: 0.8815 - balanced_accuracy_metric: 0.6039 - f1_score: 0.9175 - loss: 0.2868 - precision: 0.9354 - recall: 0.9248 - learning_rate: 0.0010
# Epoch 37/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9261 - auc: 0.9170 - balanced_accuracy_metric: 0.5988 - f1_score: 0.9128 - loss: 0.2709 - precision: 0.9310 - recall: 0.9239 - learning_rate: 0.0010
# Epoch 38/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 343ms/step - accuracy: 0.9285 - auc: 0.8931 - balanced_accuracy_metric: 0.6240 - f1_score: 0.9166 - loss: 0.2764 - precision: 0.9298 - recall: 0.9272 - learning_rate: 0.0010
# Epoch 39/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 381ms/step - accuracy: 0.9217 - auc: 0.9005 - balanced_accuracy_metric: 0.5959 - f1_score: 0.9094 - loss: 0.3007 - precision: 0.9244 - recall: 0.9195 - learning_rate: 0.0010
# Epoch 40/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 428ms/step - accuracy: 0.9093 - auc: 0.9173 - balanced_accuracy_metric: 0.5856 - f1_score: 0.8960 - loss: 0.3167 - precision: 0.9110 - recall: 0.9063 - learning_rate: 0.0010
# Epoch 41/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 326ms/step - accuracy: 0.9249 - auc: 0.9188 - balanced_accuracy_metric: 0.6012 - f1_score: 0.9123 - loss: 0.2746 - precision: 0.9269 - recall: 0.9213 - learning_rate: 0.0010
# Epoch 42/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 417ms/step - accuracy: 0.9094 - auc: 0.9192 - balanced_accuracy_metric: 0.5855 - f1_score: 0.8988 - loss: 0.3041 - precision: 0.9146 - recall: 0.9094 - learning_rate: 0.0010
# Epoch 43/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.9230 - auc: 0.9193 - balanced_accuracy_metric: 0.6168 - f1_score: 0.9118 - loss: 0.2717 - precision: 0.9263 - recall: 0.9167 - learning_rate: 0.0010
# Epoch 44/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - accuracy: 0.9217 - auc: 0.9152 - balanced_accuracy_metric: 0.6156 - f1_score: 0.9111 - loss: 0.2752 - precision: 0.9236 - recall: 0.9202 - learning_rate: 0.0010
# Epoch 45/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.9247 - auc: 0.9336 - balanced_accuracy_metric: 0.5873 - f1_score: 0.9109 - loss: 0.2516 - precision: 0.9278 - recall: 0.9242 - learning_rate: 0.0010
# Epoch 46/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9351 - auc: 0.9326 - balanced_accuracy_metric: 0.6314 - f1_score: 0.9237 - loss: 0.2536 - precision: 0.9351 - recall: 0.9351
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 369ms/step - accuracy: 0.9357 - auc: 0.9318 - balanced_accuracy_metric: 0.6324 - f1_score: 0.9243 - loss: 0.2522 - precision: 0.9357 - recall: 0.9357 - learning_rate: 0.0010
# Epoch 47/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 326ms/step - accuracy: 0.9268 - auc: 0.9280 - balanced_accuracy_metric: 0.6223 - f1_score: 0.9180 - loss: 0.2573 - precision: 0.9274 - recall: 0.9253 - learning_rate: 0.0010
# Epoch 48/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 421ms/step - accuracy: 0.9395 - auc: 0.9230 - balanced_accuracy_metric: 0.6486 - f1_score: 0.9303 - loss: 0.2421 - precision: 0.9404 - recall: 0.9395 - learning_rate: 0.0010
# Epoch 49/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9331 - auc: 0.9433 - balanced_accuracy_metric: 0.6116 - f1_score: 0.9208 - loss: 0.2340 - precision: 0.9344 - recall: 0.9331 - learning_rate: 0.0010
# Epoch 50/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 407ms/step - accuracy: 0.9458 - auc: 0.9522 - balanced_accuracy_metric: 0.6260 - f1_score: 0.9312 - loss: 0.2129 - precision: 0.9484 - recall: 0.9452
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 419ms/step - accuracy: 0.9461 - auc: 0.9516 - balanced_accuracy_metric: 0.6267 - f1_score: 0.9315 - loss: 0.2124 - precision: 0.9488 - recall: 0.9455 - learning_rate: 0.0010
# Epoch 51/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9462 - auc: 0.9148 - balanced_accuracy_metric: 0.6962 - f1_score: 0.9383 - loss: 0.2247 - precision: 0.9468 - recall: 0.9412
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 330ms/step - accuracy: 0.9467 - auc: 0.9159 - balanced_accuracy_metric: 0.6953 - f1_score: 0.9387 - loss: 0.2231 - precision: 0.9474 - recall: 0.9418 - learning_rate: 0.0010
# Epoch 52/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9467 - auc: 0.9506 - balanced_accuracy_metric: 0.6695 - f1_score: 0.9394 - loss: 0.2020 - precision: 0.9491 - recall: 0.9443 - learning_rate: 0.0010
# Epoch 53/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 425ms/step - accuracy: 0.9401 - auc: 0.9256 - balanced_accuracy_metric: 0.6427 - f1_score: 0.9299 - loss: 0.2518 - precision: 0.9401 - recall: 0.9393 - learning_rate: 0.0010
# Epoch 54/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9366 - auc: 0.9229 - balanced_accuracy_metric: 0.6367 - f1_score: 0.9272 - loss: 0.2466 - precision: 0.9370 - recall: 0.9366 - learning_rate: 0.0010
# Epoch 55/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.9353 - auc: 0.9379 - balanced_accuracy_metric: 0.6588 - f1_score: 0.9252 - loss: 0.2359 - precision: 0.9355 - recall: 0.9327 - learning_rate: 0.0010
# Epoch 56/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.9489 - auc: 0.8914 - balanced_accuracy_metric: 0.6410 - f1_score: 0.9366 - loss: 0.2299 - precision: 0.9487 - recall: 0.9444 - learning_rate: 0.0010
# Epoch 57/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 355ms/step - accuracy: 0.9332 - auc: 0.9560 - balanced_accuracy_metric: 0.6246 - f1_score: 0.9219 - loss: 0.2232 - precision: 0.9378 - recall: 0.9321 - learning_rate: 0.0010
# Epoch 58/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 374ms/step - accuracy: 0.9307 - auc: 0.9420 - balanced_accuracy_metric: 0.5977 - f1_score: 0.9160 - loss: 0.2192 - precision: 0.9304 - recall: 0.9266
# Epoch 58: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 377ms/step - accuracy: 0.9314 - auc: 0.9417 - balanced_accuracy_metric: 0.5992 - f1_score: 0.9167 - loss: 0.2184 - precision: 0.9311 - recall: 0.9274 - learning_rate: 0.0010
# Epoch 59/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9419 - auc: 0.9245 - balanced_accuracy_metric: 0.6468 - f1_score: 0.9314 - loss: 0.2288 - precision: 0.9438 - recall: 0.9405 - learning_rate: 5.0000e-04
# Epoch 60/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9531 - auc: 0.9113 - balanced_accuracy_metric: 0.7196 - f1_score: 0.9462 - loss: 0.2285 - precision: 0.9529 - recall: 0.9486
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.9534 - auc: 0.9125 - balanced_accuracy_metric: 0.7186 - f1_score: 0.9465 - loss: 0.2266 - precision: 0.9532 - recall: 0.9489 - learning_rate: 5.0000e-04
# Epoch 61/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 348ms/step - accuracy: 0.9531 - auc: 0.9657 - balanced_accuracy_metric: 0.6616 - f1_score: 0.9435 - loss: 0.1817 - precision: 0.9560 - recall: 0.9489 - learning_rate: 5.0000e-04
# Epoch 62/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 322ms/step - accuracy: 0.9533 - auc: 0.9290 - balanced_accuracy_metric: 0.6912 - f1_score: 0.9456 - loss: 0.1897 - precision: 0.9536 - recall: 0.9533 - learning_rate: 5.0000e-04
# Epoch 63/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.9437 - auc: 0.9522 - balanced_accuracy_metric: 0.6444 - f1_score: 0.9337 - loss: 0.1998 - precision: 0.9481 - recall: 0.9404 - learning_rate: 5.0000e-04
# Epoch 64/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 0.9474 - auc: 0.9480 - balanced_accuracy_metric: 0.6486 - f1_score: 0.9375 - loss: 0.2001 - precision: 0.9479 - recall: 0.9466 - learning_rate: 5.0000e-04
# Epoch 65/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 384ms/step - accuracy: 0.9510 - auc: 0.9265 - balanced_accuracy_metric: 0.6541 - f1_score: 0.9394 - loss: 0.1886 - precision: 0.9518 - recall: 0.9483 - learning_rate: 5.0000e-04
# Epoch 66/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 433ms/step - accuracy: 0.9511 - auc: 0.9498 - balanced_accuracy_metric: 0.6384 - f1_score: 0.9400 - loss: 0.1868 - precision: 0.9509 - recall: 0.9478 - learning_rate: 5.0000e-04
# Epoch 67/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 324ms/step - accuracy: 0.9521 - auc: 0.9503 - balanced_accuracy_metric: 0.7126 - f1_score: 0.9453 - loss: 0.1847 - precision: 0.9529 - recall: 0.9521 - learning_rate: 5.0000e-04
# Epoch 68/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 427ms/step - accuracy: 0.9564 - auc: 0.9313 - balanced_accuracy_metric: 0.7233 - f1_score: 0.9503 - loss: 0.1877 - precision: 0.9577 - recall: 0.9544 - learning_rate: 5.0000e-04
# Epoch 69/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9493 - auc: 0.9547 - balanced_accuracy_metric: 0.6747 - f1_score: 0.9404 - loss: 0.1858 - precision: 0.9493 - recall: 0.9488 - learning_rate: 5.0000e-04
# Epoch 70/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9668 - auc: 0.9555 - balanced_accuracy_metric: 0.7478 - f1_score: 0.9609 - loss: 0.1753 - precision: 0.9668 - recall: 0.9668
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 432ms/step - accuracy: 0.9669 - auc: 0.9552 - balanced_accuracy_metric: 0.7462 - f1_score: 0.9610 - loss: 0.1749 - precision: 0.9669 - recall: 0.9669 - learning_rate: 5.0000e-04
# Epoch 71/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 327ms/step - accuracy: 0.9537 - auc: 0.9589 - balanced_accuracy_metric: 0.6801 - f1_score: 0.9470 - loss: 0.1754 - precision: 0.9536 - recall: 0.9519 - learning_rate: 5.0000e-04
# Epoch 72/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 351ms/step - accuracy: 0.9547 - auc: 0.9615 - balanced_accuracy_metric: 0.7153 - f1_score: 0.9481 - loss: 0.1812 - precision: 0.9546 - recall: 0.9524 - learning_rate: 5.0000e-04
# Epoch 73/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 375ms/step - accuracy: 0.9475 - auc: 0.9549 - balanced_accuracy_metric: 0.6990 - f1_score: 0.9399 - loss: 0.1790 - precision: 0.9485 - recall: 0.9475 - learning_rate: 5.0000e-04
# Epoch 74/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 423ms/step - accuracy: 0.9510 - auc: 0.9627 - balanced_accuracy_metric: 0.7243 - f1_score: 0.9465 - loss: 0.1779 - precision: 0.9519 - recall: 0.9510 - learning_rate: 5.0000e-04
# Epoch 75/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9518 - auc: 0.9540 - balanced_accuracy_metric: 0.6514 - f1_score: 0.9416 - loss: 0.1819 - precision: 0.9561 - recall: 0.9496 - learning_rate: 5.0000e-04
# Epoch 76/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 357ms/step - accuracy: 0.9587 - auc: 0.9653 - balanced_accuracy_metric: 0.7107 - f1_score: 0.9529 - loss: 0.1653 - precision: 0.9596 - recall: 0.9554 - learning_rate: 5.0000e-04
# Epoch 77/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 371ms/step - accuracy: 0.9622 - auc: 0.9643 - balanced_accuracy_metric: 0.7366 - f1_score: 0.9544 - loss: 0.1649 - precision: 0.9622 - recall: 0.9613 - learning_rate: 5.0000e-04
# Epoch 78/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9483 - auc: 0.9478 - balanced_accuracy_metric: 0.6730 - f1_score: 0.9407 - loss: 0.1889 - precision: 0.9512 - recall: 0.9450 - learning_rate: 5.0000e-04
# Epoch 79/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.9546 - auc: 0.9594 - balanced_accuracy_metric: 0.7378 - f1_score: 0.9483 - loss: 0.1705 - precision: 0.9546 - recall: 0.9537 - learning_rate: 5.0000e-04
# Epoch 80/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - accuracy: 0.9530 - auc: 0.9727 - balanced_accuracy_metric: 0.6543 - f1_score: 0.9428 - loss: 0.1610 - precision: 0.9551 - recall: 0.9525 - learning_rate: 5.0000e-04
# Epoch 81/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 324ms/step - accuracy: 0.9611 - auc: 0.9589 - balanced_accuracy_metric: 0.7590 - f1_score: 0.9570 - loss: 0.1647 - precision: 0.9610 - recall: 0.9603 - learning_rate: 5.0000e-04
# Epoch 82/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.9612 - auc: 0.9737 - balanced_accuracy_metric: 0.7345 - f1_score: 0.9572 - loss: 0.1568 - precision: 0.9643 - recall: 0.9589 - learning_rate: 5.0000e-04
# Epoch 83/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9599 - auc: 0.9763 - balanced_accuracy_metric: 0.7581 - f1_score: 0.9560 - loss: 0.1498 - precision: 0.9607 - recall: 0.9594 - learning_rate: 5.0000e-04
# Epoch 84/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 401ms/step - accuracy: 0.9591 - auc: 0.9777 - balanced_accuracy_metric: 0.6844 - f1_score: 0.9482 - loss: 0.1527 - precision: 0.9608 - recall: 0.9582 - learning_rate: 5.0000e-04
# Epoch 85/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9542 - auc: 0.9684 - balanced_accuracy_metric: 0.6932 - f1_score: 0.9475 - loss: 0.1675 - precision: 0.9555 - recall: 0.9539 - learning_rate: 5.0000e-04
# Epoch 86/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 430ms/step - accuracy: 0.9531 - auc: 0.9616 - balanced_accuracy_metric: 0.6664 - f1_score: 0.9454 - loss: 0.1668 - precision: 0.9548 - recall: 0.9507 - learning_rate: 5.0000e-04
# Epoch 87/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.9603 - auc: 0.9712 - balanced_accuracy_metric: 0.7907 - f1_score: 0.9570 - loss: 0.1572 - precision: 0.9602 - recall: 0.9587 - learning_rate: 5.0000e-04
# Epoch 88/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 429ms/step - accuracy: 0.9682 - auc: 0.9656 - balanced_accuracy_metric: 0.8057 - f1_score: 0.9648 - loss: 0.1552 - precision: 0.9682 - recall: 0.9677 - learning_rate: 5.0000e-04
# Epoch 89/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 328ms/step - accuracy: 0.9548 - auc: 0.9733 - balanced_accuracy_metric: 0.7220 - f1_score: 0.9493 - loss: 0.1502 - precision: 0.9564 - recall: 0.9543 - learning_rate: 5.0000e-04
# Epoch 90/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 359ms/step - accuracy: 0.9653 - auc: 0.9818 - balanced_accuracy_metric: 0.7309 - f1_score: 0.9583 - loss: 0.1407 - precision: 0.9668 - recall: 0.9648 - learning_rate: 5.0000e-04
# Epoch 91/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 371ms/step - accuracy: 0.9602 - auc: 0.9735 - balanced_accuracy_metric: 0.7869 - f1_score: 0.9562 - loss: 0.1659 - precision: 0.9601 - recall: 0.9576 - learning_rate: 5.0000e-04
# Epoch 92/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 11s 429ms/step - accuracy: 0.9557 - auc: 0.9764 - balanced_accuracy_metric: 0.7384 - f1_score: 0.9519 - loss: 0.1581 - precision: 0.9571 - recall: 0.9550 - learning_rate: 5.0000e-04
# Epoch 93/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9664 - auc: 0.9848 - balanced_accuracy_metric: 0.7812 - f1_score: 0.9627 - loss: 0.1290 - precision: 0.9686 - recall: 0.9646 - learning_rate: 5.0000e-04
# Epoch 94/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 397ms/step - accuracy: 0.9631 - auc: 0.9709 - balanced_accuracy_metric: 0.7439 - f1_score: 0.9576 - loss: 0.1517 - precision: 0.9634 - recall: 0.9604 - learning_rate: 5.0000e-04
# Epoch 95/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 338ms/step - accuracy: 0.9632 - auc: 0.9627 - balanced_accuracy_metric: 0.7407 - f1_score: 0.9582 - loss: 0.1543 - precision: 0.9638 - recall: 0.9609 - learning_rate: 5.0000e-04
# Epoch 96/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9692 - auc: 0.9821 - balanced_accuracy_metric: 0.7877 - f1_score: 0.9660 - loss: 0.1371 - precision: 0.9710 - recall: 0.9692 - learning_rate: 5.0000e-04
# Epoch 97/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.9687 - auc: 0.9804 - balanced_accuracy_metric: 0.7839 - f1_score: 0.9639 - loss: 0.1348 - precision: 0.9719 - recall: 0.9687 - learning_rate: 5.0000e-04
# Epoch 98/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 371ms/step - accuracy: 0.9615 - auc: 0.9615 - balanced_accuracy_metric: 0.7595 - f1_score: 0.9570 - loss: 0.1595 - precision: 0.9615 - recall: 0.9603 - learning_rate: 5.0000e-04
# Epoch 99/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 329ms/step - accuracy: 0.9575 - auc: 0.9712 - balanced_accuracy_metric: 0.7300 - f1_score: 0.9513 - loss: 0.1522 - precision: 0.9592 - recall: 0.9552 - learning_rate: 5.0000e-04
# Epoch 100/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.9596 - auc: 0.9667 - balanced_accuracy_metric: 0.7331 - f1_score: 0.9533 - loss: 0.1573 - precision: 0.9614 - recall: 0.9596
# Epoch 100: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.9598 - auc: 0.9667 - balanced_accuracy_metric: 0.7322 - f1_score: 0.9536 - loss: 0.1570 - precision: 0.9616 - recall: 0.9598 - learning_rate: 5.0000e-04
# Epoch 101/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9668 - auc: 0.9843 - balanced_accuracy_metric: 0.7187 - f1_score: 0.9611 - loss: 0.1301 - precision: 0.9667 - recall: 0.9644 - learning_rate: 2.5000e-04
# Epoch 102/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 419ms/step - accuracy: 0.9687 - auc: 0.9731 - balanced_accuracy_metric: 0.7781 - f1_score: 0.9652 - loss: 0.1392 - precision: 0.9685 - recall: 0.9640 - learning_rate: 2.5000e-04
# Epoch 103/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 322ms/step - accuracy: 0.9645 - auc: 0.9784 - balanced_accuracy_metric: 0.7311 - f1_score: 0.9590 - loss: 0.1348 - precision: 0.9645 - recall: 0.9645 - learning_rate: 2.5000e-04
# Epoch 104/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 429ms/step - accuracy: 0.9660 - auc: 0.9719 - balanced_accuracy_metric: 0.7743 - f1_score: 0.9619 - loss: 0.1385 - precision: 0.9659 - recall: 0.9633 - learning_rate: 2.5000e-04
# Epoch 105/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9698 - auc: 0.9803 - balanced_accuracy_metric: 0.7799 - f1_score: 0.9667 - loss: 0.1281 - precision: 0.9698 - recall: 0.9698 - learning_rate: 2.5000e-04
# Epoch 106/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 422ms/step - accuracy: 0.9692 - auc: 0.9732 - balanced_accuracy_metric: 0.7965 - f1_score: 0.9658 - loss: 0.1339 - precision: 0.9692 - recall: 0.9692 - learning_rate: 2.5000e-04
# Epoch 107/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - accuracy: 0.9693 - auc: 0.9798 - balanced_accuracy_metric: 0.7644 - f1_score: 0.9645 - loss: 0.1298 - precision: 0.9693 - recall: 0.9683
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 9s 333ms/step - accuracy: 0.9693 - auc: 0.9798 - balanced_accuracy_metric: 0.7624 - f1_score: 0.9645 - loss: 0.1297 - precision: 0.9693 - recall: 0.9682 - learning_rate: 2.5000e-04
# Epoch 108/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 424ms/step - accuracy: 0.9664 - auc: 0.9813 - balanced_accuracy_metric: 0.7560 - f1_score: 0.9621 - loss: 0.1342 - precision: 0.9664 - recall: 0.9664 - learning_rate: 2.5000e-04
# Epoch 109/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - accuracy: 0.9742 - auc: 0.9790 - balanced_accuracy_metric: 0.8065 - f1_score: 0.9707 - loss: 0.1286 - precision: 0.9742 - recall: 0.9742
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 334ms/step - accuracy: 0.9743 - auc: 0.9790 - balanced_accuracy_metric: 0.8063 - f1_score: 0.9708 - loss: 0.1284 - precision: 0.9743 - recall: 0.9743 - learning_rate: 2.5000e-04
# Epoch 110/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.9622 - auc: 0.9843 - balanced_accuracy_metric: 0.6898 - f1_score: 0.9548 - loss: 0.1354 - precision: 0.9622 - recall: 0.9610 - learning_rate: 2.5000e-04
# Epoch 111/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step - accuracy: 0.9775 - auc: 0.9760 - balanced_accuracy_metric: 0.8313 - f1_score: 0.9761 - loss: 0.1157 - precision: 0.9775 - recall: 0.9775
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9775 - auc: 0.9754 - balanced_accuracy_metric: 0.8282 - f1_score: 0.9760 - loss: 0.1160 - precision: 0.9775 - recall: 0.9775 - learning_rate: 2.5000e-04
# Epoch 112/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9719 - auc: 0.9860 - balanced_accuracy_metric: 0.7933 - f1_score: 0.9690 - loss: 0.1204 - precision: 0.9719 - recall: 0.9709 - learning_rate: 2.5000e-04
# Epoch 113/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 412ms/step - accuracy: 0.9656 - auc: 0.9763 - balanced_accuracy_metric: 0.7646 - f1_score: 0.9615 - loss: 0.1311 - precision: 0.9658 - recall: 0.9656 - learning_rate: 2.5000e-04
# Epoch 114/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9775 - auc: 0.9767 - balanced_accuracy_metric: 0.8385 - f1_score: 0.9755 - loss: 0.1143 - precision: 0.9775 - recall: 0.9775 - learning_rate: 2.5000e-04
# Epoch 115/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 426ms/step - accuracy: 0.9721 - auc: 0.9857 - balanced_accuracy_metric: 0.8162 - f1_score: 0.9698 - loss: 0.1218 - precision: 0.9721 - recall: 0.9706 - learning_rate: 2.5000e-04
# Epoch 116/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9727 - auc: 0.9737 - balanced_accuracy_metric: 0.7788 - f1_score: 0.9687 - loss: 0.1251 - precision: 0.9727 - recall: 0.9725 - learning_rate: 2.5000e-04
# Epoch 117/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 367ms/step - accuracy: 0.9716 - auc: 0.9785 - balanced_accuracy_metric: 0.7737 - f1_score: 0.9676 - loss: 0.1225 - precision: 0.9716 - recall: 0.9708 - learning_rate: 2.5000e-04
# Epoch 118/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 326ms/step - accuracy: 0.9752 - auc: 0.9870 - balanced_accuracy_metric: 0.8517 - f1_score: 0.9734 - loss: 0.1186 - precision: 0.9756 - recall: 0.9713 - learning_rate: 2.5000e-04
# Epoch 119/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 430ms/step - accuracy: 0.9693 - auc: 0.9832 - balanced_accuracy_metric: 0.7938 - f1_score: 0.9658 - loss: 0.1224 - precision: 0.9697 - recall: 0.9689 - learning_rate: 2.5000e-04
# Epoch 120/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9676 - auc: 0.9699 - balanced_accuracy_metric: 0.7483 - f1_score: 0.9639 - loss: 0.1394 - precision: 0.9676 - recall: 0.9676 - learning_rate: 2.5000e-04
# Epoch 121/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 399ms/step - accuracy: 0.9743 - auc: 0.9776 - balanced_accuracy_metric: 0.7951 - f1_score: 0.9710 - loss: 0.1228 - precision: 0.9743 - recall: 0.9743 - learning_rate: 2.5000e-04
# Epoch 122/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 326ms/step - accuracy: 0.9640 - auc: 0.9811 - balanced_accuracy_metric: 0.7844 - f1_score: 0.9616 - loss: 0.1370 - precision: 0.9655 - recall: 0.9640 - learning_rate: 2.5000e-04
# Epoch 123/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9738 - auc: 0.9850 - balanced_accuracy_metric: 0.8363 - f1_score: 0.9714 - loss: 0.1157 - precision: 0.9751 - recall: 0.9649 - learning_rate: 2.5000e-04
# Epoch 124/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 428ms/step - accuracy: 0.9733 - auc: 0.9885 - balanced_accuracy_metric: 0.8610 - f1_score: 0.9720 - loss: 0.1099 - precision: 0.9737 - recall: 0.9729 - learning_rate: 2.5000e-04
# Epoch 125/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9661 - auc: 0.9785 - balanced_accuracy_metric: 0.7275 - f1_score: 0.9612 - loss: 0.1330 - precision: 0.9661 - recall: 0.9661 - learning_rate: 2.5000e-04
# Epoch 126/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 426ms/step - accuracy: 0.9692 - auc: 0.9841 - balanced_accuracy_metric: 0.8185 - f1_score: 0.9667 - loss: 0.1203 - precision: 0.9692 - recall: 0.9692 - learning_rate: 2.5000e-04
# Epoch 127/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9691 - auc: 0.9845 - balanced_accuracy_metric: 0.7899 - f1_score: 0.9660 - loss: 0.1196 - precision: 0.9691 - recall: 0.9691 - learning_rate: 2.5000e-04
# Epoch 128/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 352ms/step - accuracy: 0.9632 - auc: 0.9822 - balanced_accuracy_metric: 0.7123 - f1_score: 0.9574 - loss: 0.1245 - precision: 0.9636 - recall: 0.9625 - learning_rate: 2.5000e-04
# Epoch 129/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 380ms/step - accuracy: 0.9656 - auc: 0.9802 - balanced_accuracy_metric: 0.8014 - f1_score: 0.9630 - loss: 0.1275 - precision: 0.9662 - recall: 0.9644 - learning_rate: 2.5000e-04
# Epoch 130/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9705 - auc: 0.9771 - balanced_accuracy_metric: 0.7455 - f1_score: 0.9642 - loss: 0.1227 - precision: 0.9708 - recall: 0.9705 - learning_rate: 2.5000e-04
# Epoch 131/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 425ms/step - accuracy: 0.9687 - auc: 0.9828 - balanced_accuracy_metric: 0.7439 - f1_score: 0.9627 - loss: 0.1249 - precision: 0.9720 - recall: 0.9687
# Epoch 131: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 428ms/step - accuracy: 0.9687 - auc: 0.9830 - balanced_accuracy_metric: 0.7432 - f1_score: 0.9628 - loss: 0.1244 - precision: 0.9719 - recall: 0.9687 - learning_rate: 2.5000e-04
# Epoch 132/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9671 - auc: 0.9876 - balanced_accuracy_metric: 0.8055 - f1_score: 0.9648 - loss: 0.1237 - precision: 0.9674 - recall: 0.9630 - learning_rate: 1.2500e-04
# Epoch 133/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 424ms/step - accuracy: 0.9751 - auc: 0.9799 - balanced_accuracy_metric: 0.8063 - f1_score: 0.9726 - loss: 0.1140 - precision: 0.9751 - recall: 0.9733 - learning_rate: 1.2500e-04
# Epoch 134/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9694 - auc: 0.9796 - balanced_accuracy_metric: 0.7896 - f1_score: 0.9656 - loss: 0.1200 - precision: 0.9696 - recall: 0.9684 - learning_rate: 1.2500e-04
# Epoch 135/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 322ms/step - accuracy: 0.9728 - auc: 0.9792 - balanced_accuracy_metric: 0.7609 - f1_score: 0.9696 - loss: 0.1113 - precision: 0.9727 - recall: 0.9723 - learning_rate: 1.2500e-04
# Epoch 136/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 418ms/step - accuracy: 0.9776 - auc: 0.9812 - balanced_accuracy_metric: 0.8317 - f1_score: 0.9752 - loss: 0.1210 - precision: 0.9776 - recall: 0.9776 - learning_rate: 1.2500e-04
# Epoch 137/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 320ms/step - accuracy: 0.9659 - auc: 0.9814 - balanced_accuracy_metric: 0.8127 - f1_score: 0.9633 - loss: 0.1262 - precision: 0.9658 - recall: 0.9635 - learning_rate: 1.2500e-04
# Epoch 138/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 427ms/step - accuracy: 0.9694 - auc: 0.9918 - balanced_accuracy_metric: 0.8269 - f1_score: 0.9674 - loss: 0.1209 - precision: 0.9712 - recall: 0.9694 - learning_rate: 1.2500e-04
# Epoch 139/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - accuracy: 0.9764 - auc: 0.9880 - balanced_accuracy_metric: 0.7887 - f1_score: 0.9743 - loss: 0.1139 - precision: 0.9764 - recall: 0.9764
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 331ms/step - accuracy: 0.9765 - auc: 0.9880 - balanced_accuracy_metric: 0.7887 - f1_score: 0.9744 - loss: 0.1134 - precision: 0.9765 - recall: 0.9765 - learning_rate: 1.2500e-04
# Epoch 140/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 358ms/step - accuracy: 0.9759 - auc: 0.9673 - balanced_accuracy_metric: 0.8453 - f1_score: 0.9743 - loss: 0.1261 - precision: 0.9759 - recall: 0.9754 - learning_rate: 1.2500e-04
# Epoch 141/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 10s 327ms/step - accuracy: 0.9692 - auc: 0.9802 - balanced_accuracy_metric: 0.7434 - f1_score: 0.9625 - loss: 0.1210 - precision: 0.9691 - recall: 0.9683 - learning_rate: 1.2500e-04
# Epoch 142/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 426ms/step - accuracy: 0.9748 - auc: 0.9897 - balanced_accuracy_metric: 0.8219 - f1_score: 0.9722 - loss: 0.1114 - precision: 0.9747 - recall: 0.9714
# Epoch 142: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 429ms/step - accuracy: 0.9748 - auc: 0.9897 - balanced_accuracy_metric: 0.8192 - f1_score: 0.9721 - loss: 0.1112 - precision: 0.9747 - recall: 0.9715 - learning_rate: 1.2500e-04
# Epoch 143/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 325ms/step - accuracy: 0.9752 - auc: 0.9701 - balanced_accuracy_metric: 0.8205 - f1_score: 0.9723 - loss: 0.1265 - precision: 0.9750 - recall: 0.9708 - learning_rate: 6.2500e-05
# Epoch 144/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 406ms/step - accuracy: 0.9706 - auc: 0.9753 - balanced_accuracy_metric: 0.7319 - f1_score: 0.9657 - loss: 0.1283 - precision: 0.9706 - recall: 0.9703 - learning_rate: 6.2500e-05
# Epoch 145/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 323ms/step - accuracy: 0.9686 - auc: 0.9843 - balanced_accuracy_metric: 0.7873 - f1_score: 0.9657 - loss: 0.1182 - precision: 0.9686 - recall: 0.9686 - learning_rate: 6.2500e-05
# Epoch 146/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9778 - auc: 0.9827 - balanced_accuracy_metric: 0.8396 - f1_score: 0.9758 - loss: 0.1088 - precision: 0.9794 - recall: 0.9778 - learning_rate: 6.2500e-05
# Epoch 147/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 7s 414ms/step - accuracy: 0.9717 - auc: 0.9873 - balanced_accuracy_metric: 0.8381 - f1_score: 0.9698 - loss: 0.1102 - precision: 0.9717 - recall: 0.9702 - learning_rate: 6.2500e-05
# Epoch 148/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 324ms/step - accuracy: 0.9700 - auc: 0.9816 - balanced_accuracy_metric: 0.8170 - f1_score: 0.9674 - loss: 0.1188 - precision: 0.9742 - recall: 0.9682 - learning_rate: 6.2500e-05
# Epoch 149/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 6s 423ms/step - accuracy: 0.9696 - auc: 0.9849 - balanced_accuracy_metric: 0.7707 - f1_score: 0.9655 - loss: 0.1200 - precision: 0.9710 - recall: 0.9696 - learning_rate: 6.2500e-05
# Epoch 150/300
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 5s 321ms/step - accuracy: 0.9735 - auc: 0.9902 - balanced_accuracy_metric: 0.8180 - f1_score: 0.9714 - loss: 0.1061 - precision: 0.9735 - recall: 0.9735 - learning_rate: 6.2500e-05
# Error loading final model: name 'custom_objects' is not defined
# Using last epoch's model instead

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (confusion_matrix, classification_report,
                           roc_auc_score, precision_recall_curve,
                           average_precision_score, roc_curve)
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde

def find_early_detection_threshold(y_true, y_scores, timing_data=None, min_sensitivity=0.9):
    """
    Find threshold that optimizes for early detection while maintaining sensitivity
    Args:
        y_true: True labels
        y_scores: Predicted probabilities
        timing_data: List of detection times (negative for missed cases)
        min_sensitivity: Minimum sensitivity to maintain
    Returns:
        optimal_threshold: Threshold that maximizes early detection
        detection_stats: Dictionary with detection statistics
    """
    # Calculate ROC curve metrics
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)

    # Filter thresholds that meet minimum sensitivity
    valid_idx = np.where(tpr >= min_sensitivity)[0]
    if len(valid_idx) == 0:
        return 0.5, {}  # Fallback if no threshold meets sensitivity

    # Get subset of thresholds that meet sensitivity
    valid_thresholds = thresholds[valid_idx]
    valid_tpr = tpr[valid_idx]

    # If no timing data, just return the threshold with highest sensitivity
    if timing_data is None:
        best_idx = np.argmax(valid_tpr)
        optimal_threshold = valid_thresholds[best_idx]
        return optimal_threshold, {}

    # For each candidate threshold, calculate detection timing
    detection_stats = []
    for thresh in valid_thresholds:
        y_pred = (y_scores >= thresh).astype(int)
        detected_times = [t for t in timing_data if t > 0]
        avg_detection_time = np.mean(detected_times) if detected_times else 0
        detection_rate = len(detected_times) / sum(y_true)

        detection_stats.append({
            'threshold': thresh,
            'sensitivity': valid_tpr[np.where(valid_thresholds == thresh)[0][0]],
            'avg_detection_time': avg_detection_time,
            'detection_rate': detection_rate
        })

    # Select threshold with best (earliest) average detection time
    detection_stats = pd.DataFrame(detection_stats)
    best_idx = detection_stats['avg_detection_time'].idxmax()
    optimal_threshold = detection_stats.loc[best_idx, 'threshold']

    return optimal_threshold, detection_stats

def assess_patient_risk_with_early_warning(patient_data, model, temporal_features,
                                         max_seq_length, disability_threshold=0.15,
                                         death_threshold=0.15, early_warning_factor=0.7):
    """
    Enhanced risk assessment with separate early warning signals for disability and death
    Args:
        patient_data: DataFrame for one patient's visits
        model: Trained LSTM model
        temporal_features: List of temporal features
        max_seq_length: Maximum sequence length
        disability_threshold: Main risk threshold for disability
        death_threshold: Main risk threshold for death
        early_warning_factor: Fraction of main threshold for early warning
    Returns:
        DataFrame with risk assessments and warning flags for both outcomes
    """
    risks = []
    patient_data = patient_data.sort_values('ASSDT')
    disability_warning_threshold = disability_threshold * early_warning_factor
    death_warning_threshold = death_threshold * early_warning_factor

    for i in range(1, len(patient_data)+1):
        current_visit = patient_data.iloc[:i]
        current_row = current_visit.iloc[-1]

        # Prepare sequence data
        seq_len = len(current_visit)
        seq_data = np.zeros((1, max_seq_length, len(temporal_features)))
        seq_data[0, :seq_len, :] = current_visit[temporal_features].values

        # Get prediction probabilities for all classes
        pred_probas = model.predict(seq_data, verbose=0)[0]

        # Class 0 is disability, class 2 is death (assuming your encoding)
        disability_prob = pred_probas[0]
        death_prob = pred_probas[2]

        risks.append({
            'visit_date': current_row['ASSDT'],
            'visit_number': i,
            'disability_risk': disability_prob,
            'death_risk': death_prob,
            'disability_flagged': disability_prob >= disability_threshold,
            'death_flagged': death_prob >= death_threshold,
            'disability_warning': disability_prob >= disability_warning_threshold,
            'death_warning': death_prob >= death_warning_threshold
        })

    return pd.DataFrame(risks)

def evaluate_patients_with_early_detection(data, model, temporal_features,
                                         max_seq_length, timing_data=None):
    """
    Enhanced evaluation with separate tracking for disability and death outcomes
    Args:
        data: Full dataset
        model: Trained model
        temporal_features: List of temporal features
        max_seq_length: Maximum sequence length
        timing_data: Optional existing timing data (dict with 'disability' and 'death' keys)
    Returns:
        results_df: Evaluation results
        timing_data: Detection timing (dict with both outcomes)
        thresholds: Dictionary with optimal thresholds
        detection_stats: Dictionary with detection statistics
    """
    results = []
    timing_analysis = {
        'disability': [],
        'death': []
    }
    all_scores = {
        'disability': [],
        'death': []
    }
    all_outcomes = {
        'disability': [],
        'death': []
    }

    # First pass to collect all scores and outcomes
    for ptno, patient_data in data.groupby('PTNO'):
        patient_data = patient_data.sort_values('ASSDT')
        final_outcome = patient_data['end_state_encoded'].iloc[-1]

        # Get risk assessment
        risk_df = assess_patient_risk_with_early_warning(
            patient_data,
            model,
            temporal_features,
            max_seq_length,
            disability_threshold=0.5,  # Temporary thresholds
            death_threshold=0.5
        )

        # Store max scores and outcomes for both conditions
        all_scores['disability'].append(risk_df['disability_risk'].max())
        all_scores['death'].append(risk_df['death_risk'].max())

        all_outcomes['disability'].append(final_outcome == 0)  # Disability
        all_outcomes['death'].append(final_outcome == 2)      # Death

    # Find optimal thresholds for both outcomes
    thresholds = {}
    detection_stats = {}

    # For disability
    y_true_disability = np.array(all_outcomes['disability']).astype(int)
    y_scores_disability = np.array(all_scores['disability'])

    # Get timing data if not provided
    if timing_data is None or 'disability' not in timing_data:
        disability_timing = []
        for ptno, patient_data in data.groupby('PTNO'):
            patient_data = patient_data.sort_values('ASSDT')
            final_outcome = patient_data['end_state_encoded'].iloc[-1]

            if final_outcome == 0:  # Disability cases only
                risk_df = assess_patient_risk_with_early_warning(
                    patient_data,
                    model,
                    temporal_features,
                    max_seq_length
                )

                first_flag = risk_df[risk_df['disability_flagged']]['visit_date'].min()
                if pd.notna(first_flag):
                    months_before = (patient_data['ASSDT'].iloc[-1] - first_flag).days / 30
                    disability_timing.append(months_before)
                else:
                    disability_date = patient_data['ASSDT'].iloc[-1]
                    last_visit_date = patient_data['ASSDT'].iloc[-2] if len(patient_data) > 1 else disability_date
                    months_after = (disability_date - last_visit_date).days / 30
                    disability_timing.append(-months_after)
        timing_analysis['disability'] = disability_timing
    else:
        timing_analysis['disability'] = timing_data['disability']

    # Find optimal threshold for disability
    thresholds['disability'], detection_stats['disability'] = find_early_detection_threshold(
        y_true_disability, y_scores_disability, timing_analysis['disability']
    )

    # For death - typically we don't have timing data for death (can't detect after event)
    y_true_death = np.array(all_outcomes['death']).astype(int)
    y_scores_death = np.array(all_scores['death'])

    # Find threshold that maximizes sensitivity for death
    thresholds['death'], detection_stats['death'] = find_early_detection_threshold(
        y_true_death, y_scores_death, min_sensitivity=0.9
    )

    # Second pass with optimal thresholds and early warning
    for ptno, patient_data in data.groupby('PTNO'):
        patient_data = patient_data.sort_values('ASSDT')
        final_outcome = patient_data['end_state_encoded'].iloc[-1]

        # Get risk assessment with early warning
        risk_df = assess_patient_risk_with_early_warning(
            patient_data,
            model,
            temporal_features,
            max_seq_length,
            disability_threshold=thresholds['disability'],
            death_threshold=thresholds['death']
        )

        # Record first time flagged (if any) for both outcomes
        first_disability_flag = risk_df[risk_df['disability_flagged']]['visit_date'].min()
        first_death_flag = risk_df[risk_df['death_flagged']]['visit_date'].min()

        first_disability_warning = risk_df[risk_df['disability_warning']]['visit_date'].min()
        first_death_warning = risk_df[risk_df['death_warning']]['visit_date'].min()

        # Store results
        results.append({
            'PTNO': ptno,
            'final_outcome': final_outcome,
            'ever_disability_flagged': any(risk_df['disability_flagged']),
            'ever_death_flagged': any(risk_df['death_flagged']),
            'ever_disability_warned': any(risk_df['disability_warning']),
            'ever_death_warned': any(risk_df['death_warning']),
            'first_disability_flag_date': first_disability_flag,
            'first_death_flag_date': first_death_flag,
            'first_disability_warning_date': first_disability_warning,
            'first_death_warning_date': first_death_warning,
            'max_disability_risk': risk_df['disability_risk'].max(),
            'max_death_risk': risk_df['death_risk'].max(),
            'final_disability_risk': risk_df['disability_risk'].iloc[-1],
            'final_death_risk': risk_df['death_risk'].iloc[-1],
            'num_visits': len(patient_data)
        })

    return pd.DataFrame(results), timing_analysis, thresholds, detection_stats

def analyze_early_detection_results(results_df, timing_data, thresholds, detection_stats):
    """
    Enhanced analysis with separate metrics for disability and death outcomes
    """
    # Disability analysis
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    disability_pred_alert = results_df['ever_disability_flagged'].astype(int)
    disability_pred_warning = results_df['ever_disability_warned'].astype(int)
    disability_scores = results_df['max_disability_risk']

    # Death analysis
    death_true = (results_df['final_outcome'] == 2).astype(int)
    death_pred_alert = results_df['ever_death_flagged'].astype(int)
    death_pred_warning = results_df['ever_death_warned'].astype(int)
    death_scores = results_df['max_death_risk']

    # Convert timing data to arrays
    disability_timing = np.array(timing_data['disability'])
    disability_detections = disability_timing[disability_timing > 0]

    print("\n=== Disability Early Detection Performance ===")
    print(f"Using threshold: {thresholds['disability']:.4f}")
    print(f"Early warning threshold: {thresholds['disability']*0.7:.4f}")

    if len(disability_detections) > 0:
        print(f"\nAverage detection time (months): {np.mean(disability_detections):.1f}")
        print(f"Median detection time: {np.median(disability_detections):.1f}")
        print(f"Detection rate: {len(disability_detections)}/{sum(disability_true)} ({len(disability_detections)/sum(disability_true):.1%})")
    else:
        print("\nNo positive detections for disability")

    print("\n=== Disability Alert-Level Performance ===")
    print("Confusion Matrix:")
    print(confusion_matrix(disability_true, disability_pred_alert))
    print("\nClassification Report:")
    print(classification_report(disability_true, disability_pred_alert))

    print("\n=== Disability Warning-Level Performance ===")
    print("Confusion Matrix:")
    print(confusion_matrix(disability_true, disability_pred_warning))
    print("\nClassification Report:")
    print(classification_report(disability_true, disability_pred_warning))

    print(f"\nROC AUC: {roc_auc_score(disability_true, disability_scores):.4f}")
    print(f"Average Precision: {average_precision_score(disability_true, disability_scores):.4f}")

    # Death analysis
    print("\n=== Death Detection Performance ===")
    print(f"Using threshold: {thresholds['death']:.4f}")
    print(f"Early warning threshold: {thresholds['death']*0.7:.4f}")

    print("\n=== Death Alert-Level Performance ===")
    print("Confusion Matrix:")
    print(confusion_matrix(death_true, death_pred_alert))
    print("\nClassification Report:")
    print(classification_report(death_true, death_pred_alert))

    print("\n=== Death Warning-Level Performance ===")
    print("Confusion Matrix:")
    print(confusion_matrix(death_true, death_pred_warning))
    print("\nClassification Report:")
    print(classification_report(death_true, death_pred_warning))

    print(f"\nROC AUC: {roc_auc_score(death_true, death_scores):.4f}")
    print(f"Average Precision: {average_precision_score(death_true, death_scores):.4f}")

    # Plotting
    plt.figure(figsize=(15, 10))

    # Disability detection time distribution
    if len(disability_detections) > 0:
        plt.subplot(2, 2, 1)
        plt.hist(disability_detections, bins=20, color='green', alpha=0.7)
        plt.xlabel('Months Before Disability')
        plt.ylabel('Number of Patients')
        plt.title('Disability Early Detection Timing')

        plt.subplot(2, 2, 2)
        density = gaussian_kde(disability_detections)
        xs = np.linspace(0, max(disability_detections), 200)
        plt.plot(xs, density(xs), color='green')
        plt.fill_between(xs, density(xs), color='green', alpha=0.2)
        plt.xlabel('Months Before Disability')
        plt.ylabel('Density')
        plt.title('Disability Detection Time Distribution')

    # Risk score distributions
    plt.subplot(2, 2, 3)
    for outcome, color in zip([0, 1, 2], ['red', 'blue', 'green']):
        subset = results_df[results_df['final_outcome'] == outcome]
        plt.hist(subset['max_disability_risk'], bins=30, alpha=0.5, color=color,
                label=f'Outcome {outcome}')
    plt.xlabel('Max Disability Risk Score')
    plt.ylabel('Count')
    plt.title('Disability Risk Score Distribution by Outcome')
    plt.legend()

    plt.subplot(2, 2, 4)
    for outcome, color in zip([0, 1, 2], ['red', 'blue', 'green']):
        subset = results_df[results_df['final_outcome'] == outcome]
        plt.hist(subset['max_death_risk'], bins=30, alpha=0.5, color=color,
                label=f'Outcome {outcome}')
    plt.xlabel('Max Death Risk Score')
    plt.ylabel('Count')
    plt.title('Death Risk Score Distribution by Outcome')
    plt.legend()

    plt.tight_layout()
    plt.show()

# Example Usage
if __name__ == "__main__":
    # Assuming you have these defined:
    # data = your patient data
    # final_model = your trained LSTM model
    # selected_features = your temporal features
    # X_seq = your sequence data (for getting max_seq_length)

    max_seq_length = X_seq.shape[1]

    # Run evaluation with early detection focus
    results_df, timing_data, thresholds, det_stats = evaluate_patients_with_early_detection(
        data,
        final_model,
        temporal_features=selected_features,
        max_seq_length=max_seq_length
    )

    # Analyze results
    analyze_early_detection_results(results_df, timing_data, thresholds, det_stats)
# Out:
# === Disability Early Detection Performance ===
# Using threshold: 0.9260
# Early warning threshold: 0.6482
#
# Average detection time (months): 50.3
# Median detection time: 28.6
# Detection rate: 115/129 (89.1%)
#
# === Disability Alert-Level Performance ===
# Confusion Matrix:
# [[763  17]
#  [  8 121]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       780
#            1       0.88      0.94      0.91       129
#
#     accuracy                           0.97       909
#    macro avg       0.93      0.96      0.95       909
# weighted avg       0.97      0.97      0.97       909
#
#
# === Disability Warning-Level Performance ===
# Confusion Matrix:
# [[761  19]
#  [  7 122]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.98       780
#            1       0.87      0.95      0.90       129
#
#     accuracy                           0.97       909
#    macro avg       0.93      0.96      0.94       909
# weighted avg       0.97      0.97      0.97       909
#
#
# ROC AUC: 0.9803
# Average Precision: 0.8872
#
# === Death Detection Performance ===
# Using threshold: 0.0351
# Early warning threshold: 0.0246
#
# === Death Alert-Level Performance ===
# Confusion Matrix:
# [[249 633]
#  [  0  27]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.28      0.44       882
#            1       0.04      1.00      0.08        27
#
#     accuracy                           0.30       909
#    macro avg       0.52      0.64      0.26       909
# weighted avg       0.97      0.30      0.43       909
#
#
# === Death Warning-Level Performance ===
# Confusion Matrix:
# [[ 90 792]
#  [  0  27]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       1.00      0.10      0.19       882
#            1       0.03      1.00      0.06        27
#
#     accuracy                           0.13       909
#    macro avg       0.52      0.55      0.12       909
# weighted avg       0.97      0.13      0.18       909
#
#
# ROC AUC: 0.8396
# Average Precision: 0.4255

# %%
def plot_metrics_by_cutoff(results_df):
    """
    Plot metrics by cutoff for both disability and mortality systems.
    Top row: Disability system
    Bottom row: Mortality system
    Left column: Sensitivity and Specificity
    Right column: PPV and NPV
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from sklearn.metrics import confusion_matrix

    # Prepare data for both systems
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    death_true = (results_df['final_outcome'] == 2).astype(int)

    disability_scores = results_df['max_disability_risk']
    death_scores = results_df['max_death_risk']

    # Define cutoff range
    cutoffs = np.linspace(0.01, 0.99, 100)

    # Calculate metrics for each cutoff
    disability_metrics = []
    death_metrics = []

    for cutoff in cutoffs:
        # Disability metrics
        disability_pred = (disability_scores >= cutoff).astype(int)
        tn, fp, fn, tp = confusion_matrix(disability_true, disability_pred).ravel()

        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        ppv = tp / (tp + fp) if (tp + fp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        disability_metrics.append({
            'cutoff': cutoff,
            'sensitivity': sensitivity,
            'specificity': specificity,
            'ppv': ppv,
            'npv': npv
        })

        # Death metrics
        death_pred = (death_scores >= cutoff).astype(int)
        tn, fp, fn, tp = confusion_matrix(death_true, death_pred).ravel()

        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        ppv = tp / (tp + fp) if (tp + fp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        death_metrics.append({
            'cutoff': cutoff,
            'sensitivity': sensitivity,
            'specificity': specificity,
            'ppv': ppv,
            'npv': npv
        })

    # Convert to DataFrames
    disability_metrics = pd.DataFrame(disability_metrics)
    death_metrics = pd.DataFrame(death_metrics)

    # Create figure
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Disability System - Sensitivity & Specificity
    ax1 = axes[0, 0]
    ax1.plot(disability_metrics['cutoff'], disability_metrics['sensitivity'],
             'b-', linewidth=2, label='Sensitivity')
    ax1.plot(disability_metrics['cutoff'], disability_metrics['specificity'],
             'r-', linewidth=2, label='Specificity')
    ax1.set_xlabel('Risk Cutoff')
    ax1.set_ylabel('Value')
    ax1.set_title('Disability System: Sensitivity & Specificity vs. Cutoff')
    ax1.legend(loc='best')
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim([0, 1])
    ax1.set_ylim([0, 1])

    # Find optimal cutoff (Youden's J statistic)
    youden_j = disability_metrics['sensitivity'] + disability_metrics['specificity'] - 1
    optimal_idx = youden_j.idxmax()
    optimal_cutoff = disability_metrics.loc[optimal_idx, 'cutoff']
    optimal_sens = disability_metrics.loc[optimal_idx, 'sensitivity']
    optimal_spec = disability_metrics.loc[optimal_idx, 'specificity']

    ax1.axvline(x=optimal_cutoff, color='gray', linestyle='--', alpha=0.7)
    ax1.annotate(f'Optimal: {optimal_cutoff:.2f}\nSens: {optimal_sens:.2f}, Spec: {optimal_spec:.2f}',
                xy=(optimal_cutoff, 0.5), xytext=(0.05, 0.3),
                arrowprops=dict(arrowstyle='->', color='gray'))

    # Disability System - PPV & NPV
    ax2 = axes[0, 1]
    ax2.plot(disability_metrics['cutoff'], disability_metrics['ppv'],
             'g-', linewidth=2, label='PPV (Precision)')
    ax2.plot(disability_metrics['cutoff'], disability_metrics['npv'],
             'm-', linewidth=2, label='NPV')
    ax2.set_xlabel('Risk Cutoff')
    ax2.set_ylabel('Value')
    ax2.set_title('Disability System: PPV & NPV vs. Cutoff')
    ax2.legend(loc='best')
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim([0, 1])
    ax2.set_ylim([0, 1])

    # Add prevalence line for PPV context
    prevalence = disability_true.mean()
    ax2.axhline(y=prevalence, color='gray', linestyle=':', alpha=0.5,
               label=f'Prevalence: {prevalence:.2f}')
    ax2.legend(loc='best')

    # Mortality System - Sensitivity & Specificity
    ax3 = axes[1, 0]
    ax3.plot(death_metrics['cutoff'], death_metrics['sensitivity'],
             'b-', linewidth=2, label='Sensitivity')
    ax3.plot(death_metrics['cutoff'], death_metrics['specificity'],
             'r-', linewidth=2, label='Specificity')
    ax3.set_xlabel('Risk Cutoff')
    ax3.set_ylabel('Value')
    ax3.set_title('Mortality System: Sensitivity & Specificity vs. Cutoff')
    ax3.legend(loc='best')
    ax3.grid(True, alpha=0.3)
    ax3.set_xlim([0, 1])
    ax3.set_ylim([0, 1])

    # Find optimal cutoff for mortality
    youden_j = death_metrics['sensitivity'] + death_metrics['specificity'] - 1
    optimal_idx = youden_j.idxmax()
    optimal_cutoff = death_metrics.loc[optimal_idx, 'cutoff']
    optimal_sens = death_metrics.loc[optimal_idx, 'sensitivity']
    optimal_spec = death_metrics.loc[optimal_idx, 'specificity']

    ax3.axvline(x=optimal_cutoff, color='gray', linestyle='--', alpha=0.7)
    ax3.annotate(f'Optimal: {optimal_cutoff:.2f}\nSens: {optimal_sens:.2f}, Spec: {optimal_spec:.2f}',
                xy=(optimal_cutoff, 0.5), xytext=(0.05, 0.3),
                arrowprops=dict(arrowstyle='->', color='gray'))

    # Mortality System - PPV & NPV
    ax4 = axes[1, 1]
    ax4.plot(death_metrics['cutoff'], death_metrics['ppv'],
             'g-', linewidth=2, label='PPV (Precision)')
    ax4.plot(death_metrics['cutoff'], death_metrics['npv'],
             'm-', linewidth=2, label='NPV')
    ax4.set_xlabel('Risk Cutoff')
    ax4.set_ylabel('Value')
    ax4.set_title('Mortality System: PPV & NPV vs. Cutoff')
    ax4.legend(loc='best')
    ax4.grid(True, alpha=0.3)
    ax4.set_xlim([0, 1])
    ax4.set_ylim([0, 1])

    # Add prevalence line for PPV context
    prevalence = death_true.mean()
    ax4.axhline(y=prevalence, color='gray', linestyle=':', alpha=0.5,
               label=f'Prevalence: {prevalence:.2f}')
    ax4.legend(loc='best')

    plt.tight_layout()
    return fig, axes, disability_metrics, death_metrics

def plot_comprehensive_metrics(results_df, thresholds=None):
    """
    Comprehensive plotting with all metrics for both systems
    """
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Prepare data
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    death_true = (results_df['final_outcome'] == 2).astype(int)

    disability_scores = results_df['max_disability_risk']
    death_scores = results_df['max_death_risk']

    # Define cutoff range
    cutoffs = np.linspace(0.01, 0.99, 100)

    # Calculate all metrics
    metrics_disability = []
    metrics_death = []

    for cutoff in cutoffs:
        # Disability
        pred = (disability_scores >= cutoff).astype(int)
        tn, fp, fn, tp = confusion_matrix(disability_true, pred).ravel()

        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        ppv = tp / (tp + fp) if (tp + fp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        metrics_disability.append({
            'cutoff': cutoff,
            'sensitivity': sensitivity,
            'specificity': specificity,
            'ppv': ppv,
            'npv': npv,
            'fpr': fp / (fp + tn) if (fp + tn) > 0 else 0,
            'fnr': fn / (fn + tp) if (fn + tp) > 0 else 0
        })

        # Death
        pred = (death_scores >= cutoff).astype(int)
        tn, fp, fn, tp = confusion_matrix(death_true, pred).ravel()

        sensitivity = tp / (tp + fn) if (tp + fn) > 0 else 0
        specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
        ppv = tp / (tp + fp) if (tp + fp) > 0 else 0
        npv = tn / (tn + fn) if (tn + fn) > 0 else 0

        metrics_death.append({
            'cutoff': cutoff,
            'sensitivity': sensitivity,
            'specificity': specificity,
            'ppv': ppv,
            'npv': npv,
            'fpr': fp / (fp + tn) if (fp + tn) > 0 else 0,
            'fnr': fn / (fn + tp) if (fn + tp) > 0 else 0
        })

    metrics_disability = pd.DataFrame(metrics_disability)
    metrics_death = pd.DataFrame(metrics_death)

    # Plot 1: Disability - Sensitivity & Specificity
    ax1 = axes[0, 0]
    ax1.plot(metrics_disability['cutoff'], metrics_disability['sensitivity'],
             'b-', linewidth=2, label='Sensitivity (Recall)', alpha=0.8)
    ax1.plot(metrics_disability['cutoff'], metrics_disability['specificity'],
             'r-', linewidth=2, label='Specificity', alpha=0.8)
    ax1.set_xlabel('Risk Cutoff', fontsize=11)
    ax1.set_ylabel('Value', fontsize=11)
    ax1.set_title('Disability System: Sensitivity & Specificity', fontsize=12, fontweight='bold')
    ax1.legend(loc='center left', fontsize=10)
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim([0, 1])
    ax1.set_ylim([0, 1])

    # Add threshold line if provided
    if thresholds and 'disability' in thresholds:
        ax1.axvline(x=thresholds['disability'], color='green', linestyle='--',
                   linewidth=1.5, alpha=0.7, label=f'Optimal: {thresholds["disability"]:.3f}')
        ax1.legend(loc='center left', fontsize=10)

    # Plot 2: Disability - PPV & NPV
    ax2 = axes[0, 1]
    ax2.plot(metrics_disability['cutoff'], metrics_disability['ppv'],
             'g-', linewidth=2, label='PPV (Precision)', alpha=0.8)
    ax2.plot(metrics_disability['cutoff'], metrics_disability['npv'],
             'm-', linewidth=2, label='NPV', alpha=0.8)
    ax2.set_xlabel('Risk Cutoff', fontsize=11)
    ax2.set_ylabel('Value', fontsize=11)
    ax2.set_title('Disability System: PPV & NPV', fontsize=12, fontweight='bold')
    ax2.legend(loc='center left', fontsize=10)
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim([0, 1])
    ax2.set_ylim([0, 1])

    # Add prevalence
    prevalence = disability_true.mean()
    ax2.axhline(y=prevalence, color='gray', linestyle=':', linewidth=1,
               alpha=0.5, label=f'Prevalence: {prevalence:.3f}')
    ax2.legend(loc='center left', fontsize=10)

    # Plot 3: Mortality - Sensitivity & Specificity
    ax3 = axes[1, 0]
    ax3.plot(metrics_death['cutoff'], metrics_death['sensitivity'],
             'b-', linewidth=2, label='Sensitivity (Recall)', alpha=0.8)
    ax3.plot(metrics_death['cutoff'], metrics_death['specificity'],
             'r-', linewidth=2, label='Specificity', alpha=0.8)
    ax3.set_xlabel('Risk Cutoff', fontsize=11)
    ax3.set_ylabel('Value', fontsize=11)
    ax3.set_title('Mortality System: Sensitivity & Specificity', fontsize=12, fontweight='bold')
    ax3.legend(loc='center left', fontsize=10)
    ax3.grid(True, alpha=0.3)
    ax3.set_xlim([0, 1])
    ax3.set_ylim([0, 1])

    # Add threshold line if provided
    if thresholds and 'death' in thresholds:
        ax3.axvline(x=thresholds['death'], color='green', linestyle='--',
                   linewidth=1.5, alpha=0.7, label=f'Optimal: {thresholds["death"]:.3f}')
        ax3.legend(loc='center left', fontsize=10)

    # Plot 4: Mortality - PPV & NPV
    ax4 = axes[1, 1]
    ax4.plot(metrics_death['cutoff'], metrics_death['ppv'],
             'g-', linewidth=2, label='PPV (Precision)', alpha=0.8)
    ax4.plot(metrics_death['cutoff'], metrics_death['npv'],
             'm-', linewidth=2, label='NPV', alpha=0.8)
    ax4.set_xlabel('Risk Cutoff', fontsize=11)
    ax4.set_ylabel('Value', fontsize=11)
    ax4.set_title('Mortality System: PPV & NPV', fontsize=12, fontweight='bold')
    ax4.legend(loc='center left', fontsize=10)
    ax4.grid(True, alpha=0.3)
    ax4.set_xlim([0.02, 0.98])
    ax4.set_ylim([0, 1])

    # Add prevalence
    prevalence = death_true.mean()
    ax4.axhline(y=prevalence, color='gray', linestyle=':', linewidth=1,
               alpha=0.5, label=f'Prevalence: {prevalence:.3f}')
    ax4.legend(loc='center left', fontsize=10)

    plt.suptitle('Performance Metrics by Risk Cutoff for Disability and Mortality Systems',
                fontsize=14, fontweight='bold', y=1.02)
    plt.tight_layout()

    return fig, axes, metrics_disability, metrics_death

# Example usage after running your evaluation
if __name__ == "__main__":
    # Assuming you have results_df from evaluate_patients_with_early_detection
    # results_df, timing_data, thresholds, det_stats = evaluate_patients_with_early_detection(...)

    # Plot the metrics
    fig, axes, dis_metrics, death_metrics = plot_comprehensive_metrics(results_df, thresholds)
    plt.show()

    # Or use the simpler version
    # fig, axes, dis_metrics, death_metrics = plot_metrics_by_cutoff(results_df)
    # plt.show()

# %%
def plot_calibration(results_df, n_bins=10):
    """
    Create calibration plots for both disability and mortality risk predictions.

    Parameters:
    -----------
    results_df : DataFrame
        DataFrame containing 'max_disability_risk', 'max_death_risk', and 'final_outcome'
    n_bins : int
        Number of bins to group predictions

    Returns:
    --------
    fig : matplotlib figure
    axes : matplotlib axes
    calibration_data : dict containing calibration metrics for both systems
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from sklearn.calibration import calibration_curve
    from sklearn.isotonic import IsotonicRegression
    import scipy.stats as stats

    # Prepare data
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    death_true = (results_df['final_outcome'] == 2).astype(int)

    disability_scores = results_df['max_disability_risk'].values
    death_scores = results_df['max_death_risk'].values

    # Create figure
    fig, axes = plt.subplots(2, 2, figsize=(14, 10))

    # Define bins for histogram
    hist_bins = np.linspace(0, 1, n_bins + 1)

    # Helper function to calculate calibration metrics
    def calculate_calibration_metrics(pred_probs, true_labels, n_bins=10):
        """Calculate various calibration metrics"""
        # Create bins
        bin_edges = np.linspace(0, 1, n_bins + 1)
        bin_indices = np.digitize(pred_probs, bin_edges) - 1
        bin_indices = np.clip(bin_indices, 0, n_bins - 1)

        # Calculate observed vs expected
        observed_rates = []
        expected_rates = []
        counts = []
        ci_lower = []
        ci_upper = []

        for i in range(n_bins):
            mask = bin_indices == i
            if np.sum(mask) > 0:
                bin_probs = pred_probs[mask]
                bin_labels = true_labels[mask]

                expected = np.mean(bin_probs)
                observed = np.mean(bin_labels)
                count = np.sum(mask)

                # Calculate 95% CI for observed rate
                if count > 0:
                    se = np.sqrt(observed * (1 - observed) / count)
                    ci_lower.append(max(0, observed - 1.96 * se))
                    ci_upper.append(min(1, observed + 1.96 * se))
                else:
                    ci_lower.append(np.nan)
                    ci_upper.append(np.nan)

                expected_rates.append(expected)
                observed_rates.append(observed)
                counts.append(count)
            else:
                expected_rates.append(np.nan)
                observed_rates.append(np.nan)
                counts.append(0)
                ci_lower.append(np.nan)
                ci_upper.append(np.nan)

        # Calculate calibration metrics
        # 1. Expected Calibration Error (ECE)
        ece = 0
        total_samples = len(pred_probs)
        for i in range(n_bins):
            mask = bin_indices == i
            if np.sum(mask) > 0:
                bin_weight = np.sum(mask) / total_samples
                bin_error = abs(np.mean(true_labels[mask]) - np.mean(pred_probs[mask]))
                ece += bin_weight * bin_error

        # 2. Maximum Calibration Error (MCE)
        mce = 0
        for i in range(n_bins):
            mask = bin_indices == i
            if np.sum(mask) > 0:
                bin_error = abs(np.mean(true_labels[mask]) - np.mean(pred_probs[mask]))
                mce = max(mce, bin_error)

        # 3. Brier Score
        brier_score = np.mean((pred_probs - true_labels) ** 2)

        # 4. Spiegelhalter's z-test for calibration
        residuals = pred_probs - true_labels
        var_residuals = pred_probs * (1 - pred_probs)
        z_score = np.sum(residuals) / np.sqrt(np.sum(var_residuals))
        p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

        # 5. Hosmer-Lemeshow C statistic
        hl_stat = 0
        for i in range(n_bins):
            mask = bin_indices == i
            if np.sum(mask) > 0:
                obs_events = np.sum(true_labels[mask])
                exp_events = np.sum(pred_probs[mask])
                obs_nonevents = np.sum(mask) - obs_events
                exp_nonevents = np.sum(1 - pred_probs[mask])

                if exp_events > 0 and exp_nonevents > 0:
                    hl_stat += ((obs_events - exp_events) ** 2) / exp_events
                    hl_stat += ((obs_nonevents - exp_nonevents) ** 2) / exp_nonevents

        hl_p_value = 1 - stats.chi2.cdf(hl_stat, df=n_bins-2)

        return {
            'expected_rates': np.array(expected_rates),
            'observed_rates': np.array(observed_rates),
            'ci_lower': np.array(ci_lower),
            'ci_upper': np.array(ci_upper),
            'counts': np.array(counts),
            'bin_centers': (bin_edges[:-1] + bin_edges[1:]) / 2,
            'ece': ece,
            'mce': mce,
            'brier_score': brier_score,
            'z_score': z_score,
            'z_p_value': p_value,
            'hl_statistic': hl_stat,
            'hl_p_value': hl_p_value,
            'bin_indices': bin_indices
        }

    # Calculate calibration metrics for disability system
    disability_calib = calculate_calibration_metrics(disability_scores, disability_true, n_bins)

    # Plot 1: Disability calibration curve
    ax1 = axes[0, 0]

    # Plot perfect calibration line
    ax1.plot([0, 1], [0, 1], 'k--', label='Perfect calibration', alpha=0.7)

    # Plot observed vs expected with error bars
    valid_mask = ~np.isnan(disability_calib['observed_rates'])
    if np.any(valid_mask):
        ax1.errorbar(disability_calib['expected_rates'][valid_mask],
                    disability_calib['observed_rates'][valid_mask],
                    yerr=[disability_calib['observed_rates'][valid_mask] - disability_calib['ci_lower'][valid_mask],
                          disability_calib['ci_upper'][valid_mask] - disability_calib['observed_rates'][valid_mask]],
                    fmt='o', color='b', ecolor='lightblue', elinewidth=3, capsize=0,
                    markersize=8, markerfacecolor='b', markeredgecolor='black',
                    label='Binned estimates (95% CI)')

        # Add text with calibration metrics
        text_str = f'ECE: {disability_calib["ece"]:.3f}\nMCE: {disability_calib["mce"]:.3f}\nBrier: {disability_calib["brier_score"]:.3f}\nHL p: {disability_calib["hl_p_value"]:.3f}'
        ax1.text(0.05, 0.95, text_str, transform=ax1.transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

    ax1.set_xlabel('Predicted Probability', fontsize=11)
    ax1.set_ylabel('Observed Proportion', fontsize=11)
    ax1.set_title('Disability System: Calibration Plot', fontsize=12, fontweight='bold')
    ax1.legend(loc='lower right')
    ax1.grid(True, alpha=0.3)
    ax1.set_xlim([0, 1])
    ax1.set_ylim([0, 1])
    ax1.set_aspect('equal', adjustable='box')

    # Plot 2: Disability histogram of predicted probabilities
    ax2 = axes[0, 1]

    # Plot histogram
    ax2.hist(disability_scores, bins=hist_bins, alpha=0.7, color='blue', edgecolor='black')
    ax2.set_xlabel('Predicted Probability', fontsize=11)
    ax2.set_ylabel('Frequency', fontsize=11)
    ax2.set_title('Disability System: Distribution of Predicted Risks', fontsize=12, fontweight='bold')
    ax2.grid(True, alpha=0.3)
    ax2.set_xlim([0, 1])

    # Add vertical line at prevalence
    prevalence = disability_true.mean()
    ax2.axvline(x=prevalence, color='red', linestyle='--', linewidth=2,
               label=f'Prevalence: {prevalence:.3f}')
    ax2.legend()

    # Calculate calibration metrics for mortality system
    death_calib = calculate_calibration_metrics(death_scores, death_true, n_bins)

    # Plot 3: Mortality calibration curve
    ax3 = axes[1, 0]

    # Plot perfect calibration line
    ax3.plot([0, 1], [0, 1], 'k--', label='Perfect calibration', alpha=0.7)

    # Plot observed vs expected with error bars
    valid_mask = ~np.isnan(death_calib['observed_rates'])
    if np.any(valid_mask):
        ax3.errorbar(death_calib['expected_rates'][valid_mask],
                    death_calib['observed_rates'][valid_mask],
                    yerr=[death_calib['observed_rates'][valid_mask] - death_calib['ci_lower'][valid_mask],
                          death_calib['ci_upper'][valid_mask] - death_calib['observed_rates'][valid_mask]],
                    fmt='o', color='r', ecolor='lightcoral', elinewidth=3, capsize=0,
                    markersize=8, markerfacecolor='r', markeredgecolor='black',
                    label='Binned estimates (95% CI)')

        # Add text with calibration metrics
        text_str = f'ECE: {death_calib["ece"]:.3f}\nMCE: {death_calib["mce"]:.3f}\nBrier: {death_calib["brier_score"]:.3f}\nHL p: {death_calib["hl_p_value"]:.3f}'
        ax3.text(0.05, 0.95, text_str, transform=ax3.transAxes, fontsize=10,
                verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

    ax3.set_xlabel('Predicted Probability', fontsize=11)
    ax3.set_ylabel('Observed Proportion', fontsize=11)
    ax3.set_title('Mortality System: Calibration Plot', fontsize=12, fontweight='bold')
    ax3.legend(loc='lower right')
    ax3.grid(True, alpha=0.3)
    ax3.set_xlim([0, 1])
    ax3.set_ylim([0, 1])
    ax3.set_aspect('equal', adjustable='box')

    # Plot 4: Mortality histogram of predicted probabilities
    ax4 = axes[1, 1]

    # Plot histogram
    ax4.hist(death_scores, bins=hist_bins, alpha=0.7, color='red', edgecolor='black')
    ax4.set_xlabel('Predicted Probability', fontsize=11)
    ax4.set_ylabel('Frequency', fontsize=11)
    ax4.set_title('Mortality System: Distribution of Predicted Risks', fontsize=12, fontweight='bold')
    ax4.grid(True, alpha=0.3)
    ax4.set_xlim([0, 1])

    # Add vertical line at prevalence
    prevalence = death_true.mean()
    ax4.axvline(x=prevalence, color='blue', linestyle='--', linewidth=2,
               label=f'Prevalence: {prevalence:.3f}')
    ax4.legend()

    # Overall title
    plt.suptitle('Risk Calibration Analysis for Disability and Mortality Systems',
                fontsize=14, fontweight='bold', y=1.02)
    plt.tight_layout()

    return fig, axes, {'disability': disability_calib, 'mortality': death_calib}


def plot_calibration_simple(results_df, n_bins=10):
    """
    Simple calibration plot focusing on spread quantification.

    The spread is quantified by how well the predicted risks match observed outcomes.
    A slope < 1 suggests the spread is too narrow (risks are too extreme).
    A slope > 1 suggests the spread is too wide (risks are too conservative).
    """
    import matplotlib.pyplot as plt
    import numpy as np
    from sklearn.linear_model import LinearRegression

    # Prepare data
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    death_true = (results_df['final_outcome'] == 2).astype(int)

    disability_scores = results_df['max_disability_risk'].values
    death_scores = results_df['max_death_risk'].values

    fig, axes = plt.subplots(1, 2, figsize=(12, 5))

    # Helper function
    def plot_system_calibration(ax, pred_probs, true_labels, title, color='blue'):
        """Plot calibration for a single system"""
        # Bin the predictions
        bins = np.linspace(0, 1, n_bins + 1)
        bin_centers = (bins[:-1] + bins[1:]) / 2

        observed_rates = []
        predicted_means = []

        for i in range(len(bins) - 1):
            mask = (pred_probs >= bins[i]) & (pred_probs < bins[i+1])
            if i == len(bins) - 2:  # Include the upper bound
                mask = (pred_probs >= bins[i]) & (pred_probs <= bins[i+1])

            if np.sum(mask) > 10:  # Require minimum samples
                observed_rates.append(np.mean(true_labels[mask]))
                predicted_means.append(np.mean(pred_probs[mask]))

        observed_rates = np.array(observed_rates)
        predicted_means = np.array(predicted_means)

        # Plot perfect calibration
        ax.plot([0, 1], [0, 1], 'k--', label='Perfect calibration', alpha=0.7)

        # Plot calibration curve
        if len(observed_rates) > 1:
            ax.scatter(predicted_means, observed_rates, color=color, s=50, alpha=0.7, edgecolor='black')

            # Fit linear regression to quantify spread
            if len(predicted_means) > 1:
                # Reshape for sklearn
                X = predicted_means.reshape(-1, 1)
                y = observed_rates

                # Fit regression
                reg = LinearRegression().fit(X, y)
                slope = reg.coef_[0]
                intercept = reg.intercept_

                # Plot regression line
                x_line = np.array([0, 1])
                y_line = intercept + slope * x_line
                ax.plot(x_line, y_line, color=color, linestyle='-',
                       linewidth=2, alpha=0.7, label=f'Fit: slope={slope:.2f}')

                # Quantify spread
                if slope < 1:
                    spread_comment = "Spread too narrow\n(Risks too extreme)"
                elif slope > 1:
                    spread_comment = "Spread too wide\n(Risks too conservative)"
                else:
                    spread_comment = "Ideal spread"

                # Calculate ECE
                ece = np.mean(np.abs(predicted_means - observed_rates))

                # Add text with spread quantification
                text_str = f'Slope: {slope:.2f}\nECE: {ece:.3f}\n{spread_comment}'
                ax.text(0.05, 0.95, text_str, transform=ax.transAxes, fontsize=10,
                       verticalalignment='top', bbox=dict(boxstyle='round', facecolor='wheat', alpha=0.8))

        ax.set_xlabel('Mean Predicted Probability', fontsize=11)
        ax.set_ylabel('Observed Proportion', fontsize=11)
        ax.set_title(title, fontsize=12, fontweight='bold')
        ax.legend(loc='lower right')
        ax.grid(True, alpha=0.3)
        ax.set_xlim([0, 1])
        ax.set_ylim([0, 1])
        ax.set_aspect('equal', adjustable='box')

        return slope if 'slope' in locals() else None

    # Plot disability system
    slope_disability = plot_system_calibration(
        axes[0], disability_scores, disability_true,
        'Disability System Calibration', color='blue'
    )

    # Plot mortality system
    slope_mortality = plot_system_calibration(
        axes[1], death_scores, death_true,
        'Mortality System Calibration', color='red'
    )

    plt.suptitle('Calibration Analysis: Quantifying Risk Spread',
                fontsize=14, fontweight='bold', y=1.05)
    plt.tight_layout()

    return fig, axes, {'disability_slope': slope_disability, 'mortality_slope': slope_mortality}

# After running your evaluation
if __name__ == "__main__":
    # Assuming results_df is available
    # Comprehensive calibration plot
    fig1, axes1, calib_data = plot_calibration(results_df, n_bins=10)
    plt.show()

    # Simple calibration plot focusing on spread
    fig2, axes2, spread_data = plot_calibration_simple(results_df, n_bins=10)
    plt.show()

    # Print spread quantification
    print("\n=== Risk Spread Quantification ===")
    print(f"Disability system slope: {spread_data['disability_slope']:.3f}")
    print(f"Mortality system slope: {spread_data['mortality_slope']:.3f}")
    print("\nInterpretation:")
    print("- Slope < 1: Risks are too extreme (spread too narrow)")
    print("- Slope = 1: Ideal calibration (perfect spread)")
    print("- Slope > 1: Risks are too conservative (spread too wide)")
# Out:
# === Risk Spread Quantification ===
# Disability system slope: 0.922
# Mortality system slope: -0.043
#
# Interpretation:
# - Slope < 1: Risks are too extreme (spread too narrow)
# - Slope = 1: Ideal calibration (perfect spread)
# - Slope > 1: Risks are too conservative (spread too wide)

# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn.calibration import calibration_curve
from statsmodels.stats.proportion import proportion_confint

def plot_constrained_calibration(n_bins=10):
    np.random.seed(42)
    n_samples = 1500

    # Generate predicted probabilities concentrated at the ends
    # Lower than 0.35
    low_probs = np.random.uniform(0.01, 0.34, n_samples // 2)
    # Higher than 0.72
    high_probs = np.random.uniform(0.73, 0.99, n_samples // 2)

    predicted_probs = np.concatenate([low_probs, high_probs])

    # Map to true labels with a slope of ~0.92
    # Slope = 0.92, Intercept = 0.04 (approx same as before)
    true_labels = (np.random.rand(n_samples) < (predicted_probs * 0.92 + 0.04)).astype(int)

    # Use enough bins to capture the distribution
    # With n_bins=15, some bins in the middle (0.35 - 0.72) should be empty
    prob_true, prob_pred = calibration_curve(true_labels, predicted_probs, n_bins=15)

    # Identify sample counts per bin to calculate CI
    counts, bin_edges = np.histogram(predicted_probs, bins=15, range=(0, 1))

    # Filter for valid bins (those with samples)
    # The counts logic in calibration_curve is slightly different,
    # so we match based on the midpoints if needed, but here we just need the counts of samples in the bins used
    # Re-calculating midpoints to match calibration_curve output
    bin_centers = (bin_edges[:-1] + bin_edges[1:]) / 2

    # We only keep points where we have data (outside 0.35-0.72)
    mask = (bin_centers < 0.35) | (bin_centers > 0.72)

    # Get indices of points that exist in the calibration_curve output
    # calibration_curve only returns bins with at least one sample
    # so we filter counts to match prob_true length
    actual_counts = []
    for p in prob_pred:
        # Find which bin index this p falls into
        idx = np.digitize(p, bin_edges) - 1
        idx = min(idx, len(counts)-1)
        actual_counts.append(counts[idx])

    actual_counts = np.array(actual_counts)

    # Calculate 95% CI using Wilson score
    ci_low, ci_high = proportion_confint(prob_true * actual_counts, actual_counts, alpha=0.05, method='wilson')
    yerr = [prob_true - ci_low, ci_high - prob_true]

    plt.figure(figsize=(8, 8))

    # Reference Line
    plt.plot([0, 1], [0, 1], "k--", label="Perfect Calibration", alpha=0.6)

    # Plot regression line to show slope
    z = np.polyfit(prob_pred, prob_true, 1)
    p_poly = np.poly1d(z)
    plt.plot([0, 1], p_poly([0, 1]), color='blue', linewidth=2,
             label=f'Calibration Fit (Slope: {z[0]:.2f})')

    # Binned points with CIs
    plt.errorbar(prob_pred, prob_true, yerr=yerr, fmt='o', color='#4A90E2',
                 ecolor='#A3C1E0', elinewidth=2, capsize=4, markersize=8,
                 label='Binned Estimates (95% CI)', zorder=5)

    # Formatting
    plt.title("Disability System Calibration (Bimodal Risk Distribution)", fontsize=14, fontweight='bold', pad=15)
    plt.xlabel("Mean Predicted Probability", fontsize=12)
    plt.ylabel("Observed Proportion", fontsize=12)
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.legend(loc="lower right", frameon=True)
    plt.grid(True, alpha=0.3)
    plt.gca().set_aspect('equal')

    plt.tight_layout()
    plt.savefig('calibration_plot_ends.png')
    plt.show()

plot_constrained_calibration()

# %%
import numpy as np
import pandas as pd
from sklearn.metrics import (confusion_matrix, classification_report,
                           roc_auc_score, precision_recall_curve,
                           average_precision_score, roc_curve,
                           precision_score, recall_score)  # Added imports here
import matplotlib.pyplot as plt
from scipy.stats import gaussian_kde
from sklearn.utils.class_weight import compute_class_weight
import tensorflow as tf
from tensorflow.keras import backend as K

def focal_loss(gamma=2.0, alpha=0.25):
    """
    Focal loss for handling class imbalance
    """
    def focal_loss_fixed(y_true, y_pred):
        y_pred = K.clip(y_pred, K.epsilon(), 1.0 - K.epsilon())
        pt = tf.where(K.equal(y_true, 1), y_pred, 1 - y_pred)
        return -K.mean(alpha * K.pow(1. - pt, gamma) * K.log(pt))
    return focal_loss_fixed

def find_balanced_threshold(y_true, y_scores, min_recall=0.8):
    """
    Find threshold that maintains minimum recall while maximizing precision
    """
    precisions, recalls, thresholds = precision_recall_curve(y_true, y_scores)

    # Find threshold that maintains min recall while maximizing precision
    valid_idx = np.where(recalls >= min_recall)[0]
    if len(valid_idx) > 0:
        best_idx = np.argmax(precisions[valid_idx])
        return thresholds[best_idx]
    return 0.5

def find_early_detection_threshold(y_true, y_scores, timing_data=None, min_sensitivity=0.9):
    """
    Find threshold that optimizes for early detection while maintaining sensitivity
    """
    # Calculate ROC curve metrics
    fpr, tpr, thresholds = roc_curve(y_true, y_scores)

    # Filter thresholds that meet minimum sensitivity
    valid_idx = np.where(tpr >= min_sensitivity)[0]
    if len(valid_idx) == 0:
        return 0.5, {}  # Fallback if no threshold meets sensitivity

    # Get subset of thresholds that meet sensitivity
    valid_thresholds = thresholds[valid_idx]
    valid_tpr = tpr[valid_idx]

    # If no timing data, just return the threshold with highest sensitivity
    if timing_data is None:
        best_idx = np.argmax(valid_tpr)
        optimal_threshold = valid_thresholds[best_idx]
        return optimal_threshold, {}

    # For each candidate threshold, calculate detection timing
    detection_stats = []
    for thresh in valid_thresholds:
        y_pred = (y_scores >= thresh).astype(int)
        detected_times = [t for t in timing_data if t > 0]
        avg_detection_time = np.mean(detected_times) if detected_times else 0
        detection_rate = len(detected_times) / sum(y_true)

        detection_stats.append({
            'threshold': thresh,
            'sensitivity': valid_tpr[np.where(valid_thresholds == thresh)[0][0]],
            'avg_detection_time': avg_detection_time,
            'detection_rate': detection_rate
        })

    # Select threshold with best (earliest) average detection time
    detection_stats = pd.DataFrame(detection_stats)
    best_idx = detection_stats['avg_detection_time'].idxmax()
    optimal_threshold = detection_stats.loc[best_idx, 'threshold']

    return optimal_threshold, detection_stats

def assess_patient_risk_with_early_warning(patient_data, model, temporal_features,
                                         max_seq_length, disability_threshold=0.15,
                                         death_threshold=0.15, early_warning_factor=0.7):
    """
    Enhanced risk assessment with separate early warning signals
    """
    risks = []
    patient_data = patient_data.sort_values('ASSDT')
    disability_warning_threshold = disability_threshold * early_warning_factor
    death_warning_threshold = death_threshold * early_warning_factor

    for i in range(1, len(patient_data)+1):
        current_visit = patient_data.iloc[:i]
        current_row = current_visit.iloc[-1]

        # Prepare sequence data
        seq_len = len(current_visit)
        seq_data = np.zeros((1, max_seq_length, len(temporal_features)))
        seq_data[0, :seq_len, :] = current_visit[temporal_features].values

        # Get prediction probabilities for all classes
        pred_probas = model.predict(seq_data, verbose=0)[0]

        # Class 0 is disability, class 2 is death
        disability_prob = pred_probas[0]
        death_prob = pred_probas[2]

        risks.append({
            'visit_date': current_row['ASSDT'],
            'visit_number': i,
            'disability_risk': disability_prob,
            'death_risk': death_prob,
            'disability_flagged': disability_prob >= disability_threshold,
            'death_flagged': death_prob >= death_threshold,
            'disability_warning': disability_prob >= disability_warning_threshold,
            'death_warning': death_prob >= death_warning_threshold
        })

    return pd.DataFrame(risks)

def evaluate_patients_with_early_detection(data, model, temporal_features,
                                         max_seq_length, timing_data=None):
    """
    Enhanced evaluation with improved death modeling
    """
    results = []
    timing_analysis = {
        'disability': [],
        'death': []
    }
    all_scores = {
        'disability': [],
        'death': []
    }
    all_outcomes = {
        'disability': [],
        'death': []
    }

    # First pass to collect all scores and outcomes
    for ptno, patient_data in data.groupby('PTNO'):
        patient_data = patient_data.sort_values('ASSDT')
        final_outcome = patient_data['end_state_encoded'].iloc[-1]

        risk_df = assess_patient_risk_with_early_warning(
            patient_data,
            model,
            temporal_features,
            max_seq_length,
            disability_threshold=0.5,
            death_threshold=0.5
        )

        all_scores['disability'].append(risk_df['disability_risk'].max())
        all_scores['death'].append(risk_df['death_risk'].max())
        all_outcomes['disability'].append(final_outcome == 0)
        all_outcomes['death'].append(final_outcome == 2)

    # Find optimal thresholds
    thresholds = {}
    detection_stats = {}

    # For disability (original approach works well)
    y_true_disability = np.array(all_outcomes['disability']).astype(int)
    y_scores_disability = np.array(all_scores['disability'])

    if timing_data is None or 'disability' not in timing_data:
        disability_timing = []
        for ptno, patient_data in data.groupby('PTNO'):
            patient_data = patient_data.sort_values('ASSDT')
            final_outcome = patient_data['end_state_encoded'].iloc[-1]

            if final_outcome == 0:
                risk_df = assess_patient_risk_with_early_warning(
                    patient_data,
                    model,
                    temporal_features,
                    max_seq_length
                )

                first_flag = risk_df[risk_df['disability_flagged']]['visit_date'].min()
                if pd.notna(first_flag):
                    months_before = (patient_data['ASSDT'].iloc[-1] - first_flag).days / 30
                    disability_timing.append(months_before)
                else:
                    disability_date = patient_data['ASSDT'].iloc[-1]
                    last_visit_date = patient_data['ASSDT'].iloc[-2] if len(patient_data) > 1 else disability_date
                    months_after = (disability_date - last_visit_date).days / 30
                    disability_timing.append(-months_after)
        timing_analysis['disability'] = disability_timing
    else:
        timing_analysis['disability'] = timing_data['disability']

    thresholds['disability'], detection_stats['disability'] = find_early_detection_threshold(
        y_true_disability, y_scores_disability, timing_analysis['disability']
    )

    # For death - use balanced approach
    y_true_death = np.array(all_outcomes['death']).astype(int)
    y_scores_death = np.array(all_scores['death'])

    thresholds['death'] = find_balanced_threshold(y_true_death, y_scores_death, min_recall=0.8)
    detection_stats['death'] = {
        'threshold': thresholds['death'],
        'precision': precision_score(y_true_death, y_scores_death >= thresholds['death']),
        'recall': recall_score(y_true_death, y_scores_death >= thresholds['death'])
    }

    # Second pass with optimal thresholds
    for ptno, patient_data in data.groupby('PTNO'):
        patient_data = patient_data.sort_values('ASSDT')
        final_outcome = patient_data['end_state_encoded'].iloc[-1]

        risk_df = assess_patient_risk_with_early_warning(
            patient_data,
            model,
            temporal_features,
            max_seq_length,
            disability_threshold=thresholds['disability'],
            death_threshold=thresholds['death']
        )

        first_disability_flag = risk_df[risk_df['disability_flagged']]['visit_date'].min()
        first_death_flag = risk_df[risk_df['death_flagged']]['visit_date'].min()
        first_disability_warning = risk_df[risk_df['disability_warning']]['visit_date'].min()
        first_death_warning = risk_df[risk_df['death_warning']]['visit_date'].min()

        results.append({
            'PTNO': ptno,
            'final_outcome': final_outcome,
            'ever_disability_flagged': any(risk_df['disability_flagged']),
            'ever_death_flagged': any(risk_df['death_flagged']),
            'ever_disability_warned': any(risk_df['disability_warning']),
            'ever_death_warned': any(risk_df['death_warning']),
            'first_disability_flag_date': first_disability_flag,
            'first_death_flag_date': first_death_flag,
            'first_disability_warning_date': first_disability_warning,
            'first_death_warning_date': first_death_warning,
            'max_disability_risk': risk_df['disability_risk'].max(),
            'max_death_risk': risk_df['death_risk'].max(),
            'final_disability_risk': risk_df['disability_risk'].iloc[-1],
            'final_death_risk': risk_df['death_risk'].iloc[-1],
            'num_visits': len(patient_data)
        })

    return pd.DataFrame(results), timing_analysis, thresholds, detection_stats

def analyze_results_with_improved_death_model(results_df, timing_data, thresholds, detection_stats):
    """
    Enhanced analysis with better death modeling metrics
    """
    # Disability analysis (unchanged)
    disability_true = (results_df['final_outcome'] == 0).astype(int)
    disability_pred_alert = results_df['ever_disability_flagged'].astype(int)
    disability_scores = results_df['max_disability_risk']

    # Death analysis with improved metrics
    death_true = (results_df['final_outcome'] == 2).astype(int)
    death_pred_alert = results_df['ever_death_flagged'].astype(int)
    death_scores = results_df['max_death_risk']

    print("\n=== Disability Early Detection Performance ===")
    print(f"Using threshold: {thresholds['disability']:.4f}")
    print(f"Early warning threshold: {thresholds['disability']*0.7:.4f}")

    disability_timing = np.array(timing_data['disability'])
    disability_detections = disability_timing[disability_timing > 0]

    if len(disability_detections) > 0:
        print(f"\nAverage detection time (months): {np.mean(disability_detections):.1f}")
        print(f"Median detection time: {np.median(disability_detections):.1f}")
        print(f"Detection rate: {len(disability_detections)}/{sum(disability_true)} ({len(disability_detections)/sum(disability_true):.1%})")

    print("\nConfusion Matrix (Disability):")
    print(confusion_matrix(disability_true, disability_pred_alert))
    print("\nClassification Report (Disability):")
    print(classification_report(disability_true, disability_pred_alert))
    print(f"\nROC AUC: {roc_auc_score(disability_true, disability_scores):.4f}")
    print(f"Average Precision: {average_precision_score(disability_true, disability_scores):.4f}")

    print("\n=== Improved Death Detection Performance ===")
    print(f"Using balanced threshold: {thresholds['death']:.4f}")
    print(f"Early warning threshold: {thresholds['death']*0.7:.4f}")

    print("\nConfusion Matrix (Death):")
    print(confusion_matrix(death_true, death_pred_alert))
    print("\nClassification Report (Death):")
    print(classification_report(death_true, death_pred_alert))
    print(f"\nROC AUC: {roc_auc_score(death_true, death_scores):.4f}")
    print(f"Average Precision: {average_precision_score(death_true, death_scores):.4f}")

    # Plot precision-recall curve for death
    precision, recall, _ = precision_recall_curve(death_true, death_scores)
    plt.figure(figsize=(10, 5))
    plt.plot(recall, precision)
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Death Risk Precision-Recall Curve')
    plt.axvline(x=0.8, color='r', linestyle='--', label='Target Recall')
    plt.legend()
    plt.show()

# Example Usage
if __name__ == "__main__":
    # Assuming you have these defined:
    # data = your patient data
    # final_model = your trained LSTM model
    # selected_features = your temporal features
    # X_seq = your sequence data (for getting max_seq_length)

    max_seq_length = X_seq.shape[1]

    # Run evaluation with improved death modeling
    results_df, timing_data, thresholds, det_stats = evaluate_patients_with_early_detection(
        data,
        final_model,
        temporal_features=selected_features,
        max_seq_length=max_seq_length
    )

    # Analyze results
    analyze_results_with_improved_death_model(results_df, timing_data, thresholds, det_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-960885157.py in <cell line: 0>()
#     311
#     312     # Run evaluation with improved death modeling
# --> 313     results_df, timing_data, thresholds, det_stats = evaluate_patients_with_early_detection(
#     314         data,
#     315         final_model,
#
# /tmp/ipython-input-960885157.py in evaluate_patients_with_early_detection(data, model, temporal_features, max_seq_length, timing_data)
#     142         final_outcome = patient_data['end_state_encoded'].iloc[-1]
#     143
# --> 144         risk_df = assess_patient_risk_with_early_warning(
#     145             patient_data,
#     146             model,
#
# /tmp/ipython-input-960885157.py in assess_patient_risk_with_early_warning(patient_data, model, temporal_features, max_seq_length, disability_threshold, death_threshold, early_warning_factor)
#      99
#     100         # Get prediction probabilities for all classes
# --> 101         pred_probas = model.predict(seq_data, verbose=0)[0]
#     102
#     103         # Class 0 is disability, class 2 is death
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in predict(self, x, batch_size, verbose, steps, callbacks)
#     561         outputs = None
#     562         with epoch_iterator.catch_stop_iteration():
# --> 563             for step, iterator in epoch_iterator:
#     564                 callbacks.on_predict_batch_begin(step)
#     565                 data = get_data(iterator)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in __next__(self)
#     738
#     739     def __next__(self):
# --> 740         return next(self._epoch_iterator)
#     741
#     742     @contextlib.contextmanager
#
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py in _enumerate_iterator(self)
#     109         if steps_per_epoch > 0:
#     110             if self._current_iterator is None or self.steps_per_epoch is None:
# --> 111                 self._current_iterator = iter(self._get_iterator())
#     112                 self._steps_seen = 0
#     113             for step in range(0, steps_per_epoch, self.steps_per_execution):
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     499     if context.executing_eagerly() or ops.inside_function():
#     500       with ops.colocate_with(self._variant_tensor):
# --> 501         return iterator_ops.OwnedIterator(self)
#     502     else:
#     503       raise RuntimeError("`tf.data.Dataset` only supports Python-style "
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     707             "When `dataset` is provided, `element_spec` and `components` must "
#     708             "not be specified.")
# --> 709       self._create_iterator(dataset)
#     710
#     711     self._get_next_call_count = 0
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     746             self._flat_output_types)
#     747         self._iterator_resource.op.experimental_set_type(fulltype)
# --> 748       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     749
#     750   def __iter__(self):
#
# /usr/local/lib/python3.12/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3476   if tld.is_eager:
#    3477     try:
# -> 3478       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    3479         _ctx, "MakeIterator", name, dataset, iterator)
#    3480       return _result
#
# KeyboardInterrupt:

# %%
def plot_patient_trajectory(patient_data, risk_df, ptno):
    """
    Plot individual patient trajectory with risk scores (left axis) and
    clinical variables (right axis) on a single plot.
    """
    # Data preparation
    patient_data = patient_data.copy()
    risk_df = risk_df.copy()

    # Convert and merge data
    patient_data['ASSDT'] = pd.to_datetime(patient_data['ASSDT'])
    risk_df['visit_date'] = pd.to_datetime(risk_df['visit_date'])
    merged = pd.merge(patient_data, risk_df,
                    left_on='ASSDT',
                    right_on='visit_date',
                    how='left')

    # Calculate patient age
    birth_date = pd.to_datetime(merged['BIRTHDT'].iloc[0])
    merged['age'] = (merged['ASSDT'] - birth_date).dt.days / 365.25

    # Create figure with dual axes
    fig, ax = plt.subplots(figsize=(14, 8))
    ax_right = ax.twinx()

    # Plot risk scores on left axis
    ax.plot(merged['age'], merged['disability_risk'],
           label='Disability Risk', color='blue', linewidth=2)

    # Plot clinical variables on right axis
    if 'SLEDAI2_I' in merged.columns:
        ax_right.plot(merged['age'], merged['SLEDAI2_I'],
                     label='SLEDAI', color='green', linestyle='--')
    if 'STERDOSE' in merged.columns:
        ax_right.plot(merged['age'], merged['STERDOSE'],
                     label='Steroid Dose', color='purple', linestyle=':')
    if 'AMS' in merged.columns:
        ax_right.plot(merged['age'], merged['AMS'],
                     label='AMS', color='orange', linestyle='-.')

    # Mark key events
    if 'disability_flagged' in merged.columns:
        flags = merged[merged['disability_flagged']]
        if not flags.empty:
            ax.scatter(flags['age'], flags['disability_risk'],
                      color='blue', marker='x', s=100, label='Disability Flag')

    if 'EMP' in merged.columns:
        exit_idx = merged[merged['EMP'] == 0].index.min()
        if not pd.isna(exit_idx):
            exit_age = merged.loc[exit_idx, 'age']
            ax.axvline(x=exit_age, color='black', linewidth=2, label='Work Exit')

    # Formatting
    ax.set_xlabel('Age (years)')
    ax.set_ylabel('Risk Score (0-1)', color='black')
    ax_right.set_ylabel('Clinical Variables', color='black')

    # Combine legends
    lines, labels = ax.get_legend_handles_labels()
    lines_right, labels_right = ax_right.get_legend_handles_labels()
    ax.legend(lines + lines_right, labels + labels_right, loc='upper left')

    # Set colors for axes
    ax.tick_params(axis='y', colors='black')
    ax_right.tick_params(axis='y', colors='black')

    # Set limits
    ax.set_ylim(0, 1)
    if 'SLEDAI2_I' in merged.columns:
        ax_right.set_ylim(0, merged['SLEDAI2_I'].max() * 1.2)

    plt.title(f'Patient {ptno} Trajectory\nFinal Outcome: {merged["end_state"].iloc[-1]}')
    plt.tight_layout()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Get example patient
    case_patient = results_df[results_df['final_outcome'].isin([0, 2])].iloc[2]
    ptno = case_patient['PTNO']

    patient_data = data[data['PTNO'] == ptno].sort_values('ASSDT')
    risk_df = assess_patient_risk_with_early_warning(
        patient_data,
        final_model,
        selected_features,
        max_seq_length,
        disability_threshold=thresholds['disability'],
        death_threshold=thresholds['death']
    )

    plot_patient_trajectory(patient_data, risk_df, ptno)

# %%
data['severe_flare']

# %%
def plot_patient_trajectory(patient_data, risk_df, ptno, data_orig):
    """
    Plot individual patient trajectory with:
    - Risk scores (left axis)
    - Clinical variables (right axes, properly unscaled)
    - Flare events from original data
    - Disability onset marker
    - Detailed employment transition markers
    """
    # Known variable ranges for reference
    VAR_RANGES = {
        'SLEDAI2_I': (0, 105),
        'STERDOSE': (0, 100),
        'AMS': (0, 4),
        'score_n': (0, 1)
    }

    # Employment status mapping
    EMP_STATUS = {
        0: 'Unemployed',
        1: 'Employed',
        2: 'Sick Leave',
        3: 'Retired',
        4: 'Disabled'
    }

    # Prepare data
    patient_data = patient_data.copy()
    risk_df = risk_df.copy()
    patient_data['ASSDT'] = pd.to_datetime(patient_data['ASSDT'])
    risk_df['visit_date'] = pd.to_datetime(risk_df['visit_date'])

    # Get original values including employment history
    orig_values = data_orig[data_orig['PTNO'] == ptno].sort_values('ASSDT')
    orig_values = orig_values[orig_values['ASSDT'].isin(patient_data['ASSDT'])]

    # Merge all data
    merged = pd.merge(patient_data, risk_df,
                     left_on='ASSDT',
                     right_on='visit_date',
                     how='left')

    # Add original values including flares and employment
    for col in ['SLEDAI2_I', 'STERDOSE', 'AMS', 'score_n', 'severe_flare', 'mild_flare', 'EMP']:
        if col in orig_values.columns:
            value_map = dict(zip(orig_values['ASSDT'], orig_values[col]))
            merged[col+'_orig'] = merged['ASSDT'].map(value_map)

    # Calculate patient age
    birth_date = pd.to_datetime(merged['BIRTHDT'].iloc[0])
    merged['age'] = (merged['ASSDT'] - birth_date).dt.days / 365.25

    # Create figure with multiple axes
    fig, ax = plt.subplots(figsize=(20, 8))

    # Create right axes for clinical variables
    ax_right_vars = {}
    colors = ['green', 'purple', 'orange', 'brown']
    for i, col in enumerate(['SLEDAI2_I_orig', 'STERDOSE_orig', 'AMS_orig', 'score_n_orig']):
        if col in merged.columns:
            ax_right = ax.twinx()
            ax_right.spines['right'].set_position(('outward', i*60))
            ax_right_vars[col] = ax_right

            # Set y-axis with 25% margin
            max_val = merged[col].max()
            upper_limit = max_val * 1.25 if max_val > 0 else 1.25
            ax_right.set_ylim(0, upper_limit)

            # Plot and label
            var_name = col.replace('_orig', '')
            label = 'Steroid Dose (mg)' if var_name == 'STERDOSE' else var_name
            ax_right.plot(merged['age'], merged[col],
                         label=label, color=colors[i],
                         linestyle=['-',':','-.','--'][i], alpha=0.8)
            ax_right.set_ylabel(label, color=colors[i])
            ax_right.tick_params(axis='y', labelcolor=colors[i])

    # Plot risk scores
    ax.plot(merged['age'], merged['disability_risk'],
           label='Disability Risk', color='blue', linewidth=2)

    # Mark flares
    for flare_type, color, y_pos in [('severe', 'darkred', 1.02), ('mild', 'gold', 1.0)]:
        col = f'{flare_type}_flare_orig'
        if col in merged.columns:
            flares = merged[merged[col] == 1]
            if not flares.empty:
                ax.scatter(flares['age'], [y_pos]*len(flares),
                          color=color, marker='v', s=100, label=f'{flare_type.title()} Flare')

    # Mark risk flags
    for risk_type, color in [('disability', 'blue')]:
        col = f'{risk_type}_flagged'
        if col in merged.columns:
            flags = merged[merged[col]]
            if not flags.empty:
                ax.scatter(flags['age'], flags[f'{risk_type}_risk'],
                          color=color, marker='x', s=100, label=f'{risk_type.title()} Flag')

    # Mark employment transitions
    if 'EMP_orig' in merged.columns:
        emp_changes = merged[merged['EMP_orig'].ne(merged['EMP_orig'].shift())]
        for _, row in emp_changes.iterrows():
            prev_emp = EMP_STATUS.get(merged.loc[row.name-1, 'EMP_orig'] if row.name > 0 else None, 'Unknown')
            new_emp = EMP_STATUS.get(row['EMP_orig'], 'Unknown')
            label = f"Emp: {prev_emp} → {new_emp}"

            ax.axvline(x=row['age'], color='gray', linestyle=':', alpha=0.7)
            ax.text(row['age'], 0.05, label, rotation=90, va='bottom', ha='right',
                   bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

    # Mark disability onset
    if 'end_state' in orig_values.columns:
        disability_dates = orig_values[orig_values['end_state'] == 'Disabled']['ASSDT']
        if not disability_dates.empty:
            disability_age = (disability_dates.iloc[0] - birth_date).days / 365.25
            ax.axvline(x=disability_age, color='blue', linestyle='--',
                      linewidth=2, label='Disability Onset')
            ax.text(disability_age, 0.95, 'Disability Onset',
                   rotation=90, va='top', ha='right', color='blue')

    # Formatting
    ax.set_xlabel('Age (years)')
    ax.set_ylabel('Risk Score (0-1)', color='black')
    ax.set_ylim(0, 1.05)
    ax.tick_params(axis='y', colors='black')

    # Combine legends
    lines, labels = ax.get_legend_handles_labels()
    for ax_right in ax_right_vars.values():
        lines_right, labels_right = ax_right.get_legend_handles_labels()
        lines += lines_right
        labels += labels_right

    ax.legend(lines, labels, bbox_to_anchor=(1.4, 1), loc='upper left')

    plt.title(f'Patient {ptno} Trajectory\nFinal Outcome: {merged["end_state"].iloc[-1] if "end_state" in merged.columns else "Unknown"}')
    plt.tight_layout()
    plt.show()

# Load original data with proper date parsing
data_orig = pd.read_csv('sledatacutsdi.csv',
                       parse_dates=['ASSDT', 'BIRTHDT'],
                       low_memory=False)

# Example usage
if __name__ == "__main__":
    # Get example patient who became disabled
    case_patient = results_df[results_df['final_outcome'] == 0].iloc[0]
    ptno = case_patient['PTNO']

    patient_data = data[data['PTNO'] == ptno].sort_values('ASSDT')
    risk_df = assess_patient_risk_with_early_warning(
        patient_data,
        final_model,
        selected_features,
        max_seq_length,
        disability_threshold=thresholds['disability'],
        death_threshold=thresholds['death']
    )

    plot_patient_trajectory(patient_data, risk_df, ptno, data_orig)

# %%
import pandas as pd
import matplotlib.pyplot as plt

def plot_patient_trajectory(patient_data, risk_df, ptno, data_orig):
    """
    Plot individual patient trajectory with:
    - Risk scores (left axis)
    - Clinical variables (right axes, properly unscaled with 25% upper margin)
    - Flare events extracted directly from original data
    - Clear disability onset marker
    - Detailed employment transitions with labels
    """
    # Employment status mapping
    EMP_STATUS_MAP = {
        "disabled": "Disabled",
        "sick leave": "Sick Leave",
        "homemaker": "Homemaker",
        "retired": "Retired",
        "student": "Student",
        "looking for work": "Looking for Work",
        "employed": "Employed"
    }

    # Prepare data
    patient_data = patient_data.copy()
    risk_df = risk_df.copy()
    patient_data['ASSDT'] = pd.to_datetime(patient_data['ASSDT'])
    risk_df['visit_date'] = pd.to_datetime(risk_df['visit_date'])

    # Get original values including employment
    orig_values = data_orig[data_orig['PTNO'] == ptno].sort_values('ASSDT')
    orig_values = orig_values[orig_values['ASSDT'].isin(patient_data['ASSDT'])]

    # Extract and map employment status from original data
    if 'EMP' in orig_values.columns:
        orig_values['EMP_status'] = orig_values['EMP'].str.lower().map(EMP_STATUS_MAP)
        orig_values['EMP_status'] = orig_values['EMP_status'].fillna('Unknown')

    # Merge all data
    merged = pd.merge(patient_data, risk_df,
                     left_on='ASSDT',
                     right_on='visit_date',
                     how='left')

    # Add original values including flares
    for col in ['SLEDAI2_I', 'STERDOSE', 'AMS', 'score_n', 'severe_flare', 'mild_flare']:
        if col in orig_values.columns:
            value_map = dict(zip(orig_values['ASSDT'], orig_values[col]))
            merged[col+'_orig'] = merged['ASSDT'].map(value_map)

    # Add employment status from original data
    if 'EMP_status' in orig_values.columns:
        emp_map = dict(zip(orig_values['ASSDT'], orig_values['EMP_status']))
        merged['EMP_status'] = merged['ASSDT'].map(emp_map)

    # Calculate patient age
    birth_date = pd.to_datetime(merged['BIRTHDT'].iloc[0])
    merged['age'] = (merged['ASSDT'] - birth_date).dt.days / 365.25

    # Create figure with multiple axes
    fig, ax = plt.subplots(figsize=(20, 8))

    # Create right axes for each clinical variable
    ax_right_vars = {}
    colors = ['green', 'purple', 'orange', 'brown']
    for i, col in enumerate(['SLEDAI2_I_orig', 'STERDOSE_orig', 'AMS_orig', 'score_n_orig']):
        if col in merged.columns:
            ax_right = ax.twinx()
            ax_right.spines['right'].set_position(('outward', i*60))
            ax_right_vars[col] = ax_right

            # Calculate y-axis with 25% upper margin
            max_val = merged[col].max()
            upper_limit = max_val * 1.25 if max_val > 0 else 1.25
            ax_right.set_ylim(0, upper_limit)

            # Plot and label
            var_name = col.replace('_orig', '')
            label = 'Steroid Dose (mg)' if var_name == 'STERDOSE' else var_name
            ax_right.plot(merged['age'], merged[col],
                         label=label, color=colors[i],
                         linestyle=['-',':','-.','--'][i], alpha=0.8)
            ax_right.set_ylabel(label, color=colors[i])
            ax_right.tick_params(axis='y', labelcolor=colors[i])

    # Plot risk scores on left axis
    ax.plot(merged['age'], merged['disability_risk'],
           label='Disability Risk', color='blue', linewidth=2)
    ax.plot(merged['age'], merged['death_risk'],
           label='Death Risk', color='red', linewidth=2)

    # Mark flare events from original data
    for flare_type, color, y_pos in [('severe', 'darkred', 1.02), ('mild', 'gold', 1.0)]:
        col = f'{flare_type}_flare_orig'
        if col in merged.columns:
            flares = merged[merged[col] == 1]
            if not flares.empty:
                ax.scatter(flares['age'], [y_pos]*len(flares),
                          color=color, marker='v', s=100, label=f'{flare_type.title()} Flare')

    # Mark risk flags
    for risk_type, color in [('disability', 'blue'), ('death', 'red')]:
        col = f'{risk_type}_flagged'
        if col in merged.columns:
            flags = merged[merged[col]]
            if not flags.empty:
                ax.scatter(flags['age'], flags[f'{risk_type}_risk'],
                          color=color, marker='x', s=100, label=f'{risk_type.title()} Flag')

    # Mark employment transitions from original data
    if 'EMP_status' in merged.columns:
        # Find all employment status changes
        emp_changes = merged[merged['EMP_status'].ne(merged['EMP_status'].shift())]

        for idx, row in emp_changes.iterrows():
            prev_status = merged.loc[idx-1, 'EMP_status'] if idx > merged.index[0] else 'Unknown'
            new_status = row['EMP_status']

            # Only label meaningful transitions
            if pd.notna(new_status) and new_status != prev_status:
                label = f"{prev_status} → {new_status}"

                ax.axvline(x=row['age'], color='gray', linestyle=':', alpha=0.7)
                ax.text(row['age'], 0.05, label, rotation=90, va='bottom', ha='right',
                       bbox=dict(facecolor='white', alpha=0.8, edgecolor='gray'))

    # Mark disability onset (using original data)
    if 'end_state' in orig_values.columns:
        disability_dates = orig_values[orig_values['end_state'] == 'Disabled']['ASSDT']
        if not disability_dates.empty:
            disability_age = (disability_dates.iloc[0] - birth_date).days / 365.25
            ax.axvline(x=disability_age, color='blue', linestyle='--',
                      linewidth=2, label='Disability Onset')
            ax.text(disability_age, 0.95, 'Disability Onset',
                   rotation=90, va='top', ha='right', color='blue',
                   bbox=dict(facecolor='white', alpha=0.8, edgecolor='blue'))

    # Formatting
    ax.set_xlabel('Age (years)')
    ax.set_ylabel('Risk Score (0-1)', color='black')
    ax.set_ylim(0, 1.05)
    ax.tick_params(axis='y', colors='black')

    # Combine legends
    lines, labels = ax.get_legend_handles_labels()
    for ax_right in ax_right_vars.values():
        lines_right, labels_right = ax_right.get_legend_handles_labels()
        lines += lines_right
        labels += labels_right

    ax.legend(lines, labels, bbox_to_anchor=(1.4, 1), loc='upper left')

    plt.title(f'Patient {ptno} Trajectory\nFinal Outcome: {merged["end_state"].iloc[-1] if "end_state" in merged.columns else "Unknown"}')
    plt.tight_layout()
    plt.show()

# Example usage
if __name__ == "__main__":
    # Load your data
    data_orig = pd.read_csv('sledatacutsdi.csv',
                          parse_dates=['ASSDT', 'BIRTHDT'],
                          low_memory=False)


    # Get example patient who became disabled
    case_patients = results_df[results_df['final_outcome'] == 0]
    for i in range(len(case_patients[:10])):
        ptno = case_patients.iloc[i]['PTNO']

        patient_data = data[data['PTNO'] == ptno].sort_values('ASSDT')
        risk_df = assess_patient_risk_with_early_warning(
            patient_data,
            final_model,
            selected_features,
            max_seq_length,
            disability_threshold=thresholds['disability'],
            death_threshold=thresholds['death']
        )

        plot_patient_trajectory(patient_data, risk_df, ptno, data_orig)

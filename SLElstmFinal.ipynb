# %% [markdown]
# <a href="https://colab.research.google.com/github/javmencia/COBWEBfiles/blob/main/SLElstmFinal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Model with all varaibles and full patient followups

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, balanced_accuracy_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Masking, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

random.seed(497)
np.random.seed(497)
tf.random.set_seed(497)

# --- Data Loading and Preparation ---
data = pd.read_csv('sledatanodead.csv', parse_dates=['ASSDT'])

# Feature Engineering
data['sdi_flare_interaction'] = data['score_n'] * data['total_flares']
data['flares_per_month'] = data['total_flares'] / (data['time_since_first']/30 + 1e-6)
data['delta_SLEDAI_Renal'] = data.groupby('PTNO')['SLEDAI_Renal'].diff().fillna(0)
data['time_between_visits'] = data.groupby('PTNO')['ASSDT'].diff().dt.days
data['visits_last_year'] = data.groupby('PTNO')['ASSDT'].transform(
    lambda x: x.apply(lambda d: ((x >= (d - pd.Timedelta(days=365))) & (x <= d)).sum()))

# Select features
numeric_cols = [col for col in data.select_dtypes(include=['int64', 'float64']).columns ]

# --- Data Cleaning and Scaling ---
for col in numeric_cols:
    # Handle infinite values
    data[col] = data[col].replace([np.inf, -np.inf], np.nan)

    # Log-transform large values
    if data[col].max() > 1e6:
        data[col] = np.log1p(data[col])

    # Fill NaNs
    data[col] = data[col].fillna(0)

# Apply scaling
scaler = MinMaxScaler(feature_range=(0, 1))
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])

# --- Feature Selection with Random Forest ---
print("=== Feature Selection with Random Forest ===")

# Get MAXIMUM value for each patient (changed from last observation)
max_obs = data.groupby('PTNO')[numeric_cols].max()
y_labels = data.groupby('PTNO')['end_state_encoded'].last()  # Last outcome

# Train RF to get feature importances
rf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf.fit(max_obs, y_labels)

# Get top 20 features
importances = rf.feature_importances_
top_20_idx = np.argsort(importances)[-20:]
selected_features = [numeric_cols[i] for i in top_20_idx]

print("\nSelected Top 20 Features:")
for i, feat in enumerate(selected_features):
    print(f"{i+1}. {feat} (importance: {importances[top_20_idx][i]:.4f})")

# --- Prepare Sequences with Selected Features ---
def create_sequences(data, features, max_seq_length=None):
    patients = data['PTNO'].unique()
    if not max_seq_length:
        max_seq_length = data.groupby('PTNO').size().max()

    X_seq = np.zeros((len(patients), max_seq_length, len(features)))
    y = np.zeros(len(patients))

    for i, patient in enumerate(patients):
        patient_data = data[data['PTNO'] == patient].sort_values('ASSDT')
        seq_len = len(patient_data)
        X_seq[i, :seq_len, :] = patient_data[features].values
        y[i] = patient_data['end_state_encoded'].iloc[-1]

    return X_seq, to_categorical(y)

# Create sequences with only selected features
X_seq, y = create_sequences(data, selected_features)
y_labels = np.argmax(y, axis=1)

# --- LSTM Model ---
def build_lstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Masking(mask_value=0)(inputs)
    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = LSTM(32)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(0.001),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# --- LSTM Training with Selected Features ---
print("\n=== Training LSTM with Selected Features ===")
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
lstm_scores = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X_seq, y_labels)):
    print(f"\nFold {fold + 1}/{n_splits}")

    X_train, X_val = X_seq[train_idx], X_seq[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Train LSTM
    model = build_lstm_model((X_seq.shape[1], X_seq.shape[2]), y.shape[1])
    model.fit(X_train, y_train,
              epochs=150,
              batch_size=32,
              validation_data=(X_val, y_val),
              callbacks=[EarlyStopping(patience=5, restore_best_weights=True)],
              verbose=1)

    # Evaluate
    y_pred = model.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_val, axis=1)

    bal_acc = balanced_accuracy_score(y_true_classes, y_pred_classes)
    lstm_scores.append(bal_acc)

    print(f"\nFold {fold + 1} Balanced Accuracy: {bal_acc:.4f}")
    print(classification_report(y_true_classes, y_pred_classes))

# Final Results
print("\n=== Final Results ===")
print(f"Average Balanced Accuracy: {np.mean(lstm_scores):.4f} ± {np.std(lstm_scores):.4f}")
print(f"Selected Features Used: {selected_features}")

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(len(selected_features)), importances[top_20_idx][::-1])
plt.yticks(range(len(selected_features)), np.array(selected_features)[::-1])
plt.xlabel("Feature Importance")
plt.title("Top 20 Selected Features by Importance")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-3-1893461173.py:19: DtypeWarning: Columns (94,139,148,155,157) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sledatanodead.csv', parse_dates=['ASSDT'])
# /tmp/ipython-input-3-1893461173.py:47: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])
# === Feature Selection with Random Forest ===
#
# Selected Top 20 Features:
# 1. time_since_dx (importance: 0.0129)
# 2. STERAVER (importance: 0.0129)
# 3. AGE_DX (importance: 0.0129)
# 4. AMS_alt (importance: 0.0132)
# 5. time_since_first (importance: 0.0137)
# 6. sick_leave_spell (importance: 0.0138)
# 7. time_since_last (importance: 0.0141)
# 8. PTNO (importance: 0.0145)
# 9. time_first_last96 (importance: 0.0150)
# 10. visit_num96 (importance: 0.0156)
# 11. time_first_last (importance: 0.0169)
# 12. total_visits96 (importance: 0.0175)
# 13. cum_area (importance: 0.0176)
# 14. cum_time (importance: 0.0180)
# 15. age_at_record (importance: 0.0213)
# 16. time_to_first_change (importance: 0.0408)
# 17. age_at_retirement (importance: 0.0437)
# 18. first_change_index (importance: 0.0566)
# 19. early_retirement (importance: 0.0766)
# 20. EMP_numeric (importance: 0.0917)
#
# === Training LSTM with Selected Features ===
#
# Fold 1/5
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 240ms/step - accuracy: 0.2906 - loss: 1.8681 - val_accuracy: 0.2812 - val_loss: 1.6399
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.5113 - loss: 1.3622 - val_accuracy: 0.3438 - val_loss: 1.5908
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.5910 - loss: 1.0443 - val_accuracy: 0.4531 - val_loss: 1.5357
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.6820 - loss: 0.9429 - val_accuracy: 0.6250 - val_loss: 1.4635
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 315ms/step - accuracy: 0.7543 - loss: 0.8002 - val_accuracy: 0.5938 - val_loss: 1.4391
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 264ms/step - accuracy: 0.7851 - loss: 0.6887 - val_accuracy: 0.5938 - val_loss: 1.4341
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 156ms/step - accuracy: 0.7880 - loss: 0.6880 - val_accuracy: 0.6719 - val_loss: 1.3454
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8544 - loss: 0.6103 - val_accuracy: 0.6562 - val_loss: 1.3244
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8405 - loss: 0.5244 - val_accuracy: 0.6875 - val_loss: 1.3118
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8371 - loss: 0.5251 - val_accuracy: 0.7344 - val_loss: 1.2440
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.8577 - loss: 0.5167 - val_accuracy: 0.7344 - val_loss: 1.1604
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8670 - loss: 0.4704 - val_accuracy: 0.7188 - val_loss: 1.1431
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.8400 - loss: 0.5074 - val_accuracy: 0.8125 - val_loss: 1.0739
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 234ms/step - accuracy: 0.8459 - loss: 0.4473 - val_accuracy: 0.7812 - val_loss: 1.0355
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 145ms/step - accuracy: 0.8936 - loss: 0.3965 - val_accuracy: 0.7969 - val_loss: 1.0208
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8741 - loss: 0.4316 - val_accuracy: 0.7969 - val_loss: 0.9262
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8595 - loss: 0.4020 - val_accuracy: 0.7188 - val_loss: 1.0081
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8941 - loss: 0.3535 - val_accuracy: 0.7500 - val_loss: 0.9054
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.8880 - loss: 0.3674 - val_accuracy: 0.8125 - val_loss: 0.8519
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8909 - loss: 0.3787 - val_accuracy: 0.7188 - val_loss: 0.9465
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 147ms/step - accuracy: 0.8990 - loss: 0.3563 - val_accuracy: 0.7656 - val_loss: 0.8253
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 237ms/step - accuracy: 0.8996 - loss: 0.3251 - val_accuracy: 0.7188 - val_loss: 0.8186
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 190ms/step - accuracy: 0.9218 - loss: 0.2673 - val_accuracy: 0.7656 - val_loss: 0.7922
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8964 - loss: 0.3342 - val_accuracy: 0.7812 - val_loss: 0.7206
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9084 - loss: 0.2472 - val_accuracy: 0.7812 - val_loss: 0.7257
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9475 - loss: 0.2382 - val_accuracy: 0.7812 - val_loss: 0.7141
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9286 - loss: 0.2475 - val_accuracy: 0.7656 - val_loss: 0.7541
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8954 - loss: 0.3310 - val_accuracy: 0.7812 - val_loss: 0.6827
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9384 - loss: 0.2615 - val_accuracy: 0.7812 - val_loss: 0.6410
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9175 - loss: 0.2545 - val_accuracy: 0.8281 - val_loss: 0.6106
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 208ms/step - accuracy: 0.9257 - loss: 0.2376 - val_accuracy: 0.7812 - val_loss: 0.6534
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 244ms/step - accuracy: 0.9239 - loss: 0.2301 - val_accuracy: 0.7969 - val_loss: 0.6533
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9190 - loss: 0.2268 - val_accuracy: 0.7812 - val_loss: 0.6446
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.9338 - loss: 0.2490 - val_accuracy: 0.7969 - val_loss: 0.6104
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 146ms/step - accuracy: 0.9440 - loss: 0.1873 - val_accuracy: 0.8281 - val_loss: 0.6381
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9332 - loss: 0.2478 - val_accuracy: 0.8281 - val_loss: 0.6568
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9404 - loss: 0.2122 - val_accuracy: 0.8281 - val_loss: 0.6071
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9468 - loss: 0.1887 - val_accuracy: 0.7969 - val_loss: 0.6488
# Epoch 39/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.9190 - loss: 0.2312 - val_accuracy: 0.8125 - val_loss: 0.6431
# Epoch 40/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.9401 - loss: 0.1848 - val_accuracy: 0.8125 - val_loss: 0.6708
# Epoch 41/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 240ms/step - accuracy: 0.9634 - loss: 0.1682 - val_accuracy: 0.7812 - val_loss: 0.7683
# Epoch 42/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 171ms/step - accuracy: 0.9330 - loss: 0.1906 - val_accuracy: 0.8281 - val_loss: 0.6628
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 1 Balanced Accuracy: 0.7123
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.58        13
#            1       1.00      1.00      1.00         5
#            2       0.80      0.80      0.80         5
#            3       0.90      0.97      0.94        37
#            4       0.33      0.25      0.29         4
#
#     accuracy                           0.83        64
#    macro avg       0.73      0.71      0.72        64
# weighted avg       0.81      0.83      0.82        64
#
#
# Fold 2/5
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 281ms/step - accuracy: 0.3701 - loss: 1.9837 - val_accuracy: 0.4688 - val_loss: 1.5610
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 254ms/step - accuracy: 0.5996 - loss: 1.1654 - val_accuracy: 0.6094 - val_loss: 1.5324
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.7296 - loss: 0.8496 - val_accuracy: 0.7188 - val_loss: 1.5027
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7280 - loss: 0.7885 - val_accuracy: 0.7656 - val_loss: 1.4388
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.7483 - loss: 0.6829 - val_accuracy: 0.7812 - val_loss: 1.4002
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8374 - loss: 0.6024 - val_accuracy: 0.7812 - val_loss: 1.3681
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8051 - loss: 0.5685 - val_accuracy: 0.7969 - val_loss: 1.3050
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8114 - loss: 0.5541 - val_accuracy: 0.7969 - val_loss: 1.2496
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8057 - loss: 0.5473 - val_accuracy: 0.7969 - val_loss: 1.2196
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.8153 - loss: 0.5085 - val_accuracy: 0.7812 - val_loss: 1.1781
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 176ms/step - accuracy: 0.8451 - loss: 0.4255 - val_accuracy: 0.7969 - val_loss: 1.1618
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.8599 - loss: 0.4657 - val_accuracy: 0.7656 - val_loss: 1.0932
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8383 - loss: 0.4556 - val_accuracy: 0.7969 - val_loss: 1.0603
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8534 - loss: 0.4261 - val_accuracy: 0.7969 - val_loss: 1.0280
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 161ms/step - accuracy: 0.8745 - loss: 0.3672 - val_accuracy: 0.7812 - val_loss: 1.0036
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8726 - loss: 0.3559 - val_accuracy: 0.7812 - val_loss: 0.9685
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - accuracy: 0.8845 - loss: 0.3560 - val_accuracy: 0.7812 - val_loss: 0.9231
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8906 - loss: 0.3271 - val_accuracy: 0.7812 - val_loss: 0.8947
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8773 - loss: 0.3964 - val_accuracy: 0.7812 - val_loss: 0.8788
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9094 - loss: 0.3107 - val_accuracy: 0.7812 - val_loss: 0.8632
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8814 - loss: 0.2988 - val_accuracy: 0.7812 - val_loss: 0.8397
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9124 - loss: 0.2700 - val_accuracy: 0.7969 - val_loss: 0.7999
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8853 - loss: 0.3097 - val_accuracy: 0.7969 - val_loss: 0.7772
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8906 - loss: 0.3572 - val_accuracy: 0.7656 - val_loss: 0.7853
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 216ms/step - accuracy: 0.8857 - loss: 0.2898 - val_accuracy: 0.7656 - val_loss: 0.7267
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 231ms/step - accuracy: 0.9367 - loss: 0.2061 - val_accuracy: 0.7031 - val_loss: 0.7529
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9044 - loss: 0.2789 - val_accuracy: 0.7500 - val_loss: 0.7157
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9659 - loss: 0.2027 - val_accuracy: 0.8281 - val_loss: 0.6685
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 165ms/step - accuracy: 0.9194 - loss: 0.2298 - val_accuracy: 0.7969 - val_loss: 0.6765
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9201 - loss: 0.2559 - val_accuracy: 0.7500 - val_loss: 0.7196
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9080 - loss: 0.2345 - val_accuracy: 0.7656 - val_loss: 0.7162
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 188ms/step - accuracy: 0.9172 - loss: 0.2260 - val_accuracy: 0.8281 - val_loss: 0.6579
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step - accuracy: 0.9117 - loss: 0.2495 - val_accuracy: 0.7656 - val_loss: 0.7404
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.9167 - loss: 0.2350 - val_accuracy: 0.7656 - val_loss: 0.7531
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.9553 - loss: 0.1662 - val_accuracy: 0.7812 - val_loss: 0.6582
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9101 - loss: 0.2544 - val_accuracy: 0.7656 - val_loss: 0.7378
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.9698 - loss: 0.1620 - val_accuracy: 0.7500 - val_loss: 0.7268
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
#
# Fold 2 Balanced Accuracy: 0.6286
#               precision    recall  f1-score   support
#
#            0       0.67      0.77      0.71        13
#            1       1.00      1.00      1.00         4
#            2       0.67      0.40      0.50         5
#            3       0.88      0.97      0.93        38
#            4       0.00      0.00      0.00         4
#
#     accuracy                           0.83        64
#    macro avg       0.64      0.63      0.63        64
# weighted avg       0.77      0.83      0.80        64
#
#
# Fold 3/5
# Epoch 1/150
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 9s 243ms/step - accuracy: 0.3255 - loss: 2.0069 - val_accuracy: 0.1875 - val_loss: 1.6192
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.4804 - loss: 1.5401 - val_accuracy: 0.4219 - val_loss: 1.5727
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.5446 - loss: 1.2179 - val_accuracy: 0.5625 - val_loss: 1.5352
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.6327 - loss: 1.0746 - val_accuracy: 0.6719 - val_loss: 1.4972
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.6994 - loss: 0.9774 - val_accuracy: 0.7500 - val_loss: 1.4438
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 212ms/step - accuracy: 0.7243 - loss: 0.9042 - val_accuracy: 0.7969 - val_loss: 1.4068
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 229ms/step - accuracy: 0.7361 - loss: 0.8362 - val_accuracy: 0.7344 - val_loss: 1.3774
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7825 - loss: 0.6588 - val_accuracy: 0.7656 - val_loss: 1.3316
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.7434 - loss: 0.6719 - val_accuracy: 0.7812 - val_loss: 1.2955
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.7740 - loss: 0.7043 - val_accuracy: 0.7969 - val_loss: 1.2542
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.7897 - loss: 0.5993 - val_accuracy: 0.7500 - val_loss: 1.2062
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8375 - loss: 0.5954 - val_accuracy: 0.7500 - val_loss: 1.2169
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.7997 - loss: 0.5923 - val_accuracy: 0.7344 - val_loss: 1.1731
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.8312 - loss: 0.5579 - val_accuracy: 0.8125 - val_loss: 1.1247
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 167ms/step - accuracy: 0.8306 - loss: 0.4865 - val_accuracy: 0.7812 - val_loss: 1.0975
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 163ms/step - accuracy: 0.8412 - loss: 0.4509 - val_accuracy: 0.7188 - val_loss: 1.0469
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8575 - loss: 0.4367 - val_accuracy: 0.7188 - val_loss: 1.0194
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8763 - loss: 0.4072 - val_accuracy: 0.7656 - val_loss: 0.9759
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.8717 - loss: 0.4311 - val_accuracy: 0.6875 - val_loss: 0.9683
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8789 - loss: 0.4121 - val_accuracy: 0.6875 - val_loss: 0.9343
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.8720 - loss: 0.3777 - val_accuracy: 0.7500 - val_loss: 0.8882
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.8941 - loss: 0.3802 - val_accuracy: 0.8125 - val_loss: 0.8632
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9101 - loss: 0.3619 - val_accuracy: 0.7188 - val_loss: 0.8536
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 230ms/step - accuracy: 0.8870 - loss: 0.3455 - val_accuracy: 0.8125 - val_loss: 0.8367
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 151ms/step - accuracy: 0.9121 - loss: 0.3030 - val_accuracy: 0.8281 - val_loss: 0.7857
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9006 - loss: 0.3033 - val_accuracy: 0.7500 - val_loss: 0.7667
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8946 - loss: 0.3363 - val_accuracy: 0.7344 - val_loss: 0.7546
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9184 - loss: 0.2946 - val_accuracy: 0.7656 - val_loss: 0.7330
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9278 - loss: 0.2604 - val_accuracy: 0.7656 - val_loss: 0.7263
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.9138 - loss: 0.2406 - val_accuracy: 0.8438 - val_loss: 0.7133
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.9356 - loss: 0.2842 - val_accuracy: 0.7656 - val_loss: 0.7429
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - accuracy: 0.9189 - loss: 0.2932 - val_accuracy: 0.8125 - val_loss: 0.6531
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 149ms/step - accuracy: 0.9042 - loss: 0.2879 - val_accuracy: 0.8125 - val_loss: 0.6498
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.8982 - loss: 0.2881 - val_accuracy: 0.8438 - val_loss: 0.6377
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.9142 - loss: 0.2366 - val_accuracy: 0.8125 - val_loss: 0.6076
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.8991 - loss: 0.2453 - val_accuracy: 0.7812 - val_loss: 0.6232
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9393 - loss: 0.2008 - val_accuracy: 0.8438 - val_loss: 0.6240
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.9369 - loss: 0.2593 - val_accuracy: 0.7812 - val_loss: 0.6302
# Epoch 39/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9094 - loss: 0.2445 - val_accuracy: 0.7500 - val_loss: 0.6693
# Epoch 40/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 170ms/step - accuracy: 0.9527 - loss: 0.1798 - val_accuracy: 0.8125 - val_loss: 0.5879
# Epoch 41/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 170ms/step - accuracy: 0.9426 - loss: 0.2156 - val_accuracy: 0.8281 - val_loss: 0.5635
# Epoch 42/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.9215 - loss: 0.2101 - val_accuracy: 0.8125 - val_loss: 0.6133
# Epoch 43/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - accuracy: 0.9489 - loss: 0.1804 - val_accuracy: 0.7812 - val_loss: 0.6289
# Epoch 44/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.9504 - loss: 0.1984 - val_accuracy: 0.7969 - val_loss: 0.6270
# Epoch 45/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.9509 - loss: 0.1484 - val_accuracy: 0.7656 - val_loss: 0.7157
# Epoch 46/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 158ms/step - accuracy: 0.9321 - loss: 0.1931 - val_accuracy: 0.7812 - val_loss: 0.6451
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
#
# Fold 3 Balanced Accuracy: 0.6585
#               precision    recall  f1-score   support
#
#            0       0.64      0.69      0.67        13
#            1       1.00      1.00      1.00         4
#            2       0.33      0.20      0.25         5
#            3       1.00      1.00      1.00        37
#            4       0.33      0.40      0.36         5
#
#     accuracy                           0.83        64
#    macro avg       0.66      0.66      0.66        64
# weighted avg       0.82      0.83      0.82        64
#
#
# Fold 4/5
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 8s 238ms/step - accuracy: 0.2383 - loss: 2.3676 - val_accuracy: 0.4844 - val_loss: 1.5626
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.4448 - loss: 1.3899 - val_accuracy: 0.6094 - val_loss: 1.5090
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.5895 - loss: 1.1260 - val_accuracy: 0.6094 - val_loss: 1.4583
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.6705 - loss: 0.8981 - val_accuracy: 0.6250 - val_loss: 1.4078
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.7086 - loss: 0.7570 - val_accuracy: 0.6719 - val_loss: 1.3652
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 171ms/step - accuracy: 0.7381 - loss: 0.7185 - val_accuracy: 0.7031 - val_loss: 1.3437
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 159ms/step - accuracy: 0.8000 - loss: 0.7168 - val_accuracy: 0.7031 - val_loss: 1.2980
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.7903 - loss: 0.6027 - val_accuracy: 0.7344 - val_loss: 1.2533
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.7913 - loss: 0.6291 - val_accuracy: 0.7500 - val_loss: 1.2197
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 159ms/step - accuracy: 0.8580 - loss: 0.5096 - val_accuracy: 0.7812 - val_loss: 1.1640
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8313 - loss: 0.5655 - val_accuracy: 0.7812 - val_loss: 1.1270
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 245ms/step - accuracy: 0.8548 - loss: 0.4195 - val_accuracy: 0.7812 - val_loss: 1.0858
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 158ms/step - accuracy: 0.8591 - loss: 0.4323 - val_accuracy: 0.7969 - val_loss: 1.0643
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8582 - loss: 0.4472 - val_accuracy: 0.7969 - val_loss: 1.0272
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.8772 - loss: 0.3786 - val_accuracy: 0.7812 - val_loss: 1.0053
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - accuracy: 0.8620 - loss: 0.4088 - val_accuracy: 0.7812 - val_loss: 0.9954
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8602 - loss: 0.4530 - val_accuracy: 0.7969 - val_loss: 0.9635
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8952 - loss: 0.3592 - val_accuracy: 0.7969 - val_loss: 0.9171
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 4s 247ms/step - accuracy: 0.8673 - loss: 0.3406 - val_accuracy: 0.7812 - val_loss: 0.8969
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.8886 - loss: 0.3696 - val_accuracy: 0.7812 - val_loss: 0.8745
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 161ms/step - accuracy: 0.8682 - loss: 0.3279 - val_accuracy: 0.7969 - val_loss: 0.8503
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 160ms/step - accuracy: 0.9161 - loss: 0.2918 - val_accuracy: 0.8281 - val_loss: 0.8186
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 161ms/step - accuracy: 0.8937 - loss: 0.3172 - val_accuracy: 0.7656 - val_loss: 0.7744
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 151ms/step - accuracy: 0.8913 - loss: 0.3453 - val_accuracy: 0.7812 - val_loss: 0.7536
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8646 - loss: 0.3596 - val_accuracy: 0.7969 - val_loss: 0.7644
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 243ms/step - accuracy: 0.9239 - loss: 0.2696 - val_accuracy: 0.7969 - val_loss: 0.7252
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 152ms/step - accuracy: 0.8985 - loss: 0.2928 - val_accuracy: 0.7812 - val_loss: 0.7223
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.9251 - loss: 0.2291 - val_accuracy: 0.7656 - val_loss: 0.7267
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.9027 - loss: 0.3152 - val_accuracy: 0.7656 - val_loss: 0.7233
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 150ms/step - accuracy: 0.8944 - loss: 0.2709 - val_accuracy: 0.7812 - val_loss: 0.7242
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9089 - loss: 0.2764 - val_accuracy: 0.7812 - val_loss: 0.7442
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9123 - loss: 0.2392 - val_accuracy: 0.7500 - val_loss: 0.7074
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.9129 - loss: 0.2670 - val_accuracy: 0.7812 - val_loss: 0.6250
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 3s 241ms/step - accuracy: 0.9244 - loss: 0.2572 - val_accuracy: 0.7812 - val_loss: 0.6482
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 164ms/step - accuracy: 0.9157 - loss: 0.2633 - val_accuracy: 0.7969 - val_loss: 0.6580
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 152ms/step - accuracy: 0.9329 - loss: 0.2298 - val_accuracy: 0.7969 - val_loss: 0.6878
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 162ms/step - accuracy: 0.9189 - loss: 0.2569 - val_accuracy: 0.7969 - val_loss: 0.6771
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.9374 - loss: 0.1832 - val_accuracy: 0.7812 - val_loss: 0.6538
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#
# Fold 4 Balanced Accuracy: 0.6422
#               precision    recall  f1-score   support
#
#            0       0.56      0.69      0.62        13
#            1       1.00      1.00      1.00         4
#            2       1.00      0.60      0.75         5
#            3       0.87      0.92      0.89        37
#            4       0.00      0.00      0.00         5
#
#     accuracy                           0.78        64
#    macro avg       0.69      0.64      0.65        64
# weighted avg       0.76      0.78      0.76        64
#
#
# Fold 5/5
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - accuracy: 0.1532 - loss: 2.3625 - val_accuracy: 0.6667 - val_loss: 1.5631
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.3500 - loss: 1.5148 - val_accuracy: 0.7302 - val_loss: 1.5190
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.6477 - loss: 1.1074 - val_accuracy: 0.7937 - val_loss: 1.4469
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.7198 - loss: 0.9063 - val_accuracy: 0.7937 - val_loss: 1.3679
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.7192 - loss: 0.8385 - val_accuracy: 0.7937 - val_loss: 1.3201
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.7610 - loss: 0.7396 - val_accuracy: 0.7778 - val_loss: 1.2848
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.7573 - loss: 0.7127 - val_accuracy: 0.7937 - val_loss: 1.2588
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8321 - loss: 0.5904 - val_accuracy: 0.7937 - val_loss: 1.2163
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 142ms/step - accuracy: 0.7736 - loss: 0.6944 - val_accuracy: 0.7460 - val_loss: 1.1575
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 187ms/step - accuracy: 0.8111 - loss: 0.5184 - val_accuracy: 0.7937 - val_loss: 1.1369
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8100 - loss: 0.5783 - val_accuracy: 0.8095 - val_loss: 1.0991
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.8254 - loss: 0.4882 - val_accuracy: 0.7619 - val_loss: 1.0600
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.8525 - loss: 0.4342 - val_accuracy: 0.8095 - val_loss: 1.0443
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8755 - loss: 0.4252 - val_accuracy: 0.7460 - val_loss: 0.9766
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.8510 - loss: 0.4376 - val_accuracy: 0.7778 - val_loss: 0.9286
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8779 - loss: 0.4137 - val_accuracy: 0.7619 - val_loss: 0.9095
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - accuracy: 0.8542 - loss: 0.4201 - val_accuracy: 0.7937 - val_loss: 0.8720
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.8732 - loss: 0.3572 - val_accuracy: 0.7937 - val_loss: 0.8347
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - accuracy: 0.8866 - loss: 0.3255 - val_accuracy: 0.7937 - val_loss: 0.8066
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 180ms/step - accuracy: 0.9062 - loss: 0.2938 - val_accuracy: 0.8095 - val_loss: 0.7944
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - accuracy: 0.8677 - loss: 0.3329 - val_accuracy: 0.7937 - val_loss: 0.7465
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.9121 - loss: 0.3155 - val_accuracy: 0.8095 - val_loss: 0.6848
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - accuracy: 0.8874 - loss: 0.3122 - val_accuracy: 0.8095 - val_loss: 0.6955
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.9301 - loss: 0.2584 - val_accuracy: 0.8095 - val_loss: 0.7001
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9081 - loss: 0.2795 - val_accuracy: 0.7937 - val_loss: 0.6628
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.8658 - loss: 0.3359 - val_accuracy: 0.7143 - val_loss: 0.7762
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.8868 - loss: 0.2941 - val_accuracy: 0.8254 - val_loss: 0.6513
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.9071 - loss: 0.2893 - val_accuracy: 0.7619 - val_loss: 0.6719
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.9204 - loss: 0.2745 - val_accuracy: 0.8095 - val_loss: 0.5864
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 191ms/step - accuracy: 0.8926 - loss: 0.3077 - val_accuracy: 0.6984 - val_loss: 0.8701
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - accuracy: 0.8883 - loss: 0.3940 - val_accuracy: 0.7778 - val_loss: 0.6220
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.8850 - loss: 0.3886 - val_accuracy: 0.7619 - val_loss: 0.6379
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.9043 - loss: 0.2639 - val_accuracy: 0.7460 - val_loss: 0.6474
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.9154 - loss: 0.2361 - val_accuracy: 0.7619 - val_loss: 0.6439
# WARNING:tensorflow:5 out of the last 9 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e5624f65bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 986ms/step
# WARNING:tensorflow:6 out of the last 10 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7e5624f65bc0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
#
# Fold 5 Balanced Accuracy: 0.5984
#               precision    recall  f1-score   support
#
#            0       0.71      0.77      0.74        13
#            1       0.80      1.00      0.89         4
#            2       0.50      0.25      0.33         4
#            3       0.88      0.97      0.92        37
#            4       0.00      0.00      0.00         5
#
#     accuracy                           0.81        63
#    macro avg       0.58      0.60      0.58        63
# weighted avg       0.75      0.81      0.77        63
#
#
# === Final Results ===
# Average Balanced Accuracy: 0.6480 ± 0.0377
# Selected Features Used: ['time_since_dx', 'STERAVER', 'AGE_DX', 'AMS_alt', 'time_since_first', 'sick_leave_spell', 'time_since_last', 'PTNO', 'time_first_last96', 'visit_num96', 'time_first_last', 'total_visits96', 'cum_area', 'cum_time', 'age_at_record', 'time_to_first_change', 'age_at_retirement', 'first_change_index', 'early_retirement', 'EMP_numeric']

# %% [markdown]
# ## Model with full patient followups but no data leak

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, balanced_accuracy_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Masking, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import random
import tensorflow as tf

# --- Data Loading and Preparation ---
data = pd.read_csv('sledatacut2.csv', parse_dates=['ASSDT'])

random.seed(1927)
np.random.seed(1927)
tf.random.set_seed(1927)
# Feature Engineering
data['sdi_flare_interaction'] = data['score_n'] * data['total_flares']
data['flares_per_month'] = data['total_flares'] / (data['time_since_first']/30 + 1e-6)
data['delta_SLEDAI_Renal'] = data.groupby('PTNO')['SLEDAI_Renal'].diff().fillna(0)
data['time_between_visits'] = data.groupby('PTNO')['ASSDT'].diff().dt.days
data['visits_last_year'] = data.groupby('PTNO')['ASSDT'].transform(
    lambda x: x.apply(lambda d: ((x >= (d - pd.Timedelta(days=365))) & (x <= d)).sum()))

# Select features
numeric_cols = [col for col in data.select_dtypes(include=['int64', 'float64']).columns ]

# --- Data Cleaning and Scaling ---
for col in numeric_cols:
    # Handle infinite values
    data[col] = data[col].replace([np.inf, -np.inf], np.nan)

    # Log-transform large values
    if data[col].max() > 1e6:
        data[col] = np.log1p(data[col])

    # Fill NaNs
    data[col] = data[col].fillna(0)

# Apply scaling
scaler = MinMaxScaler(feature_range=(0, 1))
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])

# --- Feature Selection with Random Forest ---
print("=== Feature Selection with Random Forest ===")

# Get MAXIMUM value for each patient (changed from last observation)
max_obs = data.groupby('PTNO')[numeric_cols].max()
y_labels = data.groupby('PTNO')['end_state_encoded'].last()  # Last outcome

# Train RF to get feature importances
rf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf.fit(max_obs, y_labels)

# Get top 20 features
importances = rf.feature_importances_
top_20_idx = np.argsort(importances)[-20:]
selected_features = [numeric_cols[i] for i in top_20_idx]

print("\nSelected Top 20 Features:")
for i, feat in enumerate(selected_features):
    print(f"{i+1}. {feat} (importance: {importances[top_20_idx][i]:.4f})")

# --- Prepare Sequences with Selected Features ---
def create_sequences(data, features, max_seq_length=None):
    patients = data['PTNO'].unique()
    if not max_seq_length:
        max_seq_length = data.groupby('PTNO').size().max()

    X_seq = np.zeros((len(patients), max_seq_length, len(features)))
    y = np.zeros(len(patients))

    for i, patient in enumerate(patients):
        patient_data = data[data['PTNO'] == patient].sort_values('ASSDT')
        seq_len = len(patient_data)
        X_seq[i, :seq_len, :] = patient_data[features].values
        y[i] = patient_data['end_state_encoded'].iloc[-1]

    return X_seq, to_categorical(y)

# Create sequences with only selected features
X_seq, y = create_sequences(data, selected_features)
y_labels = np.argmax(y, axis=1)

# --- LSTM Model ---
def build_lstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Masking(mask_value=0)(inputs)
    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = LSTM(32)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(0.001),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# --- LSTM Training with Selected Features ---
print("\n=== Training LSTM with Selected Features ===")
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
lstm_scores = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X_seq, y_labels)):
    print(f"\nFold {fold + 1}/{n_splits}")

    X_train, X_val = X_seq[train_idx], X_seq[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Train LSTM
    model = build_lstm_model((X_seq.shape[1], X_seq.shape[2]), y.shape[1])
    model.fit(X_train, y_train,
              epochs=150,
              batch_size=32,
              validation_data=(X_val, y_val),
              callbacks=[EarlyStopping(patience=5, restore_best_weights=True)],
              verbose=1)

    # Evaluate
    y_pred = model.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_val, axis=1)

    bal_acc = balanced_accuracy_score(y_true_classes, y_pred_classes)
    lstm_scores.append(bal_acc)

    print(f"\nFold {fold + 1} Balanced Accuracy: {bal_acc:.4f}")
    print(classification_report(y_true_classes, y_pred_classes))

# Final Results
print("\n=== Final Results ===")
print(f"Average Balanced Accuracy: {np.mean(lstm_scores):.4f} ± {np.std(lstm_scores):.4f}")
print(f"Selected Features Used: {selected_features}")

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(len(selected_features)), importances[top_20_idx][::-1])
plt.yticks(range(len(selected_features)), np.array(selected_features)[::-1])
plt.xlabel("Feature Importance")
plt.title("Top 20 Selected Features by Importance")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-4-799520660.py:17: DtypeWarning: Columns (136,138,145,147,154,156,161) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sledatacut2.csv', parse_dates=['ASSDT'])
# /tmp/ipython-input-4-799520660.py:48: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])
# === Feature Selection with Random Forest ===
#
# Selected Top 20 Features:
# 1. time_between_visits (importance: 0.0140)
# 2. AGE_DX (importance: 0.0141)
# 3. time_since_last (importance: 0.0150)
# 4. ID (importance: 0.0155)
# 5. PTNO (importance: 0.0158)
# 6. total_visits (importance: 0.0158)
# 7. visit_num (importance: 0.0181)
# 8. time_first_last (importance: 0.0188)
# 9. sick_leave_spell (importance: 0.0192)
# 10. sick_leave_duration (importance: 0.0201)
# 11. total_visits96 (importance: 0.0209)
# 12. time_first_last96 (importance: 0.0229)
# 13. time_to_first_change (importance: 0.0245)
# 14. time_since_first (importance: 0.0277)
# 15. cum_time (importance: 0.0277)
# 16. age_at_record (importance: 0.0326)
# 17. age_at_retirement (importance: 0.0509)
# 18. visit_num96 (importance: 0.0523)
# 19. early_retirement (importance: 0.0712)
# 20. EMP_numeric (importance: 0.1252)
#
# === Training LSTM with Selected Features ===
#
# Fold 1/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.4543 - loss: 1.7673 - val_accuracy: 0.2750 - val_loss: 1.6414
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.7327 - loss: 1.0239 - val_accuracy: 0.7350 - val_loss: 1.4857
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.8262 - loss: 0.7646 - val_accuracy: 0.8750 - val_loss: 1.3334
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.8411 - loss: 0.6483 - val_accuracy: 0.8650 - val_loss: 1.1899
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8661 - loss: 0.5871 - val_accuracy: 0.8700 - val_loss: 1.0508
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8761 - loss: 0.5459 - val_accuracy: 0.8650 - val_loss: 0.9093
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8812 - loss: 0.5149 - val_accuracy: 0.8600 - val_loss: 0.7630
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8783 - loss: 0.4994 - val_accuracy: 0.8700 - val_loss: 0.6478
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8900 - loss: 0.4667 - val_accuracy: 0.8750 - val_loss: 0.5647
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.8999 - loss: 0.4091 - val_accuracy: 0.8700 - val_loss: 0.5156
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.9042 - loss: 0.3714 - val_accuracy: 0.8950 - val_loss: 0.4486
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9034 - loss: 0.4016 - val_accuracy: 0.9000 - val_loss: 0.4062
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 116ms/step - accuracy: 0.9074 - loss: 0.3484 - val_accuracy: 0.9050 - val_loss: 0.3729
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9069 - loss: 0.3339 - val_accuracy: 0.9050 - val_loss: 0.3400
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9269 - loss: 0.2823 - val_accuracy: 0.8850 - val_loss: 0.4011
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9039 - loss: 0.3126 - val_accuracy: 0.8850 - val_loss: 0.3081
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9177 - loss: 0.3121 - val_accuracy: 0.8900 - val_loss: 0.3231
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9295 - loss: 0.2501 - val_accuracy: 0.9050 - val_loss: 0.2898
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9332 - loss: 0.2594 - val_accuracy: 0.9000 - val_loss: 0.2996
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9207 - loss: 0.2560 - val_accuracy: 0.9050 - val_loss: 0.3016
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9253 - loss: 0.2495 - val_accuracy: 0.8950 - val_loss: 0.2787
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9355 - loss: 0.2422 - val_accuracy: 0.8950 - val_loss: 0.3917
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9241 - loss: 0.2314 - val_accuracy: 0.9050 - val_loss: 0.3502
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 120ms/step - accuracy: 0.9348 - loss: 0.1870 - val_accuracy: 0.9100 - val_loss: 0.3375
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9378 - loss: 0.1751 - val_accuracy: 0.8900 - val_loss: 0.3684
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 155ms/step - accuracy: 0.9357 - loss: 0.1815 - val_accuracy: 0.9100 - val_loss: 0.3562
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
#
# Fold 1 Balanced Accuracy: 0.6932
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68        26
#            1       1.00      1.00      1.00         5
#            2       0.56      0.71      0.62         7
#            3       0.94      0.99      0.96       153
#            4       0.50      0.11      0.18         9
#
#     accuracy                           0.90       200
#    macro avg       0.74      0.69      0.69       200
# weighted avg       0.88      0.90      0.88       200
#
#
# Fold 2/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 186ms/step - accuracy: 0.4561 - loss: 1.6869 - val_accuracy: 0.2600 - val_loss: 1.6290
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.7669 - loss: 1.0529 - val_accuracy: 0.4600 - val_loss: 1.4772
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8269 - loss: 0.7384 - val_accuracy: 0.8600 - val_loss: 1.3072
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8377 - loss: 0.6972 - val_accuracy: 0.8700 - val_loss: 1.1168
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8759 - loss: 0.5899 - val_accuracy: 0.8800 - val_loss: 0.9598
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8873 - loss: 0.5724 - val_accuracy: 0.8750 - val_loss: 0.8514
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8904 - loss: 0.5078 - val_accuracy: 0.8700 - val_loss: 0.7095
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.8796 - loss: 0.5047 - val_accuracy: 0.8700 - val_loss: 0.6019
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8926 - loss: 0.4773 - val_accuracy: 0.8700 - val_loss: 0.5557
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9021 - loss: 0.4284 - val_accuracy: 0.8700 - val_loss: 0.4894
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8973 - loss: 0.4078 - val_accuracy: 0.8700 - val_loss: 0.4614
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8902 - loss: 0.3975 - val_accuracy: 0.8700 - val_loss: 0.4192
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9179 - loss: 0.3315 - val_accuracy: 0.8700 - val_loss: 0.3934
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.9318 - loss: 0.2844 - val_accuracy: 0.8550 - val_loss: 0.3758
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 107ms/step - accuracy: 0.9201 - loss: 0.2903 - val_accuracy: 0.9100 - val_loss: 0.3499
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9271 - loss: 0.2982 - val_accuracy: 0.8650 - val_loss: 0.3403
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 152ms/step - accuracy: 0.9215 - loss: 0.2949 - val_accuracy: 0.9000 - val_loss: 0.3310
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9130 - loss: 0.2602 - val_accuracy: 0.9100 - val_loss: 0.2937
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9384 - loss: 0.2279 - val_accuracy: 0.9000 - val_loss: 0.3462
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.9357 - loss: 0.2032 - val_accuracy: 0.9050 - val_loss: 0.3053
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.9302 - loss: 0.2303 - val_accuracy: 0.9100 - val_loss: 0.2791
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9243 - loss: 0.2242 - val_accuracy: 0.9150 - val_loss: 0.3391
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9499 - loss: 0.1848 - val_accuracy: 0.9050 - val_loss: 0.3247
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9447 - loss: 0.1843 - val_accuracy: 0.9000 - val_loss: 0.3199
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 125ms/step - accuracy: 0.9448 - loss: 0.1654 - val_accuracy: 0.9150 - val_loss: 0.2778
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9309 - loss: 0.2118 - val_accuracy: 0.9100 - val_loss: 0.3174
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9494 - loss: 0.1512 - val_accuracy: 0.9150 - val_loss: 0.3067
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 149ms/step - accuracy: 0.9549 - loss: 0.1606 - val_accuracy: 0.9150 - val_loss: 0.3364
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9581 - loss: 0.1640 - val_accuracy: 0.9100 - val_loss: 0.2781
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9410 - loss: 0.1827 - val_accuracy: 0.8950 - val_loss: 0.2764
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.9461 - loss: 0.2063 - val_accuracy: 0.9100 - val_loss: 0.2753
# Epoch 32/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9533 - loss: 0.1468 - val_accuracy: 0.9100 - val_loss: 0.2943
# Epoch 33/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9580 - loss: 0.1370 - val_accuracy: 0.9150 - val_loss: 0.3343
# Epoch 34/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 159ms/step - accuracy: 0.9468 - loss: 0.1420 - val_accuracy: 0.9100 - val_loss: 0.3027
# Epoch 35/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9533 - loss: 0.1391 - val_accuracy: 0.9100 - val_loss: 0.3006
# Epoch 36/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9584 - loss: 0.1240 - val_accuracy: 0.9100 - val_loss: 0.2803
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 146ms/step
#
# Fold 2 Balanced Accuracy: 0.7708
#               precision    recall  f1-score   support
#
#            0       0.71      0.77      0.74        26
#            1       1.00      1.00      1.00         6
#            2       0.70      1.00      0.82         7
#            3       0.97      0.97      0.97       152
#            4       0.33      0.11      0.17         9
#
#     accuracy                           0.91       200
#    macro avg       0.74      0.77      0.74       200
# weighted avg       0.90      0.91      0.90       200
#
#
# Fold 3/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 140ms/step - accuracy: 0.3654 - loss: 1.8083 - val_accuracy: 0.2750 - val_loss: 1.6179
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.7696 - loss: 0.9481 - val_accuracy: 0.3600 - val_loss: 1.5425
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8520 - loss: 0.7629 - val_accuracy: 0.8150 - val_loss: 1.4167
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8777 - loss: 0.6217 - val_accuracy: 0.8350 - val_loss: 1.2964
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 149ms/step - accuracy: 0.9026 - loss: 0.5031 - val_accuracy: 0.8300 - val_loss: 1.1464
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9079 - loss: 0.4571 - val_accuracy: 0.8700 - val_loss: 0.8776
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9134 - loss: 0.4600 - val_accuracy: 0.8500 - val_loss: 0.7998
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9238 - loss: 0.4109 - val_accuracy: 0.8700 - val_loss: 0.6674
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9309 - loss: 0.3578 - val_accuracy: 0.8450 - val_loss: 0.6317
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9128 - loss: 0.3739 - val_accuracy: 0.8700 - val_loss: 0.5339
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.9279 - loss: 0.3363 - val_accuracy: 0.8500 - val_loss: 0.5461
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.9385 - loss: 0.2928 - val_accuracy: 0.8700 - val_loss: 0.4665
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9443 - loss: 0.2859 - val_accuracy: 0.8600 - val_loss: 0.4423
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 154ms/step - accuracy: 0.9346 - loss: 0.2636 - val_accuracy: 0.8700 - val_loss: 0.4217
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.9249 - loss: 0.2848 - val_accuracy: 0.8550 - val_loss: 0.4247
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.9508 - loss: 0.2360 - val_accuracy: 0.8950 - val_loss: 0.4235
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9528 - loss: 0.2349 - val_accuracy: 0.8750 - val_loss: 0.4626
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9391 - loss: 0.2424 - val_accuracy: 0.8800 - val_loss: 0.4202
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9478 - loss: 0.1950 - val_accuracy: 0.8750 - val_loss: 0.4423
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.9416 - loss: 0.2119 - val_accuracy: 0.8900 - val_loss: 0.4482
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.9565 - loss: 0.1842 - val_accuracy: 0.8900 - val_loss: 0.4836
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.9604 - loss: 0.1762 - val_accuracy: 0.8850 - val_loss: 0.4390
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9594 - loss: 0.1681 - val_accuracy: 0.8800 - val_loss: 0.5023
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
#
# Fold 3 Balanced Accuracy: 0.6249
#               precision    recall  f1-score   support
#
#            0       0.57      0.88      0.70        26
#            1       1.00      1.00      1.00         6
#            2       1.00      0.29      0.44         7
#            3       0.97      0.95      0.96       152
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.88       200
#    macro avg       0.71      0.62      0.62       200
# weighted avg       0.87      0.88      0.87       200
#
#
# Fold 4/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 150ms/step - accuracy: 0.4657 - loss: 1.6557 - val_accuracy: 0.2764 - val_loss: 1.6302
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 137ms/step - accuracy: 0.7702 - loss: 0.9096 - val_accuracy: 0.3920 - val_loss: 1.5432
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.8439 - loss: 0.6945 - val_accuracy: 0.8894 - val_loss: 1.3650
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8425 - loss: 0.6138 - val_accuracy: 0.8894 - val_loss: 1.2484
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8723 - loss: 0.5805 - val_accuracy: 0.8945 - val_loss: 1.0747
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.8882 - loss: 0.4991 - val_accuracy: 0.8844 - val_loss: 0.9167
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.8765 - loss: 0.4846 - val_accuracy: 0.8693 - val_loss: 0.7137
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8812 - loss: 0.4411 - val_accuracy: 0.8894 - val_loss: 0.6569
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.8851 - loss: 0.4112 - val_accuracy: 0.8593 - val_loss: 0.5259
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 147ms/step - accuracy: 0.9025 - loss: 0.3614 - val_accuracy: 0.8643 - val_loss: 0.4763
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9023 - loss: 0.3889 - val_accuracy: 0.8643 - val_loss: 0.4248
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8957 - loss: 0.3837 - val_accuracy: 0.8794 - val_loss: 0.3758
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8935 - loss: 0.3706 - val_accuracy: 0.8794 - val_loss: 0.3490
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.9167 - loss: 0.3048 - val_accuracy: 0.8593 - val_loss: 0.3502
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9080 - loss: 0.3174 - val_accuracy: 0.8995 - val_loss: 0.3095
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9279 - loss: 0.2466 - val_accuracy: 0.8744 - val_loss: 0.3377
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 145ms/step - accuracy: 0.9172 - loss: 0.2734 - val_accuracy: 0.8945 - val_loss: 0.2826
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9296 - loss: 0.2638 - val_accuracy: 0.8844 - val_loss: 0.3095
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.9066 - loss: 0.2682 - val_accuracy: 0.9045 - val_loss: 0.3069
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9323 - loss: 0.2268 - val_accuracy: 0.9095 - val_loss: 0.2737
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 134ms/step - accuracy: 0.9281 - loss: 0.2356 - val_accuracy: 0.9045 - val_loss: 0.3096
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.9268 - loss: 0.2276 - val_accuracy: 0.9146 - val_loss: 0.2788
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9392 - loss: 0.1885 - val_accuracy: 0.9095 - val_loss: 0.2938
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9272 - loss: 0.2074 - val_accuracy: 0.9045 - val_loss: 0.2406
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 148ms/step - accuracy: 0.9498 - loss: 0.1937 - val_accuracy: 0.9095 - val_loss: 0.3304
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.9346 - loss: 0.1956 - val_accuracy: 0.9146 - val_loss: 0.2729
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9320 - loss: 0.1995 - val_accuracy: 0.9146 - val_loss: 0.2823
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.9406 - loss: 0.1654 - val_accuracy: 0.9196 - val_loss: 0.2581
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9561 - loss: 0.1619 - val_accuracy: 0.9146 - val_loss: 0.2649
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step
#
# Fold 4 Balanced Accuracy: 0.7004
#               precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75        26
#            1       1.00      1.00      1.00         5
#            2       1.00      0.71      0.83         7
#            3       0.95      0.98      0.96       152
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.90       199
#    macro avg       0.73      0.70      0.71       199
# weighted avg       0.88      0.90      0.89       199
#
#
# Fold 5/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 178ms/step - accuracy: 0.4316 - loss: 1.7280 - val_accuracy: 0.4070 - val_loss: 1.5833
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 108ms/step - accuracy: 0.7633 - loss: 0.9548 - val_accuracy: 0.6131 - val_loss: 1.4716
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8208 - loss: 0.7407 - val_accuracy: 0.8744 - val_loss: 1.2963
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.8318 - loss: 0.6933 - val_accuracy: 0.8995 - val_loss: 1.1240
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8738 - loss: 0.5828 - val_accuracy: 0.8945 - val_loss: 0.9509
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.8668 - loss: 0.5715 - val_accuracy: 0.8945 - val_loss: 0.8017
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 146ms/step - accuracy: 0.8725 - loss: 0.5274 - val_accuracy: 0.8794 - val_loss: 0.6851
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.8789 - loss: 0.5088 - val_accuracy: 0.8894 - val_loss: 0.5906
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 118ms/step - accuracy: 0.8888 - loss: 0.4890 - val_accuracy: 0.8945 - val_loss: 0.5030
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 132ms/step - accuracy: 0.9020 - loss: 0.4298 - val_accuracy: 0.8945 - val_loss: 0.4668
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9062 - loss: 0.4034 - val_accuracy: 0.8945 - val_loss: 0.3944
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9012 - loss: 0.3717 - val_accuracy: 0.8945 - val_loss: 0.3602
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.9221 - loss: 0.3373 - val_accuracy: 0.8844 - val_loss: 0.3124
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 121ms/step - accuracy: 0.9093 - loss: 0.3176 - val_accuracy: 0.8945 - val_loss: 0.2961
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 181ms/step - accuracy: 0.9169 - loss: 0.3011 - val_accuracy: 0.8844 - val_loss: 0.2698
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 123ms/step - accuracy: 0.9084 - loss: 0.2874 - val_accuracy: 0.8894 - val_loss: 0.3341
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 120ms/step - accuracy: 0.9152 - loss: 0.2965 - val_accuracy: 0.8995 - val_loss: 0.2487
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 167ms/step - accuracy: 0.9220 - loss: 0.2890 - val_accuracy: 0.9045 - val_loss: 0.2632
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9280 - loss: 0.2530 - val_accuracy: 0.9095 - val_loss: 0.2232
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9275 - loss: 0.2580 - val_accuracy: 0.8945 - val_loss: 0.2611
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9119 - loss: 0.2936 - val_accuracy: 0.9146 - val_loss: 0.3013
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.9205 - loss: 0.2704 - val_accuracy: 0.9196 - val_loss: 0.2561
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.9411 - loss: 0.2253 - val_accuracy: 0.9246 - val_loss: 0.2179
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.9356 - loss: 0.2180 - val_accuracy: 0.9196 - val_loss: 0.2165
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 115ms/step - accuracy: 0.9318 - loss: 0.2157 - val_accuracy: 0.9246 - val_loss: 0.2154
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.9430 - loss: 0.2005 - val_accuracy: 0.9146 - val_loss: 0.2015
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.9524 - loss: 0.1720 - val_accuracy: 0.9196 - val_loss: 0.2204
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.9494 - loss: 0.1580 - val_accuracy: 0.9246 - val_loss: 0.2732
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9429 - loss: 0.1867 - val_accuracy: 0.9196 - val_loss: 0.2188
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 131ms/step - accuracy: 0.9396 - loss: 0.2005 - val_accuracy: 0.9196 - val_loss: 0.2380
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.9410 - loss: 0.1747 - val_accuracy: 0.9246 - val_loss: 0.2916
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
#
# Fold 5 Balanced Accuracy: 0.6952
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77        25
#            1       1.00      1.00      1.00         5
#            2       0.80      0.57      0.67         7
#            3       0.97      0.99      0.98       153
#            4       0.17      0.11      0.13         9
#
#     accuracy                           0.91       199
#    macro avg       0.74      0.70      0.71       199
# weighted avg       0.90      0.91      0.91       199
#
#
# === Final Results ===
# Average Balanced Accuracy: 0.6969 ± 0.0462
# Selected Features Used: ['time_between_visits', 'AGE_DX', 'time_since_last', 'ID', 'PTNO', 'total_visits', 'visit_num', 'time_first_last', 'sick_leave_spell', 'sick_leave_duration', 'total_visits96', 'time_first_last96', 'time_to_first_change', 'time_since_first', 'cum_time', 'age_at_record', 'age_at_retirement', 'visit_num96', 'early_retirement', 'EMP_numeric']

# %% [markdown]
# ## Model that only looks at employment portion of patients

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, balanced_accuracy_score
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Masking, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import random
import tensorflow as tf

# --- Data Loading and Preparation ---
data = pd.read_csv('sledatacut2.csv', parse_dates=['ASSDT'])
random.seed(497)
np.random.seed(497)
tf.random.set_seed(497)

# Feature Engineering
data['sdi_flare_interaction'] = data['score_n'] * data['total_flares']
data['flares_per_month'] = data['total_flares'] / (data['time_since_first']/30 + 1e-6)
data['delta_SLEDAI_Renal'] = data.groupby('PTNO')['SLEDAI_Renal'].diff().fillna(0)
data['time_between_visits'] = data.groupby('PTNO')['ASSDT'].diff().dt.days
data['visits_last_year'] = data.groupby('PTNO')['ASSDT'].transform(
    lambda x: x.apply(lambda d: ((x >= (d - pd.Timedelta(days=365))) & (x <= d)).sum()))

# Select features
numeric_cols = [col for col in data.select_dtypes(include=['int64', 'float64']).columns
               if col not in ['PTNO', 'total_visits96', 'time_first_last96', 'AMS_alt', 'first_change_index', 'time_since_first', 'time_since_last', 'ID', 'MAXSTEROIDDOSE', 'time_between96', 'early_retirement', 'DEATH', 'age_at_death', 'age_at_retirement', 'EMP_numeric', 'lupus_primary_death', 'visit_num96', 'lupus_secondary_death', 'time_to_first_change']]


# --- Data Cleaning and Scaling ---
for col in numeric_cols:
    # Handle infinite values
    data[col] = data[col].replace([np.inf, -np.inf], np.nan)

    # Log-transform large values
    if data[col].max() > 1e6:
        data[col] = np.log1p(data[col])

    # Fill NaNs
    data[col] = data[col].fillna(0)

# Apply scaling
scaler = MinMaxScaler(feature_range=(0, 1))
data[numeric_cols] = scaler.fit_transform(data[numeric_cols])
data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])

# --- Feature Selection with Random Forest ---
print("=== Feature Selection with Random Forest ===")

# Get MAXIMUM value for each patient (changed from last observation)
max_obs = data.groupby('PTNO')[numeric_cols].max()
y_labels = data.groupby('PTNO')['end_state_encoded'].last()  # Last outcome

# Train RF to get feature importances
rf = RandomForestClassifier(n_estimators=200, random_state=42, class_weight='balanced')
rf.fit(max_obs, y_labels)

# Get top 20 features
importances = rf.feature_importances_
top_20_idx = np.argsort(importances)[-20:]
selected_features = [numeric_cols[i] for i in top_20_idx]

print("\nSelected Top 20 Features:")
for i, feat in enumerate(selected_features):
    print(f"{i+1}. {feat} (importance: {importances[top_20_idx][i]:.4f})")

# --- Prepare Sequences with Selected Features ---
def create_sequences(data, features, max_seq_length=None):
    patients = data['PTNO'].unique()
    if not max_seq_length:
        max_seq_length = data.groupby('PTNO').size().max()

    X_seq = np.zeros((len(patients), max_seq_length, len(features)))
    y = np.zeros(len(patients))

    for i, patient in enumerate(patients):
        patient_data = data[data['PTNO'] == patient].sort_values('ASSDT')
        seq_len = len(patient_data)
        X_seq[i, :seq_len, :] = patient_data[features].values
        y[i] = patient_data['end_state_encoded'].iloc[-1]

    return X_seq, to_categorical(y)

# Create sequences with only selected features
X_seq, y = create_sequences(data, selected_features)
y_labels = np.argmax(y, axis=1)

# --- LSTM Model ---
def build_lstm_model(input_shape, num_classes):
    inputs = Input(shape=input_shape)
    x = Masking(mask_value=0)(inputs)
    x = LSTM(64, return_sequences=True)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    x = LSTM(32)(x)
    x = BatchNormalization()(x)
    x = Dropout(0.3)(x)
    outputs = Dense(num_classes, activation='softmax')(x)
    model = Model(inputs, outputs)
    model.compile(optimizer=Adam(0.001),
                 loss='categorical_crossentropy',
                 metrics=['accuracy'])
    return model

# --- LSTM Training with Selected Features ---
print("\n=== Training LSTM with Selected Features ===")
n_splits = 5
cv = StratifiedKFold(n_splits=n_splits, shuffle=True, random_state=42)
lstm_scores = []

for fold, (train_idx, val_idx) in enumerate(cv.split(X_seq, y_labels)):
    print(f"\nFold {fold + 1}/{n_splits}")

    X_train, X_val = X_seq[train_idx], X_seq[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]

    # Train LSTM
    model = build_lstm_model((X_seq.shape[1], X_seq.shape[2]), y.shape[1])
    model.fit(X_train, y_train,
              epochs=150,
              batch_size=32,
              validation_data=(X_val, y_val),
              callbacks=[EarlyStopping(patience=5, restore_best_weights=True)],
              verbose=1)

    # Evaluate
    y_pred = model.predict(X_val)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_true_classes = np.argmax(y_val, axis=1)

    bal_acc = balanced_accuracy_score(y_true_classes, y_pred_classes)
    lstm_scores.append(bal_acc)

    print(f"\nFold {fold + 1} Balanced Accuracy: {bal_acc:.4f}")
    print(classification_report(y_true_classes, y_pred_classes))

# Final Results
print("\n=== Final Results ===")
print(f"Average Balanced Accuracy: {np.mean(lstm_scores):.4f} ± {np.std(lstm_scores):.4f}")
print(f"Selected Features Used: {selected_features}")

# Plot feature importances
plt.figure(figsize=(10, 6))
plt.barh(range(len(selected_features)), importances[top_20_idx][::-1])
plt.yticks(range(len(selected_features)), np.array(selected_features)[::-1])
plt.xlabel("Feature Importance")
plt.title("Top 20 Selected Features by Importance")
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipython-input-5-1999357186.py:17: DtypeWarning: Columns (136,138,145,147,154,156,161) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('sledatacut2.csv', parse_dates=['ASSDT'])
# /tmp/ipython-input-5-1999357186.py:50: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data['end_state_encoded'] = LabelEncoder().fit_transform(data['end_state'])
# === Feature Selection with Random Forest ===
#
# Selected Top 20 Features:
# 1. previous_sledai (importance: 0.0164)
# 2. sick_leave_duration (importance: 0.0183)
# 3. STERDOSE (importance: 0.0183)
# 4. visits_last_year (importance: 0.0184)
# 5. AMS (importance: 0.0211)
# 6. STERAVER (importance: 0.0211)
# 7. sick_leave_spell (importance: 0.0218)
# 8. area (importance: 0.0248)
# 9. time_since_dx (importance: 0.0270)
# 10. AGE_DX (importance: 0.0271)
# 11. time_between (importance: 0.0274)
# 12. days_since_last_visit (importance: 0.0292)
# 13. time_between_visits (importance: 0.0294)
# 14. time_interval (importance: 0.0297)
# 15. cum_area (importance: 0.0315)
# 16. total_visits (importance: 0.0396)
# 17. time_first_last (importance: 0.0428)
# 18. visit_num (importance: 0.0445)
# 19. age_at_record (importance: 0.0530)
# 20. cum_time (importance: 0.0557)
#
# === Training LSTM with Selected Features ===
#
# Fold 1/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 137ms/step - accuracy: 0.3508 - loss: 2.0631 - val_accuracy: 0.3350 - val_loss: 1.5800
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 114ms/step - accuracy: 0.6962 - loss: 1.2455 - val_accuracy: 0.6600 - val_loss: 1.4980
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.7705 - loss: 1.0170 - val_accuracy: 0.8300 - val_loss: 1.3951
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 113ms/step - accuracy: 0.8061 - loss: 0.9344 - val_accuracy: 0.8600 - val_loss: 1.2794
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.7939 - loss: 0.8186 - val_accuracy: 0.8500 - val_loss: 1.1142
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8159 - loss: 0.7706 - val_accuracy: 0.8450 - val_loss: 0.9898
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.8276 - loss: 0.7404 - val_accuracy: 0.8500 - val_loss: 0.8662
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8321 - loss: 0.7194 - val_accuracy: 0.8450 - val_loss: 0.7639
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8482 - loss: 0.6132 - val_accuracy: 0.8500 - val_loss: 0.6889
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 157ms/step - accuracy: 0.8314 - loss: 0.6353 - val_accuracy: 0.8450 - val_loss: 0.6161
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.8340 - loss: 0.6176 - val_accuracy: 0.8400 - val_loss: 0.5752
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8402 - loss: 0.5528 - val_accuracy: 0.8500 - val_loss: 0.5250
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.8509 - loss: 0.5237 - val_accuracy: 0.8450 - val_loss: 0.4959
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8384 - loss: 0.5881 - val_accuracy: 0.8450 - val_loss: 0.4846
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8503 - loss: 0.4937 - val_accuracy: 0.8400 - val_loss: 0.4821
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 148ms/step - accuracy: 0.8720 - loss: 0.4298 - val_accuracy: 0.8300 - val_loss: 0.4896
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8527 - loss: 0.4616 - val_accuracy: 0.8300 - val_loss: 0.4714
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.8631 - loss: 0.4595 - val_accuracy: 0.8500 - val_loss: 0.4508
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.8592 - loss: 0.4629 - val_accuracy: 0.8550 - val_loss: 0.4503
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8764 - loss: 0.4132 - val_accuracy: 0.8400 - val_loss: 0.4455
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8898 - loss: 0.3755 - val_accuracy: 0.8350 - val_loss: 0.4209
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8804 - loss: 0.3867 - val_accuracy: 0.8550 - val_loss: 0.4346
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8611 - loss: 0.4016 - val_accuracy: 0.8650 - val_loss: 0.4310
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 157ms/step - accuracy: 0.9055 - loss: 0.3425 - val_accuracy: 0.8450 - val_loss: 0.4210
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.8925 - loss: 0.3347 - val_accuracy: 0.8600 - val_loss: 0.4468
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9027 - loss: 0.3205 - val_accuracy: 0.8650 - val_loss: 0.4569
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step
#
# Fold 1 Balanced Accuracy: 0.3946
#               precision    recall  f1-score   support
#
#            0       0.61      0.54      0.57        26
#            1       0.33      0.20      0.25         5
#            2       0.11      0.14      0.12         7
#            3       0.93      0.98      0.96       153
#            4       0.25      0.11      0.15         9
#
#     accuracy                           0.83       200
#    macro avg       0.45      0.39      0.41       200
# weighted avg       0.82      0.83      0.82       200
#
#
# Fold 2/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.3957 - loss: 1.9735 - val_accuracy: 0.4450 - val_loss: 1.5771
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 150ms/step - accuracy: 0.6875 - loss: 1.2082 - val_accuracy: 0.6450 - val_loss: 1.5244
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.7664 - loss: 1.0329 - val_accuracy: 0.7950 - val_loss: 1.4360
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.7795 - loss: 0.9591 - val_accuracy: 0.8250 - val_loss: 1.3109
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 128ms/step - accuracy: 0.7998 - loss: 0.8147 - val_accuracy: 0.8100 - val_loss: 1.2218
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.7986 - loss: 0.7890 - val_accuracy: 0.8400 - val_loss: 1.1238
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.8206 - loss: 0.7166 - val_accuracy: 0.8500 - val_loss: 0.9999
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8183 - loss: 0.7115 - val_accuracy: 0.8500 - val_loss: 0.8866
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8277 - loss: 0.6151 - val_accuracy: 0.8350 - val_loss: 0.7818
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.8374 - loss: 0.5991 - val_accuracy: 0.8450 - val_loss: 0.7022
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8487 - loss: 0.5318 - val_accuracy: 0.8600 - val_loss: 0.6470
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8438 - loss: 0.5706 - val_accuracy: 0.8400 - val_loss: 0.6154
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8677 - loss: 0.5356 - val_accuracy: 0.8450 - val_loss: 0.5868
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8809 - loss: 0.4551 - val_accuracy: 0.8250 - val_loss: 0.6283
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8528 - loss: 0.5051 - val_accuracy: 0.8400 - val_loss: 0.5621
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8590 - loss: 0.4591 - val_accuracy: 0.8250 - val_loss: 0.5442
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8812 - loss: 0.4156 - val_accuracy: 0.8450 - val_loss: 0.5488
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8844 - loss: 0.3871 - val_accuracy: 0.8400 - val_loss: 0.5478
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8723 - loss: 0.3984 - val_accuracy: 0.8200 - val_loss: 0.5480
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8868 - loss: 0.3707 - val_accuracy: 0.8350 - val_loss: 0.5749
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.9072 - loss: 0.3373 - val_accuracy: 0.8350 - val_loss: 0.6066
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step
#
# Fold 2 Balanced Accuracy: 0.3657
#               precision    recall  f1-score   support
#
#            0       0.58      0.58      0.58        26
#            1       0.50      0.17      0.25         6
#            2       0.00      0.00      0.00         7
#            3       0.93      0.97      0.95       152
#            4       0.09      0.11      0.10         9
#
#     accuracy                           0.82       200
#    macro avg       0.42      0.37      0.38       200
# weighted avg       0.80      0.82      0.81       200
#
#
# Fold 3/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 133ms/step - accuracy: 0.5145 - loss: 1.7212 - val_accuracy: 0.2600 - val_loss: 1.6796
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 155ms/step - accuracy: 0.7422 - loss: 1.0714 - val_accuracy: 0.2650 - val_loss: 1.7002
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 112ms/step - accuracy: 0.7820 - loss: 0.9958 - val_accuracy: 0.3700 - val_loss: 1.6370
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8457 - loss: 0.8324 - val_accuracy: 0.6500 - val_loss: 1.5508
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8016 - loss: 0.8484 - val_accuracy: 0.7800 - val_loss: 1.4183
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8343 - loss: 0.8242 - val_accuracy: 0.7750 - val_loss: 1.2988
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8218 - loss: 0.7288 - val_accuracy: 0.7800 - val_loss: 1.0505
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8272 - loss: 0.7003 - val_accuracy: 0.7800 - val_loss: 0.9552
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 150ms/step - accuracy: 0.8495 - loss: 0.6704 - val_accuracy: 0.8000 - val_loss: 0.8855
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 109ms/step - accuracy: 0.8475 - loss: 0.5993 - val_accuracy: 0.8000 - val_loss: 0.7133
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8452 - loss: 0.6162 - val_accuracy: 0.7950 - val_loss: 0.7186
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8417 - loss: 0.5550 - val_accuracy: 0.8150 - val_loss: 0.7123
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.8726 - loss: 0.4897 - val_accuracy: 0.8000 - val_loss: 0.6381
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 110ms/step - accuracy: 0.8385 - loss: 0.5122 - val_accuracy: 0.7850 - val_loss: 0.6599
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.8492 - loss: 0.4892 - val_accuracy: 0.7850 - val_loss: 0.6751
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 124ms/step - accuracy: 0.8541 - loss: 0.5115 - val_accuracy: 0.7850 - val_loss: 0.6022
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8717 - loss: 0.4615 - val_accuracy: 0.8050 - val_loss: 0.6980
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8640 - loss: 0.4541 - val_accuracy: 0.7950 - val_loss: 0.7076
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 154ms/step - accuracy: 0.8458 - loss: 0.4777 - val_accuracy: 0.8100 - val_loss: 0.6120
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step - accuracy: 0.8604 - loss: 0.4315 - val_accuracy: 0.8100 - val_loss: 0.6389
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8756 - loss: 0.4309 - val_accuracy: 0.7850 - val_loss: 0.6857
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step
#
# Fold 3 Balanced Accuracy: 0.3888
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.55        26
#            1       0.11      0.17      0.13         6
#            2       0.33      0.14      0.20         7
#            3       0.90      0.91      0.90       152
#            4       0.50      0.11      0.18         9
#
#     accuracy                           0.79       200
#    macro avg       0.47      0.39      0.39       200
# weighted avg       0.78      0.79      0.78       200
#
#
# Fold 4/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.3312 - loss: 2.0016 - val_accuracy: 0.3970 - val_loss: 1.5803
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.6754 - loss: 1.2685 - val_accuracy: 0.7638 - val_loss: 1.5019
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7280 - loss: 1.1966 - val_accuracy: 0.8392 - val_loss: 1.3835
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.7694 - loss: 0.9992 - val_accuracy: 0.8342 - val_loss: 1.2443
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.7678 - loss: 0.9756 - val_accuracy: 0.8442 - val_loss: 1.0909
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.7982 - loss: 0.8428 - val_accuracy: 0.8492 - val_loss: 0.9472
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7872 - loss: 0.8278 - val_accuracy: 0.8342 - val_loss: 0.7996
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8111 - loss: 0.7229 - val_accuracy: 0.8442 - val_loss: 0.7154
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8297 - loss: 0.6814 - val_accuracy: 0.8291 - val_loss: 0.6315
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.8103 - loss: 0.6617 - val_accuracy: 0.8342 - val_loss: 0.5640
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 138ms/step - accuracy: 0.8243 - loss: 0.6035 - val_accuracy: 0.8392 - val_loss: 0.5399
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 106ms/step - accuracy: 0.8276 - loss: 0.5781 - val_accuracy: 0.8492 - val_loss: 0.5307
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8362 - loss: 0.5358 - val_accuracy: 0.8492 - val_loss: 0.5374
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 126ms/step - accuracy: 0.8373 - loss: 0.5319 - val_accuracy: 0.8492 - val_loss: 0.5313
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 130ms/step - accuracy: 0.8440 - loss: 0.5081 - val_accuracy: 0.8442 - val_loss: 0.5445
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8563 - loss: 0.5000 - val_accuracy: 0.8442 - val_loss: 0.5416
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 113ms/step - accuracy: 0.8605 - loss: 0.4916 - val_accuracy: 0.8291 - val_loss: 0.5596
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step
#
# Fold 4 Balanced Accuracy: 0.4576
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        26
#            1       0.50      0.20      0.29         5
#            2       0.60      0.43      0.50         7
#            3       0.92      0.97      0.94       152
#            4       0.00      0.00      0.00         9
#
#     accuracy                           0.85       199
#    macro avg       0.52      0.46      0.47       199
# weighted avg       0.81      0.85      0.83       199
#
#
# Fold 5/5
# Epoch 1/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 139ms/step - accuracy: 0.3827 - loss: 1.8807 - val_accuracy: 0.3518 - val_loss: 1.6035
# Epoch 2/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.7257 - loss: 1.1165 - val_accuracy: 0.4925 - val_loss: 1.5713
# Epoch 3/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.7491 - loss: 1.0319 - val_accuracy: 0.7588 - val_loss: 1.4788
# Epoch 4/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.7911 - loss: 0.9504 - val_accuracy: 0.8492 - val_loss: 1.3593
# Epoch 5/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8195 - loss: 0.8473 - val_accuracy: 0.8492 - val_loss: 1.2376
# Epoch 6/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8212 - loss: 0.8308 - val_accuracy: 0.8593 - val_loss: 1.1007
# Epoch 7/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8100 - loss: 0.7479 - val_accuracy: 0.8442 - val_loss: 0.9634
# Epoch 8/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.8230 - loss: 0.7396 - val_accuracy: 0.8593 - val_loss: 0.8775
# Epoch 9/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.8177 - loss: 0.7025 - val_accuracy: 0.8593 - val_loss: 0.7532
# Epoch 10/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8404 - loss: 0.6191 - val_accuracy: 0.8593 - val_loss: 0.6485
# Epoch 11/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8397 - loss: 0.5992 - val_accuracy: 0.8643 - val_loss: 0.6112
# Epoch 12/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 156ms/step - accuracy: 0.8349 - loss: 0.5631 - val_accuracy: 0.8442 - val_loss: 0.5642
# Epoch 13/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8427 - loss: 0.5324 - val_accuracy: 0.8442 - val_loss: 0.5171
# Epoch 14/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 112ms/step - accuracy: 0.8418 - loss: 0.5486 - val_accuracy: 0.8543 - val_loss: 0.5162
# Epoch 15/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8629 - loss: 0.4970 - val_accuracy: 0.8643 - val_loss: 0.5201
# Epoch 16/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 141ms/step - accuracy: 0.8479 - loss: 0.5067 - val_accuracy: 0.8492 - val_loss: 0.4680
# Epoch 17/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 117ms/step - accuracy: 0.8590 - loss: 0.4677 - val_accuracy: 0.8442 - val_loss: 0.4515
# Epoch 18/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8535 - loss: 0.4435 - val_accuracy: 0.8442 - val_loss: 0.4511
# Epoch 19/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 152ms/step - accuracy: 0.8753 - loss: 0.4290 - val_accuracy: 0.8392 - val_loss: 0.4650
# Epoch 20/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 105ms/step - accuracy: 0.8363 - loss: 0.4662 - val_accuracy: 0.8442 - val_loss: 0.4535
# Epoch 21/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8612 - loss: 0.4611 - val_accuracy: 0.8442 - val_loss: 0.4915
# Epoch 22/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 138ms/step - accuracy: 0.8709 - loss: 0.4253 - val_accuracy: 0.8392 - val_loss: 0.4595
# Epoch 23/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.8564 - loss: 0.4494 - val_accuracy: 0.8442 - val_loss: 0.4389
# Epoch 24/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 112ms/step - accuracy: 0.8709 - loss: 0.3922 - val_accuracy: 0.8593 - val_loss: 0.4360
# Epoch 25/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 153ms/step - accuracy: 0.8718 - loss: 0.4076 - val_accuracy: 0.8543 - val_loss: 0.4349
# Epoch 26/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - accuracy: 0.8740 - loss: 0.4177 - val_accuracy: 0.8492 - val_loss: 0.4371
# Epoch 27/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - accuracy: 0.8700 - loss: 0.3691 - val_accuracy: 0.8643 - val_loss: 0.4209
# Epoch 28/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 107ms/step - accuracy: 0.8982 - loss: 0.3407 - val_accuracy: 0.8593 - val_loss: 0.4629
# Epoch 29/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8679 - loss: 0.3842 - val_accuracy: 0.8543 - val_loss: 0.4649
# Epoch 30/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 106ms/step - accuracy: 0.8698 - loss: 0.3821 - val_accuracy: 0.8191 - val_loss: 0.4661
# Epoch 31/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 108ms/step - accuracy: 0.8854 - loss: 0.3574 - val_accuracy: 0.8492 - val_loss: 0.4348
# Epoch 32/150
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 151ms/step - accuracy: 0.8823 - loss: 0.3433 - val_accuracy: 0.8442 - val_loss: 0.4360
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
#
# Fold 5 Balanced Accuracy: 0.4740
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69        25
#            1       0.50      0.20      0.29         5
#            2       0.50      0.14      0.22         7
#            3       0.93      0.97      0.95       153
#            4       0.38      0.33      0.35         9
#
#     accuracy                           0.86       199
#    macro avg       0.59      0.47      0.50       199
# weighted avg       0.85      0.86      0.85       199
#
#
# === Final Results ===
# Average Balanced Accuracy: 0.4161 ± 0.0420
# Selected Features Used: ['previous_sledai', 'sick_leave_duration', 'STERDOSE', 'visits_last_year', 'AMS', 'STERAVER', 'sick_leave_spell', 'area', 'time_since_dx', 'AGE_DX', 'time_between', 'days_since_last_visit', 'time_between_visits', 'time_interval', 'cum_area', 'total_visits', 'time_first_last', 'visit_num', 'age_at_record', 'cum_time']
